# %% [markdown]
# # NI-DM: A Summary in many parts
#
# ## Part 1: Constructing and Querying Object Models
#
# satra@mit.edu, nolan.nichols@gmail.com
#
# [Latest version](https://github.com/INCF/ni-dm/tree/source/source/notebooks/Object models.ipynb)

# %% [markdown]
# ## Outline
#
# - What is a data model, provenance, [PROV-DM](http://www.w3.org/TR/prov-dm/) and [NI-DM](http://nidm.nidash.org)?
# - What is an object model?
# - Using the [PROV Python library](https://github.com/trungdong/prov) to construct object models
# - Querying object models with [SPARQL](http://www.w3.org/TR/rdf-sparql-query/) using a [triplestore](http://en.wikipedia.org/wiki/Triplestore)
# - Mapping [XCEDE](http://www.xcede.org/) "experiment/research" primitives to NI-DM

# %% [markdown]
# ## What is a data model?
#
# A data model is an abstract conceptual formulation of information that explictly determines the structure of data and allows software and people to communicate and interpret data precisely. [ source: http://en.wikipedia.org/wiki/Data_model ]
#
# ## What is Provenance?
#
# Provenance is information about entities, activities, and people involved in producing a piece of data or thing, which can be used to form assessments about its quality, reliability or trustworthiness.
#
# ## What is PROV-DM?
#
# [PROV-DM](http://www.w3.org/TR/prov-dm/) is the conceptual data model that forms a basis for the W3C provenance (PROV) [family of specifications](http://www.w3.org/2011/prov/wiki/WorkingDrafts).
#
# PROV-DM is organized in six components, respectively dealing with: (1) [entities and activities](http://www.w3.org/TR/prov-dm/#section-entity-activity), and the time at which they were created, used, or ended; (2) [derivations](http://www.w3.org/TR/prov-dm/#section-derivation) of entities from entities; (3) [agents](http://www.w3.org/TR/prov-dm/#section-agents-attribution-association-delegation) bearing responsibility for entities that were generated and activities that happened; (4) a notion of [bundle](http://www.w3.org/TR/prov-dm/#section-provenance-of-provnance), a mechanism to support provenance of provenance; (5) [properties to link entities](http://www.w3.org/TR/prov-dm/#section-prov-extended-mechanisms) that refer to the same thing; and, (6) [collections](http://www.w3.org/TR/prov-dm/#section-collections) forming a logical structure for its members.
#
# ## What is NI-DM?
#
# NI-DM is formulated as a domain specific extension of PROV-DM. Currently, NI-DM maps identically to PROV-DM and domain extensions are captured as object models on top of PROV-DM.

# %% [markdown]
# ### Basic Provenance data model
#
# <img src="http://www.w3.org/TR/prov-o/diagrams/starting-points.svg" />

# %% [markdown]
# ### Extended provenance model
#
# <img src="http://www.w3.org/TR/2013/PR-prov-o-20130312/diagrams/expanded.svg" />

# %% [markdown]
# ### What are the advantages of using NI-DM
#
# - Provenance is not an afterthought
# - Terminology is important
# - W3C recommendation at this point
# - Many tools are starting to support the model
# - Captures data and metadata (about entities, **activities** and agents) within the same context
# - Simplifies app development
# - Maps to Semantic Web tools allowing query federation
#
# ### What are the disadvantages of using NI-DM
#
# - A new way of thinking about queries and computation
# - Requires extensive terminology
# - Current databases are not built for provenance
# - Current databases are very specifically structured
# - The transition will require resources, commitment and time

# %% [markdown]
# ## What is an object model?
#
# An object model represents a collection "through which a program can examine and manipulate some specific parts of its world."
#
# ## What are object models in NI-DM?
#
# In the context of NI-DM, object models capture specific relationships between [entities][entity] via [collections][collection] that reflect organization information derived from imaging files (e.g., DICOM, Nifti, MINC), directory structures (e.g., Freesurfer, OpenFMRI), phenotypic data (e.g., neuropsych assessments, csv files) and binary or text files (e.g., SPM.mat, Feat.fsf, aseg.stats). The models are associated with appropriate provenance.
#
# [entity]: http://www.w3.org/TR/prov-o/#Entity
# [collection]: http://www.w3.org/TR/prov-o/#Collections

# %% [markdown]
# ## Using the PROV API to construct object models
#
# We will demonstrate how to encapsulate FreeSurfer directory structures and statistic files, and CSV files using the PROV API.

# %% [markdown]
# ### Model 1: FreeSurfer Directory structure
#
# The FreeSurfer output results from a recon-all process that involves several steps. The goal here is to take the directory structure and represent it as a collection of entities, where each entity is a file produced by the recon-all process. In the ideal mode, the recon-all process itself would generate the provenance and the collection of entities. But here we generate the NI-DM encoding of FreeSurfer directories by walking FreeSurfer directories and applying heuristic properties.
#
# For demonstration purposes, we automatically generated terms based on file/directory naming conventions, and assossate these terms with an example FreeSurfer namespace [http://surfer.nmr.mgh.harvard.edu/fswiki/terms/0.1/]. This namespace is only a placeholder; however, the developers of a given neuroimaging software package (e.g., FreeSurfer) are responsible for managing a namespace that resolves to a vocabulary that describes their NI-DM object model. The best practice is to provide a URL accessible [RDF](http://www.w3.org/RDF/) representation of the terms in this namespace along with definitions for each term.
#
# Some example terms are:
#
#     - fs:subject_id : a participant identifier
#     - fs:relative_path : location of file from the root of the subject directory structure
#
# note: `fs:` is a namespace prefix that allows for a shorthand notation of the full URI (e.g., `http://surfer.nmr.mgh.harvard.edu/fswiki/terms/0.1/subject_id`)

# %% [markdown]
# #### Import necessary tools and create namespaces
#
# This example uses two Python libraries that you will need to install
#
#     - Nipype: http://nipy.org/nipype/
#     - PROV: https://github.com/trungdong/prov

# %%
# standard library
import os
import md5
from socket import getfqdn

# PROV API library
import prov.model as prov

def hash_infile(afile, chunk_len=8192):
    """ Computes md5 hash of a file"""
    md5hex = None
    if os.path.isfile(afile):
        md5obj = md5.md5()
        fp = file(afile, 'rb')
        while True:
            data = fp.read(chunk_len)
            if not data:
                break
            md5obj.update(data)
        fp.close()
        md5hex = md5obj.hexdigest()
    return md5hex

# create namespace references to terms used
foaf = prov.Namespace("foaf", "http://xmlns.com/foaf/0.1/")
dcterms = prov.Namespace("dcterms", "http://purl.org/dc/terms/")
fs = prov.Namespace("fs", "http://surfer.nmr.mgh.harvard.edu/fswiki/terms/0.1/")
nidm = prov.Namespace("nidm", "http://nidm.nidash.org/terms/0.1/")
obo = prov.Namespace("obo", "http://purl.obolibrary.org/obo/")
nif = prov.Namespace("nif", "http://neurolex.org/wiki/")

# %% [markdown]
# ### Define a function that creates a NI-DM Entity for a freesurfer file

# %%
ls -lR /Applications/freesurfer/subjects/bert
# Out:
# total 0
# dr-xr-xr-x@  2 satra  staff    68 Jun  2  2011 bem/
# dr-xr-xr-x@ 39 satra  staff  1326 Jun  2  2011 label/
# dr-xr-xr-x@ 38 satra  staff  1292 Jun  2  2011 mri/
# dr-xr-xr-x@ 12 satra  staff   408 Jun  2  2011 scripts/
# dr-xr-xr-x@  2 satra  staff    68 Jun  2  2011 src/
# dr-xr-xr-x@ 14 satra  staff   476 Jun  2  2011 stats/
# dr-xr-xr-x@ 70 satra  staff  2380 Jun  2  2011 surf/
# dr-xr-xr-x@  2 satra  staff    68 Jun  2  2011 tmp/
# dr-xr-xr-x@ 67 satra  staff  2278 Jun  2  2011 touch/
# dr-xr-xr-x@ 10 satra  staff   340 Jun  2  2011 trash/
#
# /Applications/freesurfer/subjects/bert/bem:
#
# /Applications/freesurfer/subjects/bert/label:
# total 43936
# -r--r--r--@ 1 satra  staff      702 Jun  2  2011 BA.ctab
# -r--r--r--@ 1 satra  staff     4104 Jun  2  2011 aparc.annot.a2009s.ctab
# -r--r--r--@ 1 satra  staff     1944 Jun  2  2011 aparc.annot.ctab
# -r--r--r--@ 1 satra  staff  1066072 Jun  2  2011 lh.BA.annot
# -r--r--r--@ 1 satra  staff   126374 Jun  2  2011 lh.BA1.label
# -r--r--r--@ 1 satra  staff   230450 Jun  2  2011 lh.BA2.label
# -r--r--r--@ 1 satra  staff   110281 Jun  2  2011 lh.BA3a.label
# -r--r--r--@ 1 satra  staff   179949 Jun  2  2011 lh.BA3b.label
# -r--r--r--@ 1 satra  staff   134925 Jun  2  2011 lh.BA44.label
# -r--r--r--@ 1 satra  staff   180908 Jun  2  2011 lh.BA45.label
# -r--r--r--@ 1 satra  staff   196848 Jun  2  2011 lh.BA4a.label
# -r--r--r--@ 1 satra  staff   131668 Jun  2  2011 lh.BA4p.label
# -r--r--r--@ 1 satra  staff   426464 Jun  2  2011 lh.BA6.label
# -r--r--r--@ 1 satra  staff    86830 Jun  2  2011 lh.MT.label
# -r--r--r--@ 1 satra  staff   231440 Jun  2  2011 lh.V1.label
# -r--r--r--@ 1 satra  staff   456174 Jun  2  2011 lh.V2.label
# -r--r--r--@ 1 satra  staff  1068932 Jun  2  2011 lh.aparc.a2009s.annot
# -r--r--r--@ 1 satra  staff  1067122 Jun  2  2011 lh.aparc.annot
# -r--r--r--@ 1 satra  staff  5546229 Jun  2  2011 lh.cortex.label
# -r--r--r--@ 1 satra  staff    14788 Jun  2  2011 lh.entorhinal_exvivo.label
# -r--r--r--@ 1 satra  staff  1061016 Jun  2  2011 rh.BA.annot
# -r--r--r--@ 1 satra  staff   130155 Jun  2  2011 rh.BA1.label
# -r--r--r--@ 1 satra  staff   210484 Jun  2  2011 rh.BA2.label
# -r--r--r--@ 1 satra  staff   114241 Jun  2  2011 rh.BA3a.label
# -r--r--r--@ 1 satra  staff   150660 Jun  2  2011 rh.BA3b.label
# -r--r--r--@ 1 satra  staff   255122 Jun  2  2011 rh.BA44.label
# -r--r--r--@ 1 satra  staff   254600 Jun  2  2011 rh.BA45.label
# -r--r--r--@ 1 satra  staff   184190 Jun  2  2011 rh.BA4a.label
# -r--r--r--@ 1 satra  staff   131918 Jun  2  2011 rh.BA4p.label
# -r--r--r--@ 1 satra  staff   360691 Jun  2  2011 rh.BA6.label
# -r--r--r--@ 1 satra  staff    82308 Jun  2  2011 rh.MT.label
# -r--r--r--@ 1 satra  staff   231337 Jun  2  2011 rh.V1.label
# -r--r--r--@ 1 satra  staff   432230 Jun  2  2011 rh.V2.label
# -r--r--r--@ 1 satra  staff  1063876 Jun  2  2011 rh.aparc.a2009s.annot
# -r--r--r--@ 1 satra  staff  1062066 Jun  2  2011 rh.aparc.annot
# -r--r--r--@ 1 satra  staff  5413404 Jun  2  2011 rh.cortex.label
# -r--r--r--@ 1 satra  staff     9894 Jun  2  2011 rh.entorhinal_exvivo.label
#
# /Applications/freesurfer/subjects/bert/mri:
# total 72728
# -r--r--r--@  1 satra  staff  5231304 Jun  2  2011 T1.mgz
# -r--r--r--@  1 satra  staff   407610 Jun  2  2011 aparc+aseg.mgz
# -r--r--r--@  1 satra  staff   441207 Jun  2  2011 aparc.a2009s+aseg.mgz
# -r--r--r--@  1 satra  staff   237646 Jun  2  2011 aseg.auto.mgz
# -r--r--r--@  1 satra  staff     1591 Jun  2  2011 aseg.auto_noCCseg.label_intensities.txt
# -r--r--r--@  1 satra  staff   237194 Jun  2  2011 aseg.auto_noCCseg.mgz
# -r--r--r--@  1 satra  staff   237646 Jun  2  2011 aseg.mgz
# -r--r--r--@  1 satra  staff  1388385 Jun  2  2011 brain.finalsurfs.mgz
# -r--r--r--@  1 satra  staff  1402746 Jun  2  2011 brain.mgz
# -r--r--r--@  1 satra  staff  1264655 Jun  2  2011 brainmask.auto.mgz
# -r--r--r--@  1 satra  staff   170600 Jun  2  2011 brainmask.gcuts.mgz
# -r--r--r--@  1 satra  staff  1431095 Jun  2  2011 brainmask.mgz
# -r--r--r--@  1 satra  staff   580634 Jun  2  2011 ctrl_pts.mgz
# -r--r--r--@  1 satra  staff   134979 Jun  2  2011 filled.mgz
# -r--r--r--@  1 satra  staff   113982 Jun  2  2011 lh.ribbon.mgz
# -r--r--r--@  1 satra  staff     9986 Jun  2  2011 mri_nu_correct.mni.log
# -r--r--r--@  1 satra  staff    10389 Jun  2  2011 mri_nu_correct.mni.log.bak
# -r--r--r--@  1 satra  staff  1510476 Jun  2  2011 norm.mgz
# -r--r--r--@  1 satra  staff  5386873 Jun  2  2011 nu.mgz
# -r--r--r--@  1 satra  staff  3685004 Jun  2  2011 nu_noneck.mgz
# dr-xr-xr-x@ 11 satra  staff      374 Jun  2  2011 orig/
# -r--r--r--@  1 satra  staff  5669237 Jun  2  2011 orig.mgz
# -r--r--r--@  1 satra  staff  5669066 Jun  2  2011 rawavg.mgz
# -r--r--r--@  1 satra  staff   115467 Jun  2  2011 rh.ribbon.mgz
# -r--r--r--@  1 satra  staff   216538 Jun  2  2011 ribbon.mgz
# -r--r--r--@  1 satra  staff      121 Jun  2  2011 segment.dat
# -r--r--r--@  1 satra  staff     1591 Jun  2  2011 talairach.label_intensities.txt
# -r--r--r--@  1 satra  staff      686 Jun  2  2011 talairach.log
# -r--r--r--@  1 satra  staff     1392 Jun  2  2011 talairach_with_skull.log
# dr-xr-xr-x@ 16 satra  staff      544 Jun  2  2011 transforms/
# -r--r--r--@  1 satra  staff   366781 Jun  2  2011 wm.asegedit.mgz
# -r--r--r--@  1 satra  staff   367359 Jun  2  2011 wm.mgz
# -r--r--r--@  1 satra  staff   407525 Jun  2  2011 wm.seg.mgz
# -r--r--r--@  1 satra  staff       33 Jun  2  2011 wm1.txt
# -r--r--r--@  1 satra  staff       29 Jun  2  2011 wm255.txt
# -r--r--r--@  1 satra  staff   461522 Jun  2  2011 wmparc.mgz
#
# /Applications/freesurfer/subjects/bert/mri/orig:
# total 35528
# -r--r--r--@ 1 satra  staff        1 Jun  2  2011 001-iscale.txt
# -r--r--r--@ 1 satra  staff     1689 Jun  2  2011 001.lta
# -r--r--r--@ 1 satra  staff  5996899 Jun  2  2011 001.mgz
# -r--r--r--@ 1 satra  staff        8 Jun  2  2011 002-iscale.txt
# -r--r--r--@ 1 satra  staff     1693 Jun  2  2011 002.lta
# -r--r--r--@ 1 satra  staff  6077242 Jun  2  2011 002.mgz
# -r--r--r--@ 1 satra  staff        8 Jun  2  2011 003-iscale.txt
# -r--r--r--@ 1 satra  staff     1694 Jun  2  2011 003.lta
# -r--r--r--@ 1 satra  staff  6083164 Jun  2  2011 003.mgz
#
# /Applications/freesurfer/subjects/bert/mri/transforms:
# total 194160
# dr-xr-xr-x@ 2 satra  staff        68 Jun  2  2011 bak/
# -r--r--r--@ 1 satra  staff      1696 Jun  2  2011 cc_up.lta
# -r--r--r--@ 1 satra  staff       194 Jun  2  2011 talairach.auto.xfm
# -r--r--r--@ 1 satra  staff      1548 Jun  2  2011 talairach.lta
# -r--r--r--@ 1 satra  staff  32376549 Jun  2  2011 talairach.m3z
# -r--r--r--@ 1 satra  staff  26897923 Jun  2  2011 talairach.m3z.inv.x.mgz
# -r--r--r--@ 1 satra  staff  21362544 Jun  2  2011 talairach.m3z.inv.y.mgz
# -r--r--r--@ 1 satra  staff  18566247 Jun  2  2011 talairach.m3z.inv.z.mgz
# -r--r--r--@ 1 satra  staff       194 Jun  2  2011 talairach.xfm
# -r--r--r--@ 1 satra  staff     85628 Jun  2  2011 talairach_avi.log
# -r--r--r--@ 1 satra  staff     85134 Jun  2  2011 talairach_avi.log.bak
# -r--r--r--@ 1 satra  staff        92 Jun  2  2011 talairach_avi_QA.log
# -r--r--r--@ 1 satra  staff      1591 Jun  2  2011 talairach_with_skull.lta
# -r--r--r--@ 1 satra  staff       380 Jun  2  2011 talsrcimg_to_711-2C_as_mni_average_305_t4_vox2vox.txt
#
# /Applications/freesurfer/subjects/bert/mri/transforms/bak:
#
# /Applications/freesurfer/subjects/bert/scripts:
# total 2904
# -r--r--r--@ 1 satra  staff       55 Jun  2  2011 build-stamp.txt
# -r--r--r--@ 1 satra  staff       43 Jun  2  2011 csurfdir
# -r--r--r--@ 1 satra  staff      207 Jun  2  2011 ponscc.cut.log
# -r--r--r--@ 1 satra  staff     9795 Jun  2  2011 recon-all-status.log
# -r--r--r--@ 1 satra  staff    20085 Jun  2  2011 recon-all.cmd
# -r--r--r--@ 1 satra  staff      366 Jun  2  2011 recon-all.done
# -r--r--r--@ 1 satra  staff     5304 Jun  2  2011 recon-all.env
# -r--r--r--@ 1 satra  staff     4158 Jun  2  2011 recon-all.env.bak
# -r-xr-xr-x@ 1 satra  staff   239582 Jun  2  2011 recon-all.local-copy*
# -r--r--r--@ 1 satra  staff  1179555 Jun  2  2011 recon-all.log
#
# /Applications/freesurfer/subjects/bert/src:
#
# /Applications/freesurfer/subjects/bert/stats:
# total 304
# -r--r--r--@ 1 satra  staff   8512 Jun  2  2011 aseg.stats
# -r--r--r--@ 1 satra  staff   3380 Jun  2  2011 lh.BA.stats
# -r--r--r--@ 1 satra  staff  10359 Jun  2  2011 lh.aparc.a2009s.stats
# -r--r--r--@ 1 satra  staff   5931 Jun  2  2011 lh.aparc.stats
# -r--r--r--@ 1 satra  staff  32822 Jun  2  2011 lh.curv.stats
# -r--r--r--@ 1 satra  staff   2202 Jun  2  2011 lh.entorhinal_exvivo.stats
# -r--r--r--@ 1 satra  staff   3378 Jun  2  2011 rh.BA.stats
# -r--r--r--@ 1 satra  staff  10361 Jun  2  2011 rh.aparc.a2009s.stats
# -r--r--r--@ 1 satra  staff   5933 Jun  2  2011 rh.aparc.stats
# -r--r--r--@ 1 satra  staff  32818 Jun  2  2011 rh.curv.stats
# -r--r--r--@ 1 satra  staff   2200 Jun  2  2011 rh.entorhinal_exvivo.stats
# -r--r--r--@ 1 satra  staff  11456 Jun  2  2011 wmparc.stats
#
# /Applications/freesurfer/subjects/bert/surf:
# total 254512
# -r--r--r--@ 1 satra  staff   532819 Jun  2  2011 lh.area
# -r--r--r--@ 1 satra  staff   532819 Jun  2  2011 lh.area.mid
# -r--r--r--@ 1 satra  staff   532819 Jun  2  2011 lh.area.pial
# -r--r--r--@ 1 satra  staff   532819 Jun  2  2011 lh.avg_curv
# -r--r--r--@ 1 satra  staff   532819 Jun  2  2011 lh.curv
# -r--r--r--@ 1 satra  staff   532819 Jun  2  2011 lh.curv.pial
# -r--r--r--@ 1 satra  staff   539391 Jun  2  2011 lh.defect_borders
# -r--r--r--@ 1 satra  staff   539391 Jun  2  2011 lh.defect_chull
# -r--r--r--@ 1 satra  staff   539391 Jun  2  2011 lh.defect_labels
# -r--r--r--@ 1 satra  staff  4797297 Jun  2  2011 lh.inflated
# -r--r--r--@ 1 satra  staff   532819 Jun  2  2011 lh.inflated.H
# -r--r--r--@ 1 satra  staff   532819 Jun  2  2011 lh.inflated.K
# -r--r--r--@ 1 satra  staff  4857073 Jun  2  2011 lh.inflated.nofix
# -r--r--r--@ 1 satra  staff   532819 Jun  2  2011 lh.jacobian_white
# -r--r--r--@ 1 satra  staff  4796124 Jun  2  2011 lh.orig
# -r--r--r--@ 1 satra  staff  4856272 Jun  2  2011 lh.orig.nofix
# -r--r--r--@ 1 satra  staff  4796523 Jun  2  2011 lh.pial
# -r--r--r--@ 1 satra  staff  4857473 Jun  2  2011 lh.qsphere.nofix
# -r--r--r--@ 1 satra  staff  4796920 Jun  2  2011 lh.smoothwm
# -r--r--r--@ 1 satra  staff   529395 Jun  2  2011 lh.smoothwm.BE.crv
# -r--r--r--@ 1 satra  staff   529395 Jun  2  2011 lh.smoothwm.C.crv
# -r--r--r--@ 1 satra  staff   529395 Jun  2  2011 lh.smoothwm.FI.crv
# -r--r--r--@ 1 satra  staff   529395 Jun  2  2011 lh.smoothwm.H.crv
# -r--r--r--@ 1 satra  staff   529395 Jun  2  2011 lh.smoothwm.K.crv
# -r--r--r--@ 1 satra  staff   529395 Jun  2  2011 lh.smoothwm.K1.crv
# -r--r--r--@ 1 satra  staff   529395 Jun  2  2011 lh.smoothwm.K2.crv
# -r--r--r--@ 1 satra  staff   529395 Jun  2  2011 lh.smoothwm.S.crv
# -r--r--r--@ 1 satra  staff  4856670 Jun  2  2011 lh.smoothwm.nofix
# -r--r--r--@ 1 satra  staff  4797681 Jun  2  2011 lh.sphere
# -r--r--r--@ 1 satra  staff  4798159 Jun  2  2011 lh.sphere.reg
# -r--r--r--@ 1 satra  staff   532819 Jun  2  2011 lh.sulc
# -r--r--r--@ 1 satra  staff   532819 Jun  2  2011 lh.thickness
# -r--r--r--@ 1 satra  staff   532819 Jun  2  2011 lh.volume
# -r--r--r--@ 1 satra  staff  4796528 Jun  2  2011 lh.white
# -r--r--r--@ 1 satra  staff   530291 Jun  2  2011 rh.area
# -r--r--r--@ 1 satra  staff   530291 Jun  2  2011 rh.area.mid
# -r--r--r--@ 1 satra  staff   530291 Jun  2  2011 rh.area.pial
# -r--r--r--@ 1 satra  staff   530291 Jun  2  2011 rh.avg_curv
# -r--r--r--@ 1 satra  staff   530291 Jun  2  2011 rh.curv
# -r--r--r--@ 1 satra  staff   530291 Jun  2  2011 rh.curv.pial
# -r--r--r--@ 1 satra  staff   535559 Jun  2  2011 rh.defect_borders
# -r--r--r--@ 1 satra  staff   535559 Jun  2  2011 rh.defect_chull
# -r--r--r--@ 1 satra  staff   535559 Jun  2  2011 rh.defect_labels
# -r--r--r--@ 1 satra  staff  4774545 Jun  2  2011 rh.inflated
# -r--r--r--@ 1 satra  staff   530291 Jun  2  2011 rh.inflated.H
# -r--r--r--@ 1 satra  staff   530291 Jun  2  2011 rh.inflated.K
# -r--r--r--@ 1 satra  staff  4822393 Jun  2  2011 rh.inflated.nofix
# -r--r--r--@ 1 satra  staff   530291 Jun  2  2011 rh.jacobian_white
# -r--r--r--@ 1 satra  staff  4773372 Jun  2  2011 rh.orig
# -r--r--r--@ 1 satra  staff  4821592 Jun  2  2011 rh.orig.nofix
# -r--r--r--@ 1 satra  staff  4773771 Jun  2  2011 rh.pial
# -r--r--r--@ 1 satra  staff  4822793 Jun  2  2011 rh.qsphere.nofix
# -r--r--r--@ 1 satra  staff  4774168 Jun  2  2011 rh.smoothwm
# -r--r--r--@ 1 satra  staff   528107 Jun  2  2011 rh.smoothwm.BE.crv
# -r--r--r--@ 1 satra  staff   528107 Jun  2  2011 rh.smoothwm.C.crv
# -r--r--r--@ 1 satra  staff   528107 Jun  2  2011 rh.smoothwm.FI.crv
# -r--r--r--@ 1 satra  staff   528107 Jun  2  2011 rh.smoothwm.H.crv
# -r--r--r--@ 1 satra  staff   528107 Jun  2  2011 rh.smoothwm.K.crv
# -r--r--r--@ 1 satra  staff   528107 Jun  2  2011 rh.smoothwm.K1.crv
# -r--r--r--@ 1 satra  staff   528107 Jun  2  2011 rh.smoothwm.K2.crv
# -r--r--r--@ 1 satra  staff   528107 Jun  2  2011 rh.smoothwm.S.crv
# -r--r--r--@ 1 satra  staff  4821990 Jun  2  2011 rh.smoothwm.nofix
# -r--r--r--@ 1 satra  staff  4774929 Jun  2  2011 rh.sphere
# -r--r--r--@ 1 satra  staff  4775407 Jun  2  2011 rh.sphere.reg
# -r--r--r--@ 1 satra  staff   530291 Jun  2  2011 rh.sulc
# -r--r--r--@ 1 satra  staff   530291 Jun  2  2011 rh.thickness
# -r--r--r--@ 1 satra  staff   530291 Jun  2  2011 rh.volume
# -r--r--r--@ 1 satra  staff  4773776 Jun  2  2011 rh.white
#
# /Applications/freesurfer/subjects/bert/tmp:
#
# /Applications/freesurfer/subjects/bert/touch:
# total 496
# -r--r--r--@ 1 satra  staff   43 Jun  2  2011 aparc.a2009s2aseg.touch
# -r--r--r--@ 1 satra  staff   34 Jun  2  2011 aparc2aseg.touch
# -r--r--r--@ 1 satra  staff   26 Jun  2  2011 asegmerge.touch
# -r--r--r--@ 1 satra  staff    0 Jun  2  2011 brainmask.mgz.tkmedit.touch
# -r--r--r--@ 1 satra  staff  153 Jun  2  2011 ca_label.touch
# -r--r--r--@ 1 satra  staff  167 Jun  2  2011 ca_normalize.touch
# -r--r--r--@ 1 satra  staff  201 Jun  2  2011 ca_register.touch
# -r--r--r--@ 1 satra  staff   58 Jun  2  2011 ca_register_inv.touch
# -r--r--r--@ 1 satra  staff  182 Jun  2  2011 conform.touch
# -r--r--r--@ 1 satra  staff  122 Jun  2  2011 cortical_ribbon.touch
# -r--r--r--@ 1 satra  staff  148 Jun  2  2011 em_register.touch
# -r--r--r--@ 1 satra  staff  124 Jun  2  2011 fill.touch
# -r--r--r--@ 1 satra  staff   33 Jun  2  2011 inorm1.touch
# -r--r--r--@ 1 satra  staff   68 Jun  2  2011 inorm2.touch
# -r--r--r--@ 1 satra  staff  242 Jun  2  2011 lh.aparc.touch
# -r--r--r--@ 1 satra  staff  222 Jun  2  2011 lh.aparc2.touch
# -r--r--r--@ 1 satra  staff  160 Jun  2  2011 lh.aparcstats.touch
# -r--r--r--@ 1 satra  staff  181 Jun  2  2011 lh.aparcstats2.touch
# -r--r--r--@ 1 satra  staff  154 Jun  2  2011 lh.avgcurv.touch
# -r--r--r--@ 1 satra  staff  105 Jun  2  2011 lh.curvstats.touch
# -r--r--r--@ 1 satra  staff   68 Jun  2  2011 lh.final_surfaces.touch
# -r--r--r--@ 1 satra  staff   79 Jun  2  2011 lh.inflate1.touch
# -r--r--r--@ 1 satra  staff   76 Jun  2  2011 lh.inflate2.touch
# -r--r--r--@ 1 satra  staff   79 Jun  2  2011 lh.jacobian_white.touch
# -r--r--r--@ 1 satra  staff   68 Jun  2  2011 lh.pial_surface.touch
# -r--r--r--@ 1 satra  staff   77 Jun  2  2011 lh.qsphere.touch
# -r--r--r--@ 1 satra  staff   75 Jun  2  2011 lh.smoothwm1.touch
# -r--r--r--@ 1 satra  staff   69 Jun  2  2011 lh.smoothwm2.touch
# -r--r--r--@ 1 satra  staff   61 Jun  2  2011 lh.sphmorph.touch
# -r--r--r--@ 1 satra  staff  153 Jun  2  2011 lh.sphreg.touch
# -r--r--r--@ 1 satra  staff   52 Jun  2  2011 lh.surfvolume.touch
# -r--r--r--@ 1 satra  staff   72 Jun  2  2011 lh.tessellate.touch
# -r--r--r--@ 1 satra  staff   23 Jun  2  2011 lh.topofix.touch
# -r--r--r--@ 1 satra  staff   73 Jun  2  2011 lh.white_surface.touch
# -r--r--r--@ 1 satra  staff  975 Jun  2  2011 motion_correct.touch
# -r--r--r--@ 1 satra  staff  146 Jun  2  2011 mri_remove_neck.touch
# -r--r--r--@ 1 satra  staff    0 Jun  2  2011 nu.touch
# -r--r--r--@ 1 satra  staff  242 Jun  2  2011 rh.aparc.touch
# -r--r--r--@ 1 satra  staff  222 Jun  2  2011 rh.aparc2.touch
# -r--r--r--@ 1 satra  staff  160 Jun  2  2011 rh.aparcstats.touch
# -r--r--r--@ 1 satra  staff  181 Jun  2  2011 rh.aparcstats2.touch
# -r--r--r--@ 1 satra  staff  154 Jun  2  2011 rh.avgcurv.touch
# -r--r--r--@ 1 satra  staff  105 Jun  2  2011 rh.curvstats.touch
# -r--r--r--@ 1 satra  staff   68 Jun  2  2011 rh.final_surfaces.touch
# -r--r--r--@ 1 satra  staff   79 Jun  2  2011 rh.inflate1.touch
# -r--r--r--@ 1 satra  staff   76 Jun  2  2011 rh.inflate2.touch
# -r--r--r--@ 1 satra  staff   79 Jun  2  2011 rh.jacobian_white.touch
# -r--r--r--@ 1 satra  staff   68 Jun  2  2011 rh.pial_surface.touch
# -r--r--r--@ 1 satra  staff   77 Jun  2  2011 rh.qsphere.touch
# -r--r--r--@ 1 satra  staff   75 Jun  2  2011 rh.smoothwm1.touch
# -r--r--r--@ 1 satra  staff   69 Jun  2  2011 rh.smoothwm2.touch
# -r--r--r--@ 1 satra  staff   61 Jun  2  2011 rh.sphmorph.touch
# -r--r--r--@ 1 satra  staff  153 Jun  2  2011 rh.sphreg.touch
# -r--r--r--@ 1 satra  staff   52 Jun  2  2011 rh.surfvolume.touch
# -r--r--r--@ 1 satra  staff   72 Jun  2  2011 rh.tessellate.touch
# -r--r--r--@ 1 satra  staff   23 Jun  2  2011 rh.topofix.touch
# -r--r--r--@ 1 satra  staff   73 Jun  2  2011 rh.white_surface.touch
# -r--r--r--@ 1 satra  staff  333 Jun  2  2011 segstats.touch
# -r--r--r--@ 1 satra  staff  184 Jun  2  2011 skull.lta.touch
# -r--r--r--@ 1 satra  staff  229 Jun  2  2011 skull_strip.touch
# -r--r--r--@ 1 satra  staff   58 Jun  2  2011 talairach.touch
# -r--r--r--@ 1 satra  staff    0 Jun  2  2011 wm.mgz.tkmedit.touch
# -r--r--r--@ 1 satra  staff  314 Jun  2  2011 wmaparc.stats.touch
# -r--r--r--@ 1 satra  staff  114 Jun  2  2011 wmaparc.touch
# -r--r--r--@ 1 satra  staff   53 Jun  2  2011 wmsegment.touch
#
# /Applications/freesurfer/subjects/bert/trash:
# total 4784
# -r--r--r--@ 1 satra  staff   237416 Jun  2  2011 aseg.mgz
# -r--r--r--@ 1 satra  staff  1420829 Jun  2  2011 brainmask.mgz
# -r--r--r--@ 1 satra  staff     1708 Jun  2  2011 cc_up.lta
# -r--r--r--@ 1 satra  staff     1535 Jun  2  2011 talairach.lta
# -r--r--r--@ 1 satra  staff      192 Jun  2  2011 talairach.xfm
# -r--r--r--@ 1 satra  staff     1580 Jun  2  2011 talairach_with_skull.lta
# -r--r--r--@ 1 satra  staff   365265 Jun  2  2011 wm.mgz
# -r--r--r--@ 1 satra  staff   402629 Jun  2  2011 wm.seg.mgz

# %%
# map FreeSurfer filename parts
fs_file_map =  [('T1', [nif["nlx_inv_20090243"]]), #3d T1 weighted scan
                ('lh', [obo["UBERON_0002812"]]), #left cerebral hemisphere
                ('rh', [obo["UBERON_0002813"]]), # right cerebral hemisphere
                ('BA.', [obo["UBERON_0013529"]]), #Brodmann area
                ('BA1.', [obo["UBERON_0006099"]]), #Brodmann area 1
                ('BA2.', [obo["UBERON_0013533"]]), #Brodmann area 2
                ('BA3a.', [obo["UBERON_0006100"], #Brodmann area 3a
                           obo["FMA_74532"]]), #anterior
                ('BA3b.', [obo["UBERON_0006100"], #Brodmann area 3b
                           obo["FMA_74533"]]), #posterior
                ('BA44.', [obo["UBERON_0006481"]]), #Brodmann area 44
                ('BA45.', [obo["UBERON_0006482"]]), #Brodmann area 45
                ('BA4a.', [obo["UBERON_0013535"], #Brodmann area 4a
                           obo["FMA_74532"]]), #anterior
                ('BA4a.', [obo["UBERON_0013535"], #Brodmann area 4p
                           obo["FMA_74533"]]), #posterior
                ('BA6.', [obo["UBERON_0006472"]]), #Brodmann area 6
                ('V1.', [obo["UBERON_0002436"]]),
                ('V2.', [obo["UBERON_0006473"]]),
                ('MT', [fs["MT_area"]]),
                ('entorhinal', [obo["UBERON_0002728"]]),
                ('exvivo', [fs["exvivo"]]),
                ('label', [fs["label_file"]]),
                ('annot', [fs["annotation_file"]]),
                ('cortex', [obo["UBERON_0000956"]]),
                ('.stats', [fs["statistic_file"]]),
                ('aparc.annot', [fs["default_parcellation"]]),
                ('aparc.a2009s', [fs["a2009s_parcellation"]]),
                ('.ctab', [fs["color_table"]]),
               ]

ignore_list = ['bak', 'src', 'tmp', 'trash']

# %%
def create_entity(graph, fs_subject_id, filepath):
    """ Create a PROV entity for a file in a FreeSurfer directory
    """
    # identify FreeSurfer terms based on directory and file names
    _, filename = os.path.split(filepath)
    relpath = filepath.split(fs_subject_id)[1].lstrip(os.path.sep)
    fstypes = relpath.split('/')[:-1]
    additional_types = relpath.split('/')[-1].split('.')
    
    file_md5_hash = hash_infile(filepath)
    if file_md5_hash is None:
        print fullpath

    url = "file://%s%s" % (getfqdn(), filepath)
    url_get = "http://computor.mit.edu:10101/file?file_uri=%s" % url
    # build a NI-DM object 
    obj_attr = [(prov.PROV["label"], "%s:%s" % ('.'.join(fstypes), '.'.join(additional_types))),
                (prov.PROV["label"], "%s" % filename),
                (fs["relative_path"], "%s" % relpath),
                (prov.PROV["location"], prov.Literal(url, prov.XSD["anyURI"])),
                (obo["MS_1000568"], "%s" % file_md5_hash),
               ]

    for key, uris in fs_file_map:
        if key in filename:
            obj_attr.append((prov.PROV["label"], key.rstrip('.')))
            for uri in uris:
                obj_attr.append((prov.PROV["type"], uri))
    id = md5.new(fs_subject_id + relpath + file_md5_hash).hexdigest()
    return graph.entity(fs['e/' + id], obj_attr)
    #return id

# %%
g = prov.ProvBundle()
e1 = create_entity(g, "bert", "/Applications/freesurfer/subjects/bert/mri/T1.mgz")

# %%
id = e1.get_identifier()
print e1.get_provn()
# Out:
# entity(fs:e/1cb78d63583c319e68646a4fa5d2d68e, [prov:label="mri:T1.mgz", prov:label="T1.mgz", fs:relative_path="mri/T1.mgz", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/mri/T1.mgz" %% xsd:anyURI, obo:MS_1000568="9ee09dc2722fe9884e5ced91b6393ea4", prov:label="T1", prov:type='nif:nlx_inv_20090243'])

# %% [markdown]
# ### Terms introduced
#
#     - relative_path
#     - file
#     - md5sum
#     - aparc, a2005s, a2009s, exvivo
#     - statistics

# %% [markdown]
# ### Define a function that manages creating a NI-DM FreeSurfer object

# %%
def encode_fs_directory(g, basedir, project_id, subject_id, n_items=100000):
    """ Convert a FreeSurfer directory to a PROV graph
    """
    # directory collection/catalog
    collection_hash = md5.new(project_id + ':' + subject_id).hexdigest()
    fsdir_collection = g.collection(fs[collection_hash])
    fsdir_collection.add_extra_attributes({prov.PROV['type']: fs['directory'],
                                           fs['subject_id']: subject_id})
    i = 0;
    for dirpath, dirnames, filenames in os.walk(os.path.realpath(basedir)):
        for filename in sorted(filenames):
            if filename.startswith('.'):
                continue
            i +=1 
            if i > n_items:
                break
            file2encode = os.path.realpath(os.path.join(dirpath, filename))
            if not os.path.isfile(file2encode):
                print "%s not a file" % file2encode
                continue
            ignore_key_found = False
            for key in ignore_list:
                if key in file2encode:
                    ignore_key_found = True
                    continue
            if ignore_key_found:
                continue
            try:
                entity = create_entity(g, subject_id, file2encode)
                g.hadMember(fsdir_collection, entity.get_identifier())
            except IOError, e:
                print e
    return g

# %% [markdown]
# ### Example of generating a NI-DM FreeSurfer Object
#
# This example demonstrates the conversion from [PROV Notation](http://www.w3.org/TR/prov-n/) to RDF using the [ProvToolBox](https://github.com/lucmoreau/ProvToolbox), which provides a command line utility for serializing PROV to different syntaxes.

# %%
# location of FreeSurfer $SUBJECTS_DIR
basedir = '/Applications/freesurfer/subjects/bert'
subject_id = 'bert'
project_id = 'nidm'
filename = 'bert.provn'

from subprocess import Popen, PIPE

# location of the ProvToolBox commandline conversion utility
pc = '/mindhive/gablab/satra/ProvToolbox/toolbox/target/appassembler/bin/provconvert'
graph = prov.ProvBundle()
graph.add_namespace(foaf)
graph.add_namespace(dcterms)
graph.add_namespace(fs)
graph.add_namespace(nidm)
graph.add_namespace(obo)
graph.add_namespace(nif)

graph = encode_fs_directory(graph, basedir, project_id, subject_id)
with open(filename, 'wt') as fp:
    fp.writelines(graph.get_provn())
#o, e = Popen('%s -infile %s -outfile %s.ttl' % (pc, filename, filename), 
#             stdout=PIPE, stderr=PIPE, shell=True).communicate()

# %%
cat bert.provn
# Out:
# document
#   prefix foaf <http://xmlns.com/foaf/0.1/>
#   prefix obo <http://purl.obolibrary.org/obo/>
#   prefix fs <http://surfer.nmr.mgh.harvard.edu/fswiki/terms/0.1/>
#   prefix nif <http://neurolex.org/wiki/>
#   prefix nidm <http://nidm.nidash.org/terms/0.1/>
#   prefix dcterms <http://purl.org/dc/terms/>
#
#   entity(fs:4c735fc66b5e12cdd321d6ed64394c84, [prov:type='prov:Collection', prov:type='fs:directory', fs:subject_id="bert"])
#   entity(fs:e/4f373ea0795db74b259f9796722a157b, [prov:label="label:BA.ctab", prov:label="BA.ctab", fs:relative_path="label/BA.ctab", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/label/BA.ctab" %% xsd:anyURI, obo:MS_1000568="b4f7d3570bb5606e5bad4accc1009f1c", prov:label="BA", prov:type='obo:UBERON_0013529', prov:label=".ctab", prov:type='fs:color_table'])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/4f373ea0795db74b259f9796722a157b)
#   entity(fs:e/ddbbb0eb79eb892a2273e23009f06e14, [prov:label="label:aparc.annot.a2009s.ctab", prov:label="aparc.annot.a2009s.ctab", fs:relative_path="label/aparc.annot.a2009s.ctab", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/label/aparc.annot.a2009s.ctab" %% xsd:anyURI, obo:MS_1000568="cf32a567746bf18e8b52c323dc152570", prov:label="annot", prov:type='fs:annotation_file', prov:label="aparc.annot", prov:type='fs:default_parcellation', prov:label=".ctab", prov:type='fs:color_table'])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/ddbbb0eb79eb892a2273e23009f06e14)
#   entity(fs:e/9384b407bb4a4f378d0cae474e67659f, [prov:label="label:aparc.annot.ctab", prov:label="aparc.annot.ctab", fs:relative_path="label/aparc.annot.ctab", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/label/aparc.annot.ctab" %% xsd:anyURI, obo:MS_1000568="757e7e27742ae27d720f8fc37fbdaf36", prov:label="annot", prov:type='fs:annotation_file', prov:label="aparc.annot", prov:type='fs:default_parcellation', prov:label=".ctab", prov:type='fs:color_table'])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/9384b407bb4a4f378d0cae474e67659f)
#   entity(fs:e/6e478200c09652395af2c1c413af361c, [prov:label="label:lh.BA.annot", prov:label="lh.BA.annot", fs:relative_path="label/lh.BA.annot", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/label/lh.BA.annot" %% xsd:anyURI, obo:MS_1000568="447a7298759bd53a940411ac25b186c4", prov:label="lh", prov:type='obo:UBERON_0002812', prov:label="BA", prov:type='obo:UBERON_0013529', prov:label="annot", prov:type='fs:annotation_file'])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/6e478200c09652395af2c1c413af361c)
#   entity(fs:e/1647479a605beaa9a20f8b336148c581, [prov:label="label:lh.BA1.label", prov:label="lh.BA1.label", fs:relative_path="label/lh.BA1.label", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/label/lh.BA1.label" %% xsd:anyURI, obo:MS_1000568="eea0a0c22b658197039e7d27d0442b75", prov:label="lh", prov:type='obo:UBERON_0002812', prov:label="BA1", prov:type='obo:UBERON_0006099', prov:label="label", prov:type='fs:label_file'])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/1647479a605beaa9a20f8b336148c581)
#   entity(fs:e/e4ccf963d8887dd761b095422e7448b1, [prov:label="label:lh.BA2.label", prov:label="lh.BA2.label", fs:relative_path="label/lh.BA2.label", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/label/lh.BA2.label" %% xsd:anyURI, obo:MS_1000568="f9be0afc2b3d7c0cce6fd8edd851ef34", prov:label="lh", prov:type='obo:UBERON_0002812', prov:label="BA2", prov:type='obo:UBERON_0013533', prov:label="label", prov:type='fs:label_file'])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/e4ccf963d8887dd761b095422e7448b1)
#   entity(fs:e/fff068dd3a66130e7c310b38d489bc1a, [prov:label="label:lh.BA3a.label", prov:label="lh.BA3a.label", fs:relative_path="label/lh.BA3a.label", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/label/lh.BA3a.label" %% xsd:anyURI, obo:MS_1000568="6f0c605b869554bf8b80fddf41739802", prov:label="lh", prov:type='obo:UBERON_0002812', prov:label="BA3a", prov:type='obo:UBERON_0006100', prov:type='obo:FMA_74532', prov:label="label", prov:type='fs:label_file'])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/fff068dd3a66130e7c310b38d489bc1a)
#   entity(fs:e/96a6c7b37c3b2af5326b4a2896011261, [prov:label="label:lh.BA3b.label", prov:label="lh.BA3b.label", fs:relative_path="label/lh.BA3b.label", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/label/lh.BA3b.label" %% xsd:anyURI, obo:MS_1000568="e8bd38624bf683d9d390a924a5ad88b1", prov:label="lh", prov:type='obo:UBERON_0002812', prov:label="BA3b", prov:type='obo:UBERON_0006100', prov:type='obo:FMA_74533', prov:label="label", prov:type='fs:label_file'])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/96a6c7b37c3b2af5326b4a2896011261)
#   entity(fs:e/238c3b5631dea50afc475b1f83610a7c, [prov:label="label:lh.BA44.label", prov:label="lh.BA44.label", fs:relative_path="label/lh.BA44.label", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/label/lh.BA44.label" %% xsd:anyURI, obo:MS_1000568="e8dc72ba57ed8097d22aa7469bf47415", prov:label="lh", prov:type='obo:UBERON_0002812', prov:label="BA44", prov:type='obo:UBERON_0006481', prov:label="label", prov:type='fs:label_file'])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/238c3b5631dea50afc475b1f83610a7c)
#   entity(fs:e/bd12cce951cb818d03f37c4b3149ce5e, [prov:label="label:lh.BA45.label", prov:label="lh.BA45.label", fs:relative_path="label/lh.BA45.label", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/label/lh.BA45.label" %% xsd:anyURI, obo:MS_1000568="2914548fdecb9e2c5e4c035be55e27bf", prov:label="lh", prov:type='obo:UBERON_0002812', prov:label="BA45", prov:type='obo:UBERON_0006482', prov:label="label", prov:type='fs:label_file'])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/bd12cce951cb818d03f37c4b3149ce5e)
#   entity(fs:e/ace0a6e985ee1ab0f2a5cd8d05fa3652, [prov:label="label:lh.BA4a.label", prov:label="lh.BA4a.label", fs:relative_path="label/lh.BA4a.label", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/label/lh.BA4a.label" %% xsd:anyURI, obo:MS_1000568="89785b04b5809aa5266d5ed2b45ad94e", prov:label="lh", prov:type='obo:UBERON_0002812', prov:label="BA4a", prov:type='obo:UBERON_0013535', prov:type='obo:FMA_74532', prov:label="BA4a", prov:type='obo:UBERON_0013535', prov:type='obo:FMA_74533', prov:label="label", prov:type='fs:label_file'])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/ace0a6e985ee1ab0f2a5cd8d05fa3652)
#   entity(fs:e/273cc9bcf0d4208b8e0372022b6b1ea7, [prov:label="label:lh.BA4p.label", prov:label="lh.BA4p.label", fs:relative_path="label/lh.BA4p.label", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/label/lh.BA4p.label" %% xsd:anyURI, obo:MS_1000568="337858b01c296cc01d0acbfdaf530e47", prov:label="lh", prov:type='obo:UBERON_0002812', prov:label="label", prov:type='fs:label_file'])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/273cc9bcf0d4208b8e0372022b6b1ea7)
#   entity(fs:e/ecc5f86fe3fa522c5ce33abd2a6c37ef, [prov:label="label:lh.BA6.label", prov:label="lh.BA6.label", fs:relative_path="label/lh.BA6.label", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/label/lh.BA6.label" %% xsd:anyURI, obo:MS_1000568="296d0502ee09f5e20dbc8f37bfccf48e", prov:label="lh", prov:type='obo:UBERON_0002812', prov:label="BA6", prov:type='obo:UBERON_0006472', prov:label="label", prov:type='fs:label_file'])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/ecc5f86fe3fa522c5ce33abd2a6c37ef)
#   entity(fs:e/9ecfdc7e286e1ff3072d4488c388c658, [prov:label="label:lh.MT.label", prov:label="lh.MT.label", fs:relative_path="label/lh.MT.label", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/label/lh.MT.label" %% xsd:anyURI, obo:MS_1000568="298ed9dbf6f89bf5c64add421d9a111b", prov:label="lh", prov:type='obo:UBERON_0002812', prov:label="MT", prov:type='fs:MT area', prov:label="label", prov:type='fs:label_file'])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/9ecfdc7e286e1ff3072d4488c388c658)
#   entity(fs:e/98fa7413da06602c1cac19ec2f599a0c, [prov:label="label:lh.V1.label", prov:label="lh.V1.label", fs:relative_path="label/lh.V1.label", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/label/lh.V1.label" %% xsd:anyURI, obo:MS_1000568="245a981fe8d4751d6ce7f9d69483d325", prov:label="lh", prov:type='obo:UBERON_0002812', prov:label="V1", prov:type='obo:UBERON_0002436', prov:label="label", prov:type='fs:label_file'])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/98fa7413da06602c1cac19ec2f599a0c)
#   entity(fs:e/670cc3bb902867cec89049c0b2d7b7cd, [prov:label="label:lh.V2.label", prov:label="lh.V2.label", fs:relative_path="label/lh.V2.label", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/label/lh.V2.label" %% xsd:anyURI, obo:MS_1000568="ac662347434f52d2bd4635ec10b7e0dc", prov:label="lh", prov:type='obo:UBERON_0002812', prov:label="V2", prov:type='obo:UBERON_0006473', prov:label="label", prov:type='fs:label_file'])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/670cc3bb902867cec89049c0b2d7b7cd)
#   entity(fs:e/a0e576b34fccba0ddea2f56ca46d2a78, [prov:label="label:lh.aparc.a2009s.annot", prov:label="lh.aparc.a2009s.annot", fs:relative_path="label/lh.aparc.a2009s.annot", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/label/lh.aparc.a2009s.annot" %% xsd:anyURI, obo:MS_1000568="ff44bb467ea95d819645fac1131add6e", prov:label="lh", prov:type='obo:UBERON_0002812', prov:label="annot", prov:type='fs:annotation_file', prov:label="aparc.a2009s", prov:type='fs:a2009s_parcellation'])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/a0e576b34fccba0ddea2f56ca46d2a78)
#   entity(fs:e/c7e18a791ade78beafcc86e3442435e9, [prov:label="label:lh.aparc.annot", prov:label="lh.aparc.annot", fs:relative_path="label/lh.aparc.annot", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/label/lh.aparc.annot" %% xsd:anyURI, obo:MS_1000568="53efa1330df228eb5ed6b736a76be4d4", prov:label="lh", prov:type='obo:UBERON_0002812', prov:label="annot", prov:type='fs:annotation_file', prov:label="aparc.annot", prov:type='fs:default_parcellation'])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/c7e18a791ade78beafcc86e3442435e9)
#   entity(fs:e/d181985ff91d722572ae14b2eefb779a, [prov:label="label:lh.cortex.label", prov:label="lh.cortex.label", fs:relative_path="label/lh.cortex.label", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/label/lh.cortex.label" %% xsd:anyURI, obo:MS_1000568="53609d4375881330280e4dc6a5e1e0a3", prov:label="lh", prov:type='obo:UBERON_0002812', prov:label="label", prov:type='fs:label_file', prov:label="cortex", prov:type='obo:UBERON_0000956'])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/d181985ff91d722572ae14b2eefb779a)
#   entity(fs:e/1faf5cbfb0ac2cdd7fccf5fbc8470c78, [prov:label="label:lh.entorhinal_exvivo.label", prov:label="lh.entorhinal_exvivo.label", fs:relative_path="label/lh.entorhinal_exvivo.label", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/label/lh.entorhinal_exvivo.label" %% xsd:anyURI, obo:MS_1000568="0e23f4d5885f588aa9283b94af63048a", prov:label="lh", prov:type='obo:UBERON_0002812', prov:label="rh", prov:type='obo:UBERON_0002813', prov:label="entorhinal", prov:type='obo:UBERON_0002728', prov:label="exvivo", prov:type='fs:exvivo', prov:label="label", prov:type='fs:label_file'])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/1faf5cbfb0ac2cdd7fccf5fbc8470c78)
#   entity(fs:e/40db8920901587f529e3f0fd4333c93c, [prov:label="label:rh.BA.annot", prov:label="rh.BA.annot", fs:relative_path="label/rh.BA.annot", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/label/rh.BA.annot" %% xsd:anyURI, obo:MS_1000568="c213d434573fe31344634efe79bb15e5", prov:label="rh", prov:type='obo:UBERON_0002813', prov:label="BA", prov:type='obo:UBERON_0013529', prov:label="annot", prov:type='fs:annotation_file'])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/40db8920901587f529e3f0fd4333c93c)
#   entity(fs:e/3440510e9d73fe73426921856cb3905b, [prov:label="label:rh.BA1.label", prov:label="rh.BA1.label", fs:relative_path="label/rh.BA1.label", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/label/rh.BA1.label" %% xsd:anyURI, obo:MS_1000568="29d6fce600ab74493a9649b72caed720", prov:label="rh", prov:type='obo:UBERON_0002813', prov:label="BA1", prov:type='obo:UBERON_0006099', prov:label="label", prov:type='fs:label_file'])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/3440510e9d73fe73426921856cb3905b)
#   entity(fs:e/5ad800c5fd517e8dfd255cd9d96c1ecd, [prov:label="label:rh.BA2.label", prov:label="rh.BA2.label", fs:relative_path="label/rh.BA2.label", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/label/rh.BA2.label" %% xsd:anyURI, obo:MS_1000568="05568178613843113796917fa32f3fef", prov:label="rh", prov:type='obo:UBERON_0002813', prov:label="BA2", prov:type='obo:UBERON_0013533', prov:label="label", prov:type='fs:label_file'])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/5ad800c5fd517e8dfd255cd9d96c1ecd)
#   entity(fs:e/47e53669f046ec5ef2cebfa43fee711c, [prov:label="label:rh.BA3a.label", prov:label="rh.BA3a.label", fs:relative_path="label/rh.BA3a.label", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/label/rh.BA3a.label" %% xsd:anyURI, obo:MS_1000568="88c47fba4c3c3a6710ef3c149138dfd4", prov:label="rh", prov:type='obo:UBERON_0002813', prov:label="BA3a", prov:type='obo:UBERON_0006100', prov:type='obo:FMA_74532', prov:label="label", prov:type='fs:label_file'])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/47e53669f046ec5ef2cebfa43fee711c)
#   entity(fs:e/06b16c5f4cfda9f8fbc1a283de1ceeb9, [prov:label="label:rh.BA3b.label", prov:label="rh.BA3b.label", fs:relative_path="label/rh.BA3b.label", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/label/rh.BA3b.label" %% xsd:anyURI, obo:MS_1000568="6dc61432b8c4c841c40bff1d877a656f", prov:label="rh", prov:type='obo:UBERON_0002813', prov:label="BA3b", prov:type='obo:UBERON_0006100', prov:type='obo:FMA_74533', prov:label="label", prov:type='fs:label_file'])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/06b16c5f4cfda9f8fbc1a283de1ceeb9)
#   entity(fs:e/c9bf03e447abf3cca0e9bef329f7e972, [prov:label="label:rh.BA44.label", prov:label="rh.BA44.label", fs:relative_path="label/rh.BA44.label", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/label/rh.BA44.label" %% xsd:anyURI, obo:MS_1000568="fbe3be4211552d3e816588fe2b1c816c", prov:label="rh", prov:type='obo:UBERON_0002813', prov:label="BA44", prov:type='obo:UBERON_0006481', prov:label="label", prov:type='fs:label_file'])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/c9bf03e447abf3cca0e9bef329f7e972)
#   entity(fs:e/f3431fdce9424c32d3dfa7000e41359c, [prov:label="label:rh.BA45.label", prov:label="rh.BA45.label", fs:relative_path="label/rh.BA45.label", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/label/rh.BA45.label" %% xsd:anyURI, obo:MS_1000568="16baa40cae0bbd021c4d986843c217ab", prov:label="rh", prov:type='obo:UBERON_0002813', prov:label="BA45", prov:type='obo:UBERON_0006482', prov:label="label", prov:type='fs:label_file'])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/f3431fdce9424c32d3dfa7000e41359c)
#   entity(fs:e/e43d5f753309599e08178cb85840e161, [prov:label="label:rh.BA4a.label", prov:label="rh.BA4a.label", fs:relative_path="label/rh.BA4a.label", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/label/rh.BA4a.label" %% xsd:anyURI, obo:MS_1000568="3b235053990bcdf6fe67ce94a5e4f6d7", prov:label="rh", prov:type='obo:UBERON_0002813', prov:label="BA4a", prov:type='obo:UBERON_0013535', prov:type='obo:FMA_74532', prov:label="BA4a", prov:type='obo:UBERON_0013535', prov:type='obo:FMA_74533', prov:label="label", prov:type='fs:label_file'])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/e43d5f753309599e08178cb85840e161)
#   entity(fs:e/83a5269e7bc3b9f5c544f8a66afb4fd4, [prov:label="label:rh.BA4p.label", prov:label="rh.BA4p.label", fs:relative_path="label/rh.BA4p.label", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/label/rh.BA4p.label" %% xsd:anyURI, obo:MS_1000568="618eee913baf4b103d72961bb568107b", prov:label="rh", prov:type='obo:UBERON_0002813', prov:label="label", prov:type='fs:label_file'])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/83a5269e7bc3b9f5c544f8a66afb4fd4)
#   entity(fs:e/e237836f1ccaa0630872e4afb3893ce0, [prov:label="label:rh.BA6.label", prov:label="rh.BA6.label", fs:relative_path="label/rh.BA6.label", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/label/rh.BA6.label" %% xsd:anyURI, obo:MS_1000568="92a2aee9d5ce643b78e31c761a8b26c6", prov:label="rh", prov:type='obo:UBERON_0002813', prov:label="BA6", prov:type='obo:UBERON_0006472', prov:label="label", prov:type='fs:label_file'])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/e237836f1ccaa0630872e4afb3893ce0)
#   entity(fs:e/2e666b3610aab62dad14c304c682133a, [prov:label="label:rh.MT.label", prov:label="rh.MT.label", fs:relative_path="label/rh.MT.label", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/label/rh.MT.label" %% xsd:anyURI, obo:MS_1000568="66972b7ed340a49cfce91ebace647a22", prov:label="rh", prov:type='obo:UBERON_0002813', prov:label="MT", prov:type='fs:MT area', prov:label="label", prov:type='fs:label_file'])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/2e666b3610aab62dad14c304c682133a)
#   entity(fs:e/cc6afec7beedd24d00ec77a960266a6d, [prov:label="label:rh.V1.label", prov:label="rh.V1.label", fs:relative_path="label/rh.V1.label", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/label/rh.V1.label" %% xsd:anyURI, obo:MS_1000568="bcc4588e4ec1ca7948dc7d215c54ba14", prov:label="rh", prov:type='obo:UBERON_0002813', prov:label="V1", prov:type='obo:UBERON_0002436', prov:label="label", prov:type='fs:label_file'])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/cc6afec7beedd24d00ec77a960266a6d)
#   entity(fs:e/0c5c8dbfcb44279530bca5c70cec31a3, [prov:label="label:rh.V2.label", prov:label="rh.V2.label", fs:relative_path="label/rh.V2.label", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/label/rh.V2.label" %% xsd:anyURI, obo:MS_1000568="238073c12deacb2b86effba41b16800b", prov:label="rh", prov:type='obo:UBERON_0002813', prov:label="V2", prov:type='obo:UBERON_0006473', prov:label="label", prov:type='fs:label_file'])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/0c5c8dbfcb44279530bca5c70cec31a3)
#   entity(fs:e/34521ed78bfbb8ccba0fc56c7731ceb4, [prov:label="label:rh.aparc.a2009s.annot", prov:label="rh.aparc.a2009s.annot", fs:relative_path="label/rh.aparc.a2009s.annot", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/label/rh.aparc.a2009s.annot" %% xsd:anyURI, obo:MS_1000568="41a363a7f9b5747ad58c4906d5dffcaf", prov:label="rh", prov:type='obo:UBERON_0002813', prov:label="annot", prov:type='fs:annotation_file', prov:label="aparc.a2009s", prov:type='fs:a2009s_parcellation'])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/34521ed78bfbb8ccba0fc56c7731ceb4)
#   entity(fs:e/ee43e48c9a26d523cca05e0b81a52f4b, [prov:label="label:rh.aparc.annot", prov:label="rh.aparc.annot", fs:relative_path="label/rh.aparc.annot", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/label/rh.aparc.annot" %% xsd:anyURI, obo:MS_1000568="bcd8a069d3d63e45c95c696fdfae951b", prov:label="rh", prov:type='obo:UBERON_0002813', prov:label="annot", prov:type='fs:annotation_file', prov:label="aparc.annot", prov:type='fs:default_parcellation'])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/ee43e48c9a26d523cca05e0b81a52f4b)
#   entity(fs:e/6ff119b9eabea5033778dffdd2f1b445, [prov:label="label:rh.cortex.label", prov:label="rh.cortex.label", fs:relative_path="label/rh.cortex.label", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/label/rh.cortex.label" %% xsd:anyURI, obo:MS_1000568="9fc9ccf7f26190fbbfa39807f15f1499", prov:label="rh", prov:type='obo:UBERON_0002813', prov:label="label", prov:type='fs:label_file', prov:label="cortex", prov:type='obo:UBERON_0000956'])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/6ff119b9eabea5033778dffdd2f1b445)
#   entity(fs:e/d21f7a0e83a410456c8b0e7e6fe17e99, [prov:label="label:rh.entorhinal_exvivo.label", prov:label="rh.entorhinal_exvivo.label", fs:relative_path="label/rh.entorhinal_exvivo.label", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/label/rh.entorhinal_exvivo.label" %% xsd:anyURI, obo:MS_1000568="a521d31d70427c10666e262786603971", prov:label="rh", prov:type='obo:UBERON_0002813', prov:label="entorhinal", prov:type='obo:UBERON_0002728', prov:label="exvivo", prov:type='fs:exvivo', prov:label="label", prov:type='fs:label_file'])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/d21f7a0e83a410456c8b0e7e6fe17e99)
#   entity(fs:e/1cb78d63583c319e68646a4fa5d2d68e, [prov:label="mri:T1.mgz", prov:label="T1.mgz", fs:relative_path="mri/T1.mgz", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/mri/T1.mgz" %% xsd:anyURI, obo:MS_1000568="9ee09dc2722fe9884e5ced91b6393ea4", prov:label="T1", prov:type='nif:nlx_inv_20090243'])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/1cb78d63583c319e68646a4fa5d2d68e)
#   entity(fs:e/25e11c0685c1aa5ff7b49bacf9851b83, [prov:label="mri:aparc+aseg.mgz", prov:label="aparc+aseg.mgz", fs:relative_path="mri/aparc+aseg.mgz", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/mri/aparc+aseg.mgz" %% xsd:anyURI, obo:MS_1000568="fbbb676093b067671b81151d4f3fe8ec"])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/25e11c0685c1aa5ff7b49bacf9851b83)
#   entity(fs:e/0a2c9f4fc03af5d6e3f1512d8559752d, [prov:label="mri:aparc.a2009s+aseg.mgz", prov:label="aparc.a2009s+aseg.mgz", fs:relative_path="mri/aparc.a2009s+aseg.mgz", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/mri/aparc.a2009s+aseg.mgz" %% xsd:anyURI, obo:MS_1000568="91d939e73ac3a1716ca4846e5a88189e", prov:label="aparc.a2009s", prov:type='fs:a2009s_parcellation'])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/0a2c9f4fc03af5d6e3f1512d8559752d)
#   entity(fs:e/883f217ec1a45dac8c5329790d5ae178, [prov:label="mri:aseg.auto.mgz", prov:label="aseg.auto.mgz", fs:relative_path="mri/aseg.auto.mgz", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/mri/aseg.auto.mgz" %% xsd:anyURI, obo:MS_1000568="cc0e469b1a511ed5cde657aef32996b8"])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/883f217ec1a45dac8c5329790d5ae178)
#   entity(fs:e/7ae3900b34f56de6448c499b02049cc1, [prov:label="mri:aseg.auto_noCCseg.label_intensities.txt", prov:label="aseg.auto_noCCseg.label_intensities.txt", fs:relative_path="mri/aseg.auto_noCCseg.label_intensities.txt", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/mri/aseg.auto_noCCseg.label_intensities.txt" %% xsd:anyURI, obo:MS_1000568="6541f5729dbad96b34833f7c01809b38", prov:label="label", prov:type='fs:label_file'])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/7ae3900b34f56de6448c499b02049cc1)
#   entity(fs:e/18a1151864219a5f81f7b0fabbff6d63, [prov:label="mri:aseg.auto_noCCseg.mgz", prov:label="aseg.auto_noCCseg.mgz", fs:relative_path="mri/aseg.auto_noCCseg.mgz", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/mri/aseg.auto_noCCseg.mgz" %% xsd:anyURI, obo:MS_1000568="b91f3d7e65a630469e7ea80ebcb2b53f"])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/18a1151864219a5f81f7b0fabbff6d63)
#   entity(fs:e/d62a54567a6484a81728913059a80786, [prov:label="mri:aseg.mgz", prov:label="aseg.mgz", fs:relative_path="mri/aseg.mgz", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/mri/aseg.mgz" %% xsd:anyURI, obo:MS_1000568="cc0e469b1a511ed5cde657aef32996b8"])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/d62a54567a6484a81728913059a80786)
#   entity(fs:e/3f2d8123db170fdd7cecdfa510553f50, [prov:label="mri:brain.finalsurfs.mgz", prov:label="brain.finalsurfs.mgz", fs:relative_path="mri/brain.finalsurfs.mgz", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/mri/brain.finalsurfs.mgz" %% xsd:anyURI, obo:MS_1000568="30362eb636800feca7ce300d0291f7d5"])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/3f2d8123db170fdd7cecdfa510553f50)
#   entity(fs:e/394489d6e425dd730aa19f6a08b2a924, [prov:label="mri:brain.mgz", prov:label="brain.mgz", fs:relative_path="mri/brain.mgz", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/mri/brain.mgz" %% xsd:anyURI, obo:MS_1000568="7df4399241263d84811ae7bf0d907a63"])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/394489d6e425dd730aa19f6a08b2a924)
#   entity(fs:e/cc1dfeb964c44d0c8274cf260c71f903, [prov:label="mri:brainmask.auto.mgz", prov:label="brainmask.auto.mgz", fs:relative_path="mri/brainmask.auto.mgz", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/mri/brainmask.auto.mgz" %% xsd:anyURI, obo:MS_1000568="9f7ef59ef06a7897265621022356f874"])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/cc1dfeb964c44d0c8274cf260c71f903)
#   entity(fs:e/7964e43cada02e1c0c3b2368545467fe, [prov:label="mri:brainmask.gcuts.mgz", prov:label="brainmask.gcuts.mgz", fs:relative_path="mri/brainmask.gcuts.mgz", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/mri/brainmask.gcuts.mgz" %% xsd:anyURI, obo:MS_1000568="9eb5ca8cecd738b19bd5ea2506210bb8"])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/7964e43cada02e1c0c3b2368545467fe)
#   entity(fs:e/2e8c08c04bdf0c7f692610f0adc31b7c, [prov:label="mri:brainmask.mgz", prov:label="brainmask.mgz", fs:relative_path="mri/brainmask.mgz", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/mri/brainmask.mgz" %% xsd:anyURI, obo:MS_1000568="3303635d79a2fb55421a6e56d4d796e4"])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/2e8c08c04bdf0c7f692610f0adc31b7c)
#   entity(fs:e/d7ca8cf3414f2467da39a1e7b89f53df, [prov:label="mri:ctrl_pts.mgz", prov:label="ctrl_pts.mgz", fs:relative_path="mri/ctrl_pts.mgz", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/mri/ctrl_pts.mgz" %% xsd:anyURI, obo:MS_1000568="5a6a0dbaa9064058ae51402f4948203d"])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/d7ca8cf3414f2467da39a1e7b89f53df)
#   entity(fs:e/4e1c6bc6deedd326a99e0e9d15ba7560, [prov:label="mri:filled.mgz", prov:label="filled.mgz", fs:relative_path="mri/filled.mgz", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/mri/filled.mgz" %% xsd:anyURI, obo:MS_1000568="388513b60b45379c1b9bba8f73a29f69"])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/4e1c6bc6deedd326a99e0e9d15ba7560)
#   entity(fs:e/99a55a333971ac9e6bf4dfed8706af7e, [prov:label="mri:lh.ribbon.mgz", prov:label="lh.ribbon.mgz", fs:relative_path="mri/lh.ribbon.mgz", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/mri/lh.ribbon.mgz" %% xsd:anyURI, obo:MS_1000568="a1f48b46493a92be4bae948b5942b5b6", prov:label="lh", prov:type='obo:UBERON_0002812'])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/99a55a333971ac9e6bf4dfed8706af7e)
#   entity(fs:e/d8bdc2e281b9ebdb1513af6e70952282, [prov:label="mri:mri_nu_correct.mni.log", prov:label="mri_nu_correct.mni.log", fs:relative_path="mri/mri_nu_correct.mni.log", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/mri/mri_nu_correct.mni.log" %% xsd:anyURI, obo:MS_1000568="7284ca4a0970c264e723784360c4b270"])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/d8bdc2e281b9ebdb1513af6e70952282)
#   entity(fs:e/2a3f25bc36e9b33f335d7d556dfa6b46, [prov:label="mri:norm.mgz", prov:label="norm.mgz", fs:relative_path="mri/norm.mgz", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/mri/norm.mgz" %% xsd:anyURI, obo:MS_1000568="709d8656eb624bb47921efc1edc46ed5"])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/2a3f25bc36e9b33f335d7d556dfa6b46)
#   entity(fs:e/4be97ed742a8c9e778c2fe8ec8a573f4, [prov:label="mri:nu.mgz", prov:label="nu.mgz", fs:relative_path="mri/nu.mgz", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/mri/nu.mgz" %% xsd:anyURI, obo:MS_1000568="6811c8080ecab00cff659584a723a35b"])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/4be97ed742a8c9e778c2fe8ec8a573f4)
#   entity(fs:e/8f4b43da99a8bfae058f1ef24e731152, [prov:label="mri:nu_noneck.mgz", prov:label="nu_noneck.mgz", fs:relative_path="mri/nu_noneck.mgz", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/mri/nu_noneck.mgz" %% xsd:anyURI, obo:MS_1000568="af3f62ad1bb58b941e6f73354b65dfaf"])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/8f4b43da99a8bfae058f1ef24e731152)
#   entity(fs:e/4e2984df0c16fd21d13d6c63bd7e973e, [prov:label="mri:orig.mgz", prov:label="orig.mgz", fs:relative_path="mri/orig.mgz", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/mri/orig.mgz" %% xsd:anyURI, obo:MS_1000568="e6aa5cac3a76d8c8b06d65fffd94fdc1"])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/4e2984df0c16fd21d13d6c63bd7e973e)
#   entity(fs:e/5527ed87d9a2d4c5a93efebe787d2de7, [prov:label="mri:rawavg.mgz", prov:label="rawavg.mgz", fs:relative_path="mri/rawavg.mgz", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/mri/rawavg.mgz" %% xsd:anyURI, obo:MS_1000568="e21e1cc2895dfaf0d36f7879fd2252c9"])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/5527ed87d9a2d4c5a93efebe787d2de7)
#   entity(fs:e/12ebb25a80312f699a37cb5a7f85dfc4, [prov:label="mri:rh.ribbon.mgz", prov:label="rh.ribbon.mgz", fs:relative_path="mri/rh.ribbon.mgz", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/mri/rh.ribbon.mgz" %% xsd:anyURI, obo:MS_1000568="9bef6e6a055d80f422de11e7328eca1a", prov:label="rh", prov:type='obo:UBERON_0002813'])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/12ebb25a80312f699a37cb5a7f85dfc4)
#   entity(fs:e/d49746cc89d900abdfc61cebf07d1224, [prov:label="mri:ribbon.mgz", prov:label="ribbon.mgz", fs:relative_path="mri/ribbon.mgz", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/mri/ribbon.mgz" %% xsd:anyURI, obo:MS_1000568="05a4235eae8f134b5f0985d06dcaa900"])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/d49746cc89d900abdfc61cebf07d1224)
#   entity(fs:e/d94bd7e6cdc65448ba2b2e0f2eef3ec0, [prov:label="mri:segment.dat", prov:label="segment.dat", fs:relative_path="mri/segment.dat", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/mri/segment.dat" %% xsd:anyURI, obo:MS_1000568="bba5b7f1db80421990285068fb065f8a"])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/d94bd7e6cdc65448ba2b2e0f2eef3ec0)
#   entity(fs:e/a13d86a6c743161c67a4beca4c251eaa, [prov:label="mri:talairach.label_intensities.txt", prov:label="talairach.label_intensities.txt", fs:relative_path="mri/talairach.label_intensities.txt", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/mri/talairach.label_intensities.txt" %% xsd:anyURI, obo:MS_1000568="8f73357b44f49ad34c3499d5edbfe306", prov:label="label", prov:type='fs:label_file'])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/a13d86a6c743161c67a4beca4c251eaa)
#   entity(fs:e/9a4d877deb5dad141b297f41a2d7c5dd, [prov:label="mri:talairach.log", prov:label="talairach.log", fs:relative_path="mri/talairach.log", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/mri/talairach.log" %% xsd:anyURI, obo:MS_1000568="02b5cb3aa116caa89f580f064f065d37"])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/9a4d877deb5dad141b297f41a2d7c5dd)
#   entity(fs:e/305d475aeef4747b39273925c9d1697f, [prov:label="mri:talairach_with_skull.log", prov:label="talairach_with_skull.log", fs:relative_path="mri/talairach_with_skull.log", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/mri/talairach_with_skull.log" %% xsd:anyURI, obo:MS_1000568="6e296bfdf0b579dd79abe0ca4bf26de6"])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/305d475aeef4747b39273925c9d1697f)
#   entity(fs:e/79768570f70350fe0dd6a398f7159f5d, [prov:label="mri:wm.asegedit.mgz", prov:label="wm.asegedit.mgz", fs:relative_path="mri/wm.asegedit.mgz", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/mri/wm.asegedit.mgz" %% xsd:anyURI, obo:MS_1000568="fd291d8772636dfafab916f22ad1c8c8"])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/79768570f70350fe0dd6a398f7159f5d)
#   entity(fs:e/5954dfa49cba2ba28de86dbf29841569, [prov:label="mri:wm.mgz", prov:label="wm.mgz", fs:relative_path="mri/wm.mgz", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/mri/wm.mgz" %% xsd:anyURI, obo:MS_1000568="a3a65de9ab59d84bbdd33dfa1271c661"])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/5954dfa49cba2ba28de86dbf29841569)
#   entity(fs:e/688d5ccaf61fabb0f06f68394fb3441c, [prov:label="mri:wm.seg.mgz", prov:label="wm.seg.mgz", fs:relative_path="mri/wm.seg.mgz", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/mri/wm.seg.mgz" %% xsd:anyURI, obo:MS_1000568="6014e434d923da8a6ae432e33a4bb363"])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/688d5ccaf61fabb0f06f68394fb3441c)
#   entity(fs:e/f86ed4fdb83af11e2306c72330ef5dc1, [prov:label="mri:wm1.txt", prov:label="wm1.txt", fs:relative_path="mri/wm1.txt", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/mri/wm1.txt" %% xsd:anyURI, obo:MS_1000568="18fbad2e966d01b408a65628f9a31cce"])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/f86ed4fdb83af11e2306c72330ef5dc1)
#   entity(fs:e/e6f33e870fe384bcb0eb500c659069da, [prov:label="mri:wm255.txt", prov:label="wm255.txt", fs:relative_path="mri/wm255.txt", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/mri/wm255.txt" %% xsd:anyURI, obo:MS_1000568="d84cd2194b1ccdf66e835a30f84d768f"])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/e6f33e870fe384bcb0eb500c659069da)
#   entity(fs:e/37995980ea578c2d7c8cd2928142c0bc, [prov:label="mri:wmparc.mgz", prov:label="wmparc.mgz", fs:relative_path="mri/wmparc.mgz", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/mri/wmparc.mgz" %% xsd:anyURI, obo:MS_1000568="59f73e49d5737fc63106e8c4a2239f57"])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/37995980ea578c2d7c8cd2928142c0bc)
#   entity(fs:e/971a85178a45a3b137eac6e0ebb4aa13, [prov:label="mri.orig:001-iscale.txt", prov:label="001-iscale.txt", fs:relative_path="mri/orig/001-iscale.txt", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/mri/orig/001-iscale.txt" %% xsd:anyURI, obo:MS_1000568="c4ca4238a0b923820dcc509a6f75849b"])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/971a85178a45a3b137eac6e0ebb4aa13)
#   entity(fs:e/58b2be9393cd3eab1ed5975b7a325238, [prov:label="mri.orig:001.lta", prov:label="001.lta", fs:relative_path="mri/orig/001.lta", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/mri/orig/001.lta" %% xsd:anyURI, obo:MS_1000568="01808a74040f4fe04b7122bef26ee8cf"])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/58b2be9393cd3eab1ed5975b7a325238)
#   entity(fs:e/889d228f75cd26356b92c8d862aa348f, [prov:label="mri.orig:001.mgz", prov:label="001.mgz", fs:relative_path="mri/orig/001.mgz", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/mri/orig/001.mgz" %% xsd:anyURI, obo:MS_1000568="f3f9206926ae28af4b8056ee704fe9b5"])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/889d228f75cd26356b92c8d862aa348f)
#   entity(fs:e/1c92fcb58593a643fc7e1cbbb7113e15, [prov:label="mri.orig:002-iscale.txt", prov:label="002-iscale.txt", fs:relative_path="mri/orig/002-iscale.txt", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/mri/orig/002-iscale.txt" %% xsd:anyURI, obo:MS_1000568="ec2cd92c8140ea711d6e3d06772a3805"])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/1c92fcb58593a643fc7e1cbbb7113e15)
#   entity(fs:e/e51dd944ae3491dc9481ee1a51f24871, [prov:label="mri.orig:002.lta", prov:label="002.lta", fs:relative_path="mri/orig/002.lta", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/mri/orig/002.lta" %% xsd:anyURI, obo:MS_1000568="72eb61a5b72e7499347100d54a439eaa"])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/e51dd944ae3491dc9481ee1a51f24871)
#   entity(fs:e/24c9e687e3e6793496866147898db2d2, [prov:label="mri.orig:002.mgz", prov:label="002.mgz", fs:relative_path="mri/orig/002.mgz", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/mri/orig/002.mgz" %% xsd:anyURI, obo:MS_1000568="7912ecef5731bfb32656ccbfb30dd14d"])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/24c9e687e3e6793496866147898db2d2)
#   entity(fs:e/9ec637947fa8cb2e581160850c4e6fbd, [prov:label="mri.orig:003-iscale.txt", prov:label="003-iscale.txt", fs:relative_path="mri/orig/003-iscale.txt", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/mri/orig/003-iscale.txt" %% xsd:anyURI, obo:MS_1000568="61bbd09d64e59cc6af02b6a93f159e62"])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/9ec637947fa8cb2e581160850c4e6fbd)
#   entity(fs:e/dc9e35a45e45507d92426b57fbba33a9, [prov:label="mri.orig:003.lta", prov:label="003.lta", fs:relative_path="mri/orig/003.lta", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/mri/orig/003.lta" %% xsd:anyURI, obo:MS_1000568="822334fe07506e0602500a6e8f5ef324"])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/dc9e35a45e45507d92426b57fbba33a9)
#   entity(fs:e/37cb9dc1a0184a14ac6d2795562d067b, [prov:label="mri.orig:003.mgz", prov:label="003.mgz", fs:relative_path="mri/orig/003.mgz", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/mri/orig/003.mgz" %% xsd:anyURI, obo:MS_1000568="77780faebbbee32af35a67a6ad6fb106"])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/37cb9dc1a0184a14ac6d2795562d067b)
#   entity(fs:e/52098411241c523ae3e07152e7d28ea8, [prov:label="mri.transforms:cc_up.lta", prov:label="cc_up.lta", fs:relative_path="mri/transforms/cc_up.lta", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/mri/transforms/cc_up.lta" %% xsd:anyURI, obo:MS_1000568="e0105a7cae17fdd28e6ebed4a3ad3ff1"])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/52098411241c523ae3e07152e7d28ea8)
#   entity(fs:e/08a735fd15d8bfd1d02ca29b69b3c100, [prov:label="mri.transforms:talairach.auto.xfm", prov:label="talairach.auto.xfm", fs:relative_path="mri/transforms/talairach.auto.xfm", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/mri/transforms/talairach.auto.xfm" %% xsd:anyURI, obo:MS_1000568="508fd4e03ae541d1aaaef9267fc9d5cf"])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/08a735fd15d8bfd1d02ca29b69b3c100)
#   entity(fs:e/22a965b81c58631d3c5824761dc9766c, [prov:label="mri.transforms:talairach.lta", prov:label="talairach.lta", fs:relative_path="mri/transforms/talairach.lta", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/mri/transforms/talairach.lta" %% xsd:anyURI, obo:MS_1000568="85052c3ecb86ab1d074a6ee7ff7e5ed0"])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/22a965b81c58631d3c5824761dc9766c)
#   entity(fs:e/151ba97893738401679e569465b86063, [prov:label="mri.transforms:talairach.m3z", prov:label="talairach.m3z", fs:relative_path="mri/transforms/talairach.m3z", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/mri/transforms/talairach.m3z" %% xsd:anyURI, obo:MS_1000568="6bdd3630ab320b77bdd78260e98081ce"])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/151ba97893738401679e569465b86063)
#   entity(fs:e/a67fc94779a31c3a410518f27be22f00, [prov:label="mri.transforms:talairach.m3z.inv.x.mgz", prov:label="talairach.m3z.inv.x.mgz", fs:relative_path="mri/transforms/talairach.m3z.inv.x.mgz", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/mri/transforms/talairach.m3z.inv.x.mgz" %% xsd:anyURI, obo:MS_1000568="5f081cee7d8c56ddd3c7de50c8f3439e"])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/a67fc94779a31c3a410518f27be22f00)
#   entity(fs:e/f8f76b274c3d83658c9dc9a9b6e81db1, [prov:label="mri.transforms:talairach.m3z.inv.y.mgz", prov:label="talairach.m3z.inv.y.mgz", fs:relative_path="mri/transforms/talairach.m3z.inv.y.mgz", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/mri/transforms/talairach.m3z.inv.y.mgz" %% xsd:anyURI, obo:MS_1000568="7d40df24ccac5754cb7d7e2bba96886d"])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/f8f76b274c3d83658c9dc9a9b6e81db1)
#   entity(fs:e/2c88edb2bf3455667d39e32d55f24986, [prov:label="mri.transforms:talairach.m3z.inv.z.mgz", prov:label="talairach.m3z.inv.z.mgz", fs:relative_path="mri/transforms/talairach.m3z.inv.z.mgz", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/mri/transforms/talairach.m3z.inv.z.mgz" %% xsd:anyURI, obo:MS_1000568="d858b15844506481c0350864cf1be208"])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/2c88edb2bf3455667d39e32d55f24986)
#   entity(fs:e/0f0c11d32c45537302fbfb94346f96cf, [prov:label="mri.transforms:talairach.xfm", prov:label="talairach.xfm", fs:relative_path="mri/transforms/talairach.xfm", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/mri/transforms/talairach.xfm" %% xsd:anyURI, obo:MS_1000568="508fd4e03ae541d1aaaef9267fc9d5cf"])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/0f0c11d32c45537302fbfb94346f96cf)
#   entity(fs:e/81b573e469e71a203e4f048ccce6a260, [prov:label="mri.transforms:talairach_avi.log", prov:label="talairach_avi.log", fs:relative_path="mri/transforms/talairach_avi.log", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/mri/transforms/talairach_avi.log" %% xsd:anyURI, obo:MS_1000568="bc45a5f394a24abbb4cf457bd0676388"])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/81b573e469e71a203e4f048ccce6a260)
#   entity(fs:e/c80037d6b2ab49388e6bc8d55ed9e4ff, [prov:label="mri.transforms:talairach_avi_QA.log", prov:label="talairach_avi_QA.log", fs:relative_path="mri/transforms/talairach_avi_QA.log", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/mri/transforms/talairach_avi_QA.log" %% xsd:anyURI, obo:MS_1000568="89a6dc751e22da96ed96ee2eb6f72dad"])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/c80037d6b2ab49388e6bc8d55ed9e4ff)
#   entity(fs:e/fbd27e2fee337718fbebcc1600991cf1, [prov:label="mri.transforms:talairach_with_skull.lta", prov:label="talairach_with_skull.lta", fs:relative_path="mri/transforms/talairach_with_skull.lta", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/mri/transforms/talairach_with_skull.lta" %% xsd:anyURI, obo:MS_1000568="bf4e75d2e5ad3a0e683d902295c6834d"])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/fbd27e2fee337718fbebcc1600991cf1)
#   entity(fs:e/4b4f826e44200fd2daeb3d5e1f43065b, [prov:label="scripts:build-stamp.txt", prov:label="build-stamp.txt", fs:relative_path="scripts/build-stamp.txt", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/scripts/build-stamp.txt" %% xsd:anyURI, obo:MS_1000568="20bf35f2173240e12f6fbea6638b529a"])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/4b4f826e44200fd2daeb3d5e1f43065b)
#   entity(fs:e/01da85dd387f2d13a416a564f7a9d4b8, [prov:label="scripts:csurfdir", prov:label="csurfdir", fs:relative_path="scripts/csurfdir", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/scripts/csurfdir" %% xsd:anyURI, obo:MS_1000568="65ecacaf0c190f54a5d276b9537c85a9"])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/01da85dd387f2d13a416a564f7a9d4b8)
#   entity(fs:e/8795d4d2b8ba3050944dee7394e96a80, [prov:label="scripts:ponscc.cut.log", prov:label="ponscc.cut.log", fs:relative_path="scripts/ponscc.cut.log", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/scripts/ponscc.cut.log" %% xsd:anyURI, obo:MS_1000568="45f77ddf74a61dd9746f677cd17b5949"])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/8795d4d2b8ba3050944dee7394e96a80)
#   entity(fs:e/0c49dacae4f8e8d20788854266362ada, [prov:label="scripts:recon-all-status.log", prov:label="recon-all-status.log", fs:relative_path="scripts/recon-all-status.log", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/scripts/recon-all-status.log" %% xsd:anyURI, obo:MS_1000568="22e390e176120eef2c66a74ef2229efd"])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/0c49dacae4f8e8d20788854266362ada)
#   entity(fs:e/178cacd43ec90d7b1e0aca0f135705fb, [prov:label="scripts:recon-all.cmd", prov:label="recon-all.cmd", fs:relative_path="scripts/recon-all.cmd", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/scripts/recon-all.cmd" %% xsd:anyURI, obo:MS_1000568="791566137a541dbeabd93c170e548719"])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/178cacd43ec90d7b1e0aca0f135705fb)
#   entity(fs:e/b4a4615938244aff5b01bc2749c3d3a8, [prov:label="scripts:recon-all.done", prov:label="recon-all.done", fs:relative_path="scripts/recon-all.done", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/scripts/recon-all.done" %% xsd:anyURI, obo:MS_1000568="d3c873a97b5531308893761fef12197c"])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/b4a4615938244aff5b01bc2749c3d3a8)
#   entity(fs:e/1cc64dfa2eac74ea3fd96ed114d2b571, [prov:label="scripts:recon-all.env", prov:label="recon-all.env", fs:relative_path="scripts/recon-all.env", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/scripts/recon-all.env" %% xsd:anyURI, obo:MS_1000568="10ed7f4f15cc9ddc8ff7b46645586bdd"])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/1cc64dfa2eac74ea3fd96ed114d2b571)
#   entity(fs:e/44614e19e65d39f4bc2c7f455fc4286b, [prov:label="scripts:recon-all.local-copy", prov:label="recon-all.local-copy", fs:relative_path="scripts/recon-all.local-copy", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/scripts/recon-all.local-copy" %% xsd:anyURI, obo:MS_1000568="7c6fb61a1c5242d4ce7c5aa4c44fa176"])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/44614e19e65d39f4bc2c7f455fc4286b)
# ...
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/7bda8c63499d71cdaf58e0d8bbe99ded)
#   entity(fs:e/62f0dbdb6e6f1f7688d2346729a7b15e, [prov:label="touch:lh.tessellate.touch", prov:label="lh.tessellate.touch", fs:relative_path="touch/lh.tessellate.touch", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/touch/lh.tessellate.touch" %% xsd:anyURI, obo:MS_1000568="bf965e117dff279f90fc72949694f931", prov:label="lh", prov:type='obo:UBERON_0002812'])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/62f0dbdb6e6f1f7688d2346729a7b15e)
#   entity(fs:e/24eddd0e50f0dfdbfc1723126a3cfb3c, [prov:label="touch:lh.topofix.touch", prov:label="lh.topofix.touch", fs:relative_path="touch/lh.topofix.touch", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/touch/lh.topofix.touch" %% xsd:anyURI, obo:MS_1000568="3edec4dc4f85b33909fd92f44e03be92", prov:label="lh", prov:type='obo:UBERON_0002812'])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/24eddd0e50f0dfdbfc1723126a3cfb3c)
#   entity(fs:e/33ef3ad99bd0b891b966f2895567df23, [prov:label="touch:lh.white_surface.touch", prov:label="lh.white_surface.touch", fs:relative_path="touch/lh.white_surface.touch", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/touch/lh.white_surface.touch" %% xsd:anyURI, obo:MS_1000568="1b490fbb60a3fc0e53a69a79f6c684dc", prov:label="lh", prov:type='obo:UBERON_0002812'])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/33ef3ad99bd0b891b966f2895567df23)
#   entity(fs:e/6e8171f1d63a390ba4a9e525fa5d9bae, [prov:label="touch:motion_correct.touch", prov:label="motion_correct.touch", fs:relative_path="touch/motion_correct.touch", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/touch/motion_correct.touch" %% xsd:anyURI, obo:MS_1000568="fbf1c8df7959a6a68de9f73bd8ca6d89"])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/6e8171f1d63a390ba4a9e525fa5d9bae)
#   entity(fs:e/722c82fb8966d50a1979102a7f8c9142, [prov:label="touch:mri_remove_neck.touch", prov:label="mri_remove_neck.touch", fs:relative_path="touch/mri_remove_neck.touch", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/touch/mri_remove_neck.touch" %% xsd:anyURI, obo:MS_1000568="9bd2fc2bbee62096921c593927eb8051"])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/722c82fb8966d50a1979102a7f8c9142)
#   entity(fs:e/325fb141a586e0bce5d689a60b924621, [prov:label="touch:nu.touch", prov:label="nu.touch", fs:relative_path="touch/nu.touch", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/touch/nu.touch" %% xsd:anyURI, obo:MS_1000568="d41d8cd98f00b204e9800998ecf8427e"])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/325fb141a586e0bce5d689a60b924621)
#   entity(fs:e/53226ecdb2b8a3e5133aa082e36b64aa, [prov:label="touch:rh.aparc.touch", prov:label="rh.aparc.touch", fs:relative_path="touch/rh.aparc.touch", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/touch/rh.aparc.touch" %% xsd:anyURI, obo:MS_1000568="4a3cc4e2b61800cec78bdb37ef0b4841", prov:label="rh", prov:type='obo:UBERON_0002813'])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/53226ecdb2b8a3e5133aa082e36b64aa)
#   entity(fs:e/9f3589d22de01cf0369fc0aab5c8f691, [prov:label="touch:rh.aparc2.touch", prov:label="rh.aparc2.touch", fs:relative_path="touch/rh.aparc2.touch", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/touch/rh.aparc2.touch" %% xsd:anyURI, obo:MS_1000568="bd84524a9290ce29abd109a8a83512c2", prov:label="rh", prov:type='obo:UBERON_0002813'])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/9f3589d22de01cf0369fc0aab5c8f691)
#   entity(fs:e/83144015cd524c53c28a3a3c46975024, [prov:label="touch:rh.aparcstats.touch", prov:label="rh.aparcstats.touch", fs:relative_path="touch/rh.aparcstats.touch", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/touch/rh.aparcstats.touch" %% xsd:anyURI, obo:MS_1000568="aaf87ece4e909269fa98abdeec59f825", prov:label="rh", prov:type='obo:UBERON_0002813'])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/83144015cd524c53c28a3a3c46975024)
#   entity(fs:e/7d2ab183a9c60583342ab0ff5ffd1e73, [prov:label="touch:rh.aparcstats2.touch", prov:label="rh.aparcstats2.touch", fs:relative_path="touch/rh.aparcstats2.touch", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/touch/rh.aparcstats2.touch" %% xsd:anyURI, obo:MS_1000568="ad8213428fb4fa225b3c9373e8220344", prov:label="rh", prov:type='obo:UBERON_0002813'])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/7d2ab183a9c60583342ab0ff5ffd1e73)
#   entity(fs:e/81b8c8e22257323e1dcdc8886c3cc5b0, [prov:label="touch:rh.avgcurv.touch", prov:label="rh.avgcurv.touch", fs:relative_path="touch/rh.avgcurv.touch", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/touch/rh.avgcurv.touch" %% xsd:anyURI, obo:MS_1000568="b00e8008a139199259638708adcc2aad", prov:label="rh", prov:type='obo:UBERON_0002813'])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/81b8c8e22257323e1dcdc8886c3cc5b0)
#   entity(fs:e/7288320d7da914c0fbd17d0005d47674, [prov:label="touch:rh.curvstats.touch", prov:label="rh.curvstats.touch", fs:relative_path="touch/rh.curvstats.touch", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/touch/rh.curvstats.touch" %% xsd:anyURI, obo:MS_1000568="2b1ddf3dbd774ecde3c4968c9befed07", prov:label="rh", prov:type='obo:UBERON_0002813'])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/7288320d7da914c0fbd17d0005d47674)
#   entity(fs:e/85a4d0cc8f1af3a7c2cc2d983b1cff37, [prov:label="touch:rh.final_surfaces.touch", prov:label="rh.final_surfaces.touch", fs:relative_path="touch/rh.final_surfaces.touch", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/touch/rh.final_surfaces.touch" %% xsd:anyURI, obo:MS_1000568="ab5cfcae4397805c7eab1ebd77e7fda5", prov:label="rh", prov:type='obo:UBERON_0002813'])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/85a4d0cc8f1af3a7c2cc2d983b1cff37)
#   entity(fs:e/68158639f26a3febb9636bee93bbbabe, [prov:label="touch:rh.inflate1.touch", prov:label="rh.inflate1.touch", fs:relative_path="touch/rh.inflate1.touch", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/touch/rh.inflate1.touch" %% xsd:anyURI, obo:MS_1000568="57cad7f49edee894fda38c94b520b5ca", prov:label="rh", prov:type='obo:UBERON_0002813'])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/68158639f26a3febb9636bee93bbbabe)
#   entity(fs:e/5e088725d2867d0936f5f5dafc83a1fb, [prov:label="touch:rh.inflate2.touch", prov:label="rh.inflate2.touch", fs:relative_path="touch/rh.inflate2.touch", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/touch/rh.inflate2.touch" %% xsd:anyURI, obo:MS_1000568="56966320ec63cfbba368c2ae4ddfbab1", prov:label="rh", prov:type='obo:UBERON_0002813'])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/5e088725d2867d0936f5f5dafc83a1fb)
#   entity(fs:e/73f12203c5033832540762e9b880057d, [prov:label="touch:rh.jacobian_white.touch", prov:label="rh.jacobian_white.touch", fs:relative_path="touch/rh.jacobian_white.touch", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/touch/rh.jacobian_white.touch" %% xsd:anyURI, obo:MS_1000568="a946aef1937679ea4a6a149ffc5a7016", prov:label="rh", prov:type='obo:UBERON_0002813'])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/73f12203c5033832540762e9b880057d)
#   entity(fs:e/4fde0c9c7aa682cbea4af7f527558fb6, [prov:label="touch:rh.pial_surface.touch", prov:label="rh.pial_surface.touch", fs:relative_path="touch/rh.pial_surface.touch", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/touch/rh.pial_surface.touch" %% xsd:anyURI, obo:MS_1000568="ab5cfcae4397805c7eab1ebd77e7fda5", prov:label="rh", prov:type='obo:UBERON_0002813'])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/4fde0c9c7aa682cbea4af7f527558fb6)
#   entity(fs:e/3de9886fc4e081ad4e542245310f798b, [prov:label="touch:rh.qsphere.touch", prov:label="rh.qsphere.touch", fs:relative_path="touch/rh.qsphere.touch", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/touch/rh.qsphere.touch" %% xsd:anyURI, obo:MS_1000568="e2840a4aa749273c3f5eedf6e7e16096", prov:label="rh", prov:type='obo:UBERON_0002813'])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/3de9886fc4e081ad4e542245310f798b)
#   entity(fs:e/dca1ee70d42ce7fda908d21b24b3f222, [prov:label="touch:rh.smoothwm1.touch", prov:label="rh.smoothwm1.touch", fs:relative_path="touch/rh.smoothwm1.touch", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/touch/rh.smoothwm1.touch" %% xsd:anyURI, obo:MS_1000568="4f0c2c4f377aef49b38a78ed88bfa13a", prov:label="rh", prov:type='obo:UBERON_0002813'])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/dca1ee70d42ce7fda908d21b24b3f222)
#   entity(fs:e/80b5aee8a13e7a1eb26dcd8a2b55c53c, [prov:label="touch:rh.smoothwm2.touch", prov:label="rh.smoothwm2.touch", fs:relative_path="touch/rh.smoothwm2.touch", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/touch/rh.smoothwm2.touch" %% xsd:anyURI, obo:MS_1000568="c4109fa54d9fe043c9b3b73ccaddcba2", prov:label="rh", prov:type='obo:UBERON_0002813'])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/80b5aee8a13e7a1eb26dcd8a2b55c53c)
#   entity(fs:e/a3651765f9b5166c957127fccdedd70b, [prov:label="touch:rh.sphmorph.touch", prov:label="rh.sphmorph.touch", fs:relative_path="touch/rh.sphmorph.touch", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/touch/rh.sphmorph.touch" %% xsd:anyURI, obo:MS_1000568="8f99840e77c14780b44d5c86450c0bcc", prov:label="rh", prov:type='obo:UBERON_0002813'])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/a3651765f9b5166c957127fccdedd70b)
#   entity(fs:e/a99ae98f7bd694000043856c4d50cb08, [prov:label="touch:rh.sphreg.touch", prov:label="rh.sphreg.touch", fs:relative_path="touch/rh.sphreg.touch", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/touch/rh.sphreg.touch" %% xsd:anyURI, obo:MS_1000568="f23e9032eb1a18c127c80e8bba0d81d6", prov:label="rh", prov:type='obo:UBERON_0002813'])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/a99ae98f7bd694000043856c4d50cb08)
#   entity(fs:e/5a82097b6a2dcca9405c1f060946e960, [prov:label="touch:rh.surfvolume.touch", prov:label="rh.surfvolume.touch", fs:relative_path="touch/rh.surfvolume.touch", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/touch/rh.surfvolume.touch" %% xsd:anyURI, obo:MS_1000568="323c7e2fafd1c74efa63198c4d8c9ebb", prov:label="rh", prov:type='obo:UBERON_0002813'])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/5a82097b6a2dcca9405c1f060946e960)
#   entity(fs:e/8f15f2963623cf37addb49e86a757acb, [prov:label="touch:rh.tessellate.touch", prov:label="rh.tessellate.touch", fs:relative_path="touch/rh.tessellate.touch", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/touch/rh.tessellate.touch" %% xsd:anyURI, obo:MS_1000568="f57b379b4afe9531c213fd8444cd603b", prov:label="rh", prov:type='obo:UBERON_0002813'])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/8f15f2963623cf37addb49e86a757acb)
#   entity(fs:e/3f04805ea31956ae6df58a7ec73b88e6, [prov:label="touch:rh.topofix.touch", prov:label="rh.topofix.touch", fs:relative_path="touch/rh.topofix.touch", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/touch/rh.topofix.touch" %% xsd:anyURI, obo:MS_1000568="b3e02688509265a5315e4391527f6404", prov:label="rh", prov:type='obo:UBERON_0002813'])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/3f04805ea31956ae6df58a7ec73b88e6)
#   entity(fs:e/a40a832f454f187da43c3de44d059f5c, [prov:label="touch:rh.white_surface.touch", prov:label="rh.white_surface.touch", fs:relative_path="touch/rh.white_surface.touch", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/touch/rh.white_surface.touch" %% xsd:anyURI, obo:MS_1000568="164a778df6099b650f87aabd669abd73", prov:label="rh", prov:type='obo:UBERON_0002813'])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/a40a832f454f187da43c3de44d059f5c)
#   entity(fs:e/ff40e2eb7100fcbfd548a841e3cde21a, [prov:label="touch:segstats.touch", prov:label="segstats.touch", fs:relative_path="touch/segstats.touch", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/touch/segstats.touch" %% xsd:anyURI, obo:MS_1000568="9302dd888c82b860a588aeeb62843eed"])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/ff40e2eb7100fcbfd548a841e3cde21a)
#   entity(fs:e/4db3366e6f3e521fae60e2d25c4bb5f9, [prov:label="touch:skull.lta.touch", prov:label="skull.lta.touch", fs:relative_path="touch/skull.lta.touch", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/touch/skull.lta.touch" %% xsd:anyURI, obo:MS_1000568="2365adcdf6631c677a829fb7322e90db"])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/4db3366e6f3e521fae60e2d25c4bb5f9)
#   entity(fs:e/2d9b32daa54094ed32ceac3d615a3c77, [prov:label="touch:skull_strip.touch", prov:label="skull_strip.touch", fs:relative_path="touch/skull_strip.touch", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/touch/skull_strip.touch" %% xsd:anyURI, obo:MS_1000568="b67aca166879e0de148dd52550f9e25f"])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/2d9b32daa54094ed32ceac3d615a3c77)
#   entity(fs:e/deba339a0acc692ac00645cd096c1e10, [prov:label="touch:talairach.touch", prov:label="talairach.touch", fs:relative_path="touch/talairach.touch", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/touch/talairach.touch" %% xsd:anyURI, obo:MS_1000568="b81f486efc083dc9f5654744f1b3defc"])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/deba339a0acc692ac00645cd096c1e10)
#   entity(fs:e/b735361a6d73fd431a79429a845e08b4, [prov:label="touch:wm.mgz.tkmedit.touch", prov:label="wm.mgz.tkmedit.touch", fs:relative_path="touch/wm.mgz.tkmedit.touch", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/touch/wm.mgz.tkmedit.touch" %% xsd:anyURI, obo:MS_1000568="d41d8cd98f00b204e9800998ecf8427e"])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/b735361a6d73fd431a79429a845e08b4)
#   entity(fs:e/ff5852ca4e97c2ae3eda9babdba02f9b, [prov:label="touch:wmaparc.stats.touch", prov:label="wmaparc.stats.touch", fs:relative_path="touch/wmaparc.stats.touch", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/touch/wmaparc.stats.touch" %% xsd:anyURI, obo:MS_1000568="0541dddfdd001847b2f8bd90dde27c6c", prov:label=".stats", prov:type='fs:statistic_file'])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/ff5852ca4e97c2ae3eda9babdba02f9b)
#   entity(fs:e/9883457126804b62a9a7cf16a338eae3, [prov:label="touch:wmaparc.touch", prov:label="wmaparc.touch", fs:relative_path="touch/wmaparc.touch", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/touch/wmaparc.touch" %% xsd:anyURI, obo:MS_1000568="a8c028f254302623e130aecb047dd23c"])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/9883457126804b62a9a7cf16a338eae3)
#   entity(fs:e/084823e4e1d738a3a3d1dfae574ab038, [prov:label="touch:wmsegment.touch", prov:label="wmsegment.touch", fs:relative_path="touch/wmsegment.touch", prov:location="file://81.42.168.192.in-addr.arpa/Applications/freesurfer/subjects/bert/touch/wmsegment.touch" %% xsd:anyURI, obo:MS_1000568="81d2dab3ff3d5b86eddff28f9ef49f0c"])
#   hadMember(fs:4c735fc66b5e12cdd321d6ed64394c84, fs:e/084823e4e1d738a3a3d1dfae574ab038)
# endDocument

# %% [markdown]
# ### Querying object models with SPARQL using a triplestore
#
# In this section we will show example SPARQL queries that access a triplestore.
#
#     - What is a triplestore?
#     - How are NI-DM objects uploaded to a triplestore?
#     - How do we query a triplestore for data stored using NI-DM?

# %% [markdown]
# ### What is a triplestore?
#
#     - A triplestore is a database for storing RDF triples (i.e., subject, predicate, object statements).
#     - The triplestore provides a way to create, read, update, and delete persisted RDF statements using the SPARQL 1.1 protocol.
#     - Here we are using the triplestore functionality of the Virtuoso database (http://virtuoso.openlinksw.com/)
#     - The specific triplestore can easily be swapped for another system such as Jena or Seseme.

# %% [markdown]
# ### How are NIDM objects uploaded to a triplestore?
#
#     - The examples above demonstrates how to create a collection of NI-DM FreeSurfer objects in RDF.
#     - RDF files can be bulk uploaded through the Virtuoso web interface or using a SPARQL Insert Statement
#     - This is an example of adding a single RDF triple

# %%
import requests
from requests.auth import HTTPDigestAuth

from IPython.core.display import HTML


# connection params for secure endpoint
endpoint = 'http://computor.mit.edu:8890/sparql'
username = 'username'
password = 'password'

# session defaults
session = requests.Session()
session.auth = HTTPDigestAuth(username, password)

session.headers = {'Accept':'text/html'} # HTML from SELECT queries

# INSERT - CREATE new triples
query =  """PREFIX nidm: <http://nidm.nidash.org#>
            PREFIX prov: <http://www.w3.org/ns/prov#>
            PREFIX nlx: <http://uri.neuinfo.org/nif/nifstd/>
            
            INSERT DATA
            INTO GRAPH <http://nidm.nidash.org>
                {nidm:UUID12345 a prov:Entity;
                    nlx:nlx_150774 "2.0"}"""

data = {'query': query}
result = session.post(endpoint, data=data)
HTML(result.content)

# %% [markdown]
# ### How do we query a triplestore for data stored using NI-DM?
#
#     - this example shows how to query for FreeSurfer details given a subject id

# %%
    def getSubjectDetails(self, subject_id):
        session = requests.Session()

        qstring = '''
        PREFIX fs: <http://surfer.nmr.mgh.harvard.edu/fswiki/#>
        PREFIX xsd: <http://www.w3.org/2001/XMLSchema#>
        PREFIX nidm: <http://nidm.nidash.org/#>
        PREFIX prov: <http://www.w3.org/ns/prov#>

        select distinct ?structureName ?structureGV where {
             # ?subjectCollection fs:subject_id "%s"^^<http://www.w3.org/2001/XMLSchema#string> .
             # ?subjectCollection prov:hadMember ?otherMembers .
             # ?collectionFromProv prov:wasDerivedFrom ?otherMembers .
             # ?collectionFromProv prov:hadMember ?membersOfProvCollection .
             # ?membersOfProvCollection a fs:GrayVol . # filter by those that have a type of fs:GrayVol(ume)
             # ?membersOfProvCollection fs:structure ?structureName . 
             # ?membersOfProvCollection fs:value ?structureGV .
        } ''' % (subject_id)

# %% [markdown]
# ### Mapping XCEDE primitives to NI-DM
#
# The XCEDE XML schema allows for storing information in the context of a flexible and extensible experiment hierarchy.
#
# It accommodates arbitrary configurations centered around Project, Subject, Visit, Study, Episode, and Acquisition objects, as well as limited information about data provenance. Effectively defining a hierarchy of relationships.
#
# It is ill-suited for modeling and querying across complex derived data created from many of today’s workflow systems.

# %% [markdown]
# ### Mappings
#
#
# - xcede:Project     -> prov:Activity (prov:type = nidm:Project)
# - xcede:Study       -> prov:Activity (prov:type = nidm:Study, dcterms:subpartOf = some_project)
# - xcede:Visit       -> prov:Activity (prov:type = nidm:Visit, dcterms:subpartOf = some_study)
# - xcede:Episode     -> prov:Activity (prov:type = nidm:Episod, dcterms:subpartOf = some_visit)
# - xcede:Acquisition -> prov:Activity (prov:type = nidm:Acquisition, dcterms:subpartOf = some_episode)
