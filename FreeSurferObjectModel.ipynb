# %% [markdown]
# # NI-DM: A Summary in many parts
#
# ## Part 3: Constructing and Querying FreeSurfer Object Models
#
# [Latest version][notebook] | [Latest slideshow][slideshow]
#
# [notebook]: http://nbviewer.ipython.org/urls/raw.github.com/ni-/notebooks/master/FreeSurferObjectModel.ipynb
# [slideshow]: http://slideviewer.herokuapp.com/url/raw.github.com/ni-/notebooks/master/FreeSurferObjectModel.ipynb

# %% [markdown]
# ## Outline
#
# - Using the [PROV Python library](https://github.com/trungdong/prov) to construct FreeSurfer object models
# - Querying FreeSurfer object models with [SPARQL](http://www.w3.org/TR/rdf-sparql-query/) using a [triplestore](http://en.wikipedia.org/wiki/Triplestore)

# %% [markdown]
# ## Using the PROV API to construct FreeSurfer object models
#
# We will demonstrate how to encapsulate FreeSurfer directory structures and statistic files

# %% [markdown]
# ### Model 1: FreeSurfer Directory structure
#
# The FreeSurfer output results from a recon-all process that involves several steps. The goal here is to take the directory structure and represent it as a collection of entities, where each entity is a file produced by the recon-all process. In the ideal mode, the recon-all process itself would generate the provenance and the collection of entities. But here we generate the NI-DM encoding of FreeSurfer directories by walking FreeSurfer directories and applying heuristic properties.
#
# For demonstration purposes, we automatically generated terms based on file/directory naming conventions, and assossate these terms with an example FreeSurfer namespace [http://freesurfer.net/fswiki/terms/0.1/]. This namespace is only a placeholder; however, the developers of a given neuroimaging software package (e.g., FreeSurfer) are responsible for managing a namespace that resolves to a vocabulary that describes their NI-DM object model. The best practice is to provide a URL accessible [RDF](http://www.w3.org/RDF/) representation of the terms in this namespace along with definitions for each term.
#
# Some example terms are:
#
#     - fs:subject_id : a participant identifier
#     - fs:relative_path : location of file from the root of the subject directory structure
#
# note: `fs:` is a namespace prefix that allows for a shorthand notation of the full URI (e.g., `http://freesurfer.net/fswiki/terms/0.1/subject_id`)

# %% [markdown]
# #### Import necessary tools and create namespaces
#
# This example uses the PROV Python library
#
#     - PROV: https://github.com/trungdong/prov

# %%
# standard library
import os
import md5
from socket import getfqdn

# PROV API library
import prov.model as prov

def hash_infile(afile, chunk_len=8192):
    """ Computes md5 hash of a file"""
    md5hex = None
    if os.path.isfile(afile):
        md5obj = md5.md5()
        fp = file(afile, 'rb')
        while True:
            data = fp.read(chunk_len)
            if not data:
                break
            md5obj.update(data)
        fp.close()
        md5hex = md5obj.hexdigest()
    return md5hex

# create namespace references to terms used
foaf = prov.Namespace("foaf", "http://xmlns.com/foaf/0.1/")
dcterms = prov.Namespace("dcterms", "http://purl.org/dc/terms/")
fs = prov.Namespace("fs", "http://freesurfer.net/fswiki/terms/0.1/")
nidm = prov.Namespace("nidm", "http://nidm.nidash.org/terms/0.1/")
niiri = prov.Namespace("niiri", "http://nidm.nidash.org/iri/")
obo = prov.Namespace("obo", "http://purl.obolibrary.org/obo/")
nif = prov.Namespace("nif", "http://neurolex.org/wiki/")

# %% [markdown]
# ### Define a function that creates a NI-DM Entity for a freesurfer file

# %%
sdir = os.path.join(os.environ['FREESURFER_HOME'], 'subjects', 'bert/')
for dirpath, dirnames, filenames in os.walk(sdir):
    for filename in sorted(filenames):
        print os.path.join(dirpath, filename).replace(sdir, '')
# Out:
# label/BA.ctab
# label/BA.thresh.ctab
# label/aparc.annot.DKTatlas40.ctab
# label/aparc.annot.a2009s.ctab
# label/aparc.annot.ctab
# label/lh.BA.annot
# label/lh.BA.thresh.annot
# label/lh.BA1.label
# label/lh.BA1.thresh.label
# label/lh.BA2.label
# label/lh.BA2.thresh.label
# label/lh.BA3a.label
# label/lh.BA3a.thresh.label
# label/lh.BA3b.label
# label/lh.BA3b.thresh.label
# label/lh.BA44.label
# label/lh.BA44.thresh.label
# label/lh.BA45.label
# label/lh.BA45.thresh.label
# label/lh.BA4a.label
# label/lh.BA4a.thresh.label
# label/lh.BA4p.label
# label/lh.BA4p.thresh.label
# label/lh.BA6.label
# label/lh.BA6.thresh.label
# label/lh.MT.label
# label/lh.MT.thresh.label
# label/lh.V1.label
# label/lh.V1.thresh.label
# label/lh.V2.label
# label/lh.V2.thresh.label
# label/lh.aparc.DKTatlas40.annot
# label/lh.aparc.a2009s.annot
# label/lh.aparc.annot
# label/lh.bert_ref.aparc.a2009s.annot
# label/lh.bert_ref.aparc.annot
# label/lh.cortex.label
# label/lh.entorhinal_exvivo.label
# label/lh.overlap.annot
# label/lh.perirhinal.label
# label/rh.BA.annot
# label/rh.BA.thresh.annot
# label/rh.BA1.label
# label/rh.BA1.thresh.label
# label/rh.BA2.label
# label/rh.BA2.thresh.label
# label/rh.BA3a.label
# label/rh.BA3a.thresh.label
# label/rh.BA3b.label
# label/rh.BA3b.thresh.label
# label/rh.BA44.label
# label/rh.BA44.thresh.label
# label/rh.BA45.label
# label/rh.BA45.thresh.label
# label/rh.BA4a.label
# label/rh.BA4a.thresh.label
# label/rh.BA4p.label
# label/rh.BA4p.thresh.label
# label/rh.BA6.label
# label/rh.BA6.thresh.label
# label/rh.MT.label
# label/rh.MT.thresh.label
# label/rh.V1.label
# label/rh.V1.thresh.label
# label/rh.V2.label
# label/rh.V2.thresh.label
# label/rh.aparc.DKTatlas40.annot
# label/rh.aparc.a2009s.annot
# label/rh.aparc.annot
# label/rh.bert_ref.aparc.a2009s.annot
# label/rh.bert_ref.aparc.annot
# label/rh.cortex.label
# label/rh.entorhinal_exvivo.label
# label/rh.overlap.annot
# label/rh.perirhinal.label
# mri/.xdebug_mris_calc
# mri/.xdebug_tkmedit
# mri/T1.mgz
# mri/aparc+aseg.mgz
# mri/aparc.a2009s+aseg.mgz
# mri/aseg.auto.mgz
# mri/aseg.auto_noCCseg.label_intensities.txt
# mri/aseg.auto_noCCseg.mgz
# mri/aseg.mgz
# mri/brain.finalsurfs.mgz
# mri/brain.mgz
# mri/brainmask.auto.mgz
# mri/brainmask.gcuts.mgz
# mri/brainmask.mgz
# mri/ctrl_pts.mgz
# mri/filled.mgz
# mri/lh.ribbon.mgz
# mri/mri_nu_correct.mni.log
# mri/mri_nu_correct.mni.log.bak
# mri/norm.mgz
# mri/nu.mgz
# mri/nu_noneck.mgz
# mri/orig.mgz
# mri/rawavg.mgz
# mri/rh.ribbon.mgz
# mri/ribbon.mgz
# mri/segment.dat
# mri/talairach.label_intensities.txt
# mri/talairach.log
# mri/talairach_with_skull.log
# mri/talairach_with_skull_2.log
# mri/wm.asegedit.mgz
# mri/wm.mgz
# mri/wm.seg.mgz
# mri/wm1.txt
# mri/wm255.txt
# mri/wmparc.mgz
# mri/orig/001-iscale.txt
# mri/orig/001.lta
# mri/orig/001.mgz
# mri/orig/002-iscale.txt
# mri/orig/002.lta
# mri/orig/002.mgz
# mri/orig/003-iscale.txt
# mri/orig/003.lta
# mri/orig/003.mgz
# mri/transforms/cc_up.lta
# mri/transforms/talairach.auto.xfm
# mri/transforms/talairach.lta
# mri/transforms/talairach.m3z
# mri/transforms/talairach.m3z.inv.x.mgz
# mri/transforms/talairach.m3z.inv.y.mgz
# mri/transforms/talairach.m3z.inv.z.mgz
# mri/transforms/talairach.xfm
# mri/transforms/talairach_avi.log
# mri/transforms/talairach_avi_QA.log
# mri/transforms/talairach_avi_QA2.log
# mri/transforms/talairach_with_skull.lta
# mri/transforms/talairach_with_skull_2.lta
# mri/transforms/talsrcimg_to_711-2C_as_mni_average_305_t4_vox2vox.txt
# scripts/build-stamp.txt
# scripts/csurfdir
# scripts/pctsurfcon.log
# scripts/pctsurfcon.log.old
# scripts/ponscc.cut.log
# scripts/recon-all-status.log
# scripts/recon-all.cmd
# scripts/recon-all.done
# scripts/recon-all.env
# scripts/recon-all.local-copy
# scripts/recon-all.log
# stats/aseg.stats
# stats/lh.BA.stats
# stats/lh.BA.thresh.stats
# stats/lh.aparc.DKTatlas40.stats
# stats/lh.aparc.a2009s.stats
# stats/lh.aparc.stats
# stats/lh.curv.stats
# stats/lh.entorhinal_exvivo.stats
# stats/lh.w-g.pct.stats
# stats/rh.BA.stats
# stats/rh.BA.thresh.stats
# stats/rh.aparc.DKTatlas40.stats
# stats/rh.aparc.a2009s.stats
# stats/rh.aparc.stats
# stats/rh.curv.stats
# stats/rh.entorhinal_exvivo.stats
# stats/rh.w-g.pct.stats
# stats/wmparc.stats
# surf/lh.area
# surf/lh.area.mid
# surf/lh.area.pial
# surf/lh.avg_curv
# surf/lh.curv
# surf/lh.curv.pial
# surf/lh.defect_borders
# surf/lh.defect_chull
# surf/lh.defect_labels
# surf/lh.inflated
# surf/lh.inflated.H
# surf/lh.inflated.K
# surf/lh.inflated.nofix
# surf/lh.jacobian_white
# surf/lh.orig
# surf/lh.orig.nofix
# surf/lh.pial
# surf/lh.qsphere.nofix
# surf/lh.smoothwm
# surf/lh.smoothwm.BE.crv
# surf/lh.smoothwm.C.crv
# surf/lh.smoothwm.FI.crv
# surf/lh.smoothwm.H.crv
# surf/lh.smoothwm.K.crv
# surf/lh.smoothwm.K1.crv
# surf/lh.smoothwm.K2.crv
# surf/lh.smoothwm.S.crv
# surf/lh.smoothwm.nofix
# surf/lh.sphere
# surf/lh.sphere.reg
# surf/lh.sulc
# surf/lh.thickness
# surf/lh.volume
# surf/lh.w-g.pct.mgh
# surf/lh.white
# surf/rh.area
# surf/rh.area.mid
# surf/rh.area.pial
# surf/rh.avg_curv
# surf/rh.curv
# surf/rh.curv.pial
# surf/rh.defect_borders
# surf/rh.defect_chull
# surf/rh.defect_labels
# surf/rh.inflated
# surf/rh.inflated.H
# surf/rh.inflated.K
# surf/rh.inflated.nofix
# surf/rh.jacobian_white
# surf/rh.orig
# surf/rh.orig.nofix
# surf/rh.pial
# surf/rh.qsphere.nofix
# surf/rh.smoothwm
# surf/rh.smoothwm.BE.crv
# surf/rh.smoothwm.C.crv
# surf/rh.smoothwm.FI.crv
# surf/rh.smoothwm.H.crv
# surf/rh.smoothwm.K.crv
# surf/rh.smoothwm.K1.crv
# surf/rh.smoothwm.K2.crv
# surf/rh.smoothwm.S.crv
# surf/rh.smoothwm.nofix
# surf/rh.sphere
# surf/rh.sphere.reg
# surf/rh.sulc
# surf/rh.thickness
# surf/rh.volume
# surf/rh.w-g.pct.mgh
# surf/rh.white
# touch/aparc.a2009s2aseg.touch
# touch/aparc2aseg.touch
# touch/asegmerge.touch
# touch/brainmask.mgz.tkmedit.touch
# touch/ca_label.touch
# touch/ca_normalize.touch
# touch/ca_register.touch
# touch/ca_register_inv.touch
# touch/conform.touch
# touch/cortical_ribbon.touch
# touch/em_register.touch
# touch/fill.touch
# touch/inorm1.touch
# touch/inorm2.touch
# touch/lh.aparc.touch
# touch/lh.aparc2.touch
# touch/lh.aparcstats.touch
# touch/lh.aparcstats2.touch
# touch/lh.aparcstats3.touch
# touch/lh.avgcurv.touch
# touch/lh.curvstats.touch
# touch/lh.final_surfaces.touch
# touch/lh.inflate1.touch
# touch/lh.inflate2.touch
# touch/lh.jacobian_white.touch
# touch/lh.pctsurfcon.touch
# touch/lh.pial_surface.touch
# touch/lh.qsphere.touch
# touch/lh.smoothwm1.touch
# touch/lh.smoothwm2.touch
# touch/lh.sphmorph.touch
# touch/lh.sphreg.touch
# touch/lh.surfvolume.touch
# touch/lh.tessellate.touch
# touch/lh.topofix.touch
# touch/lh.white_surface.touch
# touch/motion_correct.touch
# touch/mri_remove_neck.touch
# touch/nu.touch
# touch/rh.aparc.touch
# touch/rh.aparc2.touch
# touch/rh.aparcstats.touch
# touch/rh.aparcstats2.touch
# touch/rh.aparcstats3.touch
# touch/rh.avgcurv.touch
# touch/rh.curvstats.touch
# touch/rh.final_surfaces.touch
# touch/rh.inflate1.touch
# touch/rh.inflate2.touch
# touch/rh.jacobian_white.touch
# touch/rh.pctsurfcon.touch
# touch/rh.pial_surface.touch
# touch/rh.qsphere.touch
# touch/rh.smoothwm1.touch
# touch/rh.smoothwm2.touch
# touch/rh.sphmorph.touch
# touch/rh.sphreg.touch
# touch/rh.surfvolume.touch
# touch/rh.tessellate.touch
# touch/rh.topofix.touch
# touch/rh.white_surface.touch
# touch/segstats.touch
# touch/skull.lta.touch
# touch/skull_2.lta.touch
# touch/skull_strip.touch
# touch/talairach.touch
# touch/wm.mgz.tkmedit.touch
# touch/wmaparc.stats.touch
# touch/wmaparc.touch
# touch/wmsegment.touch

# %% [markdown]
# ### Create map from FreeSurfer terms to ontology-based vocabularies
#
# This is a temporary association of filenames in freesurfer directories

# %%
# map FreeSurfer filename parts
fs_file_map =  [('T1', [nif["nlx_inv_20090243"]]), #3d T1 weighted scan
                ('lh', [obo["UBERON_0002812"]]), #left cerebral hemisphere
                ('rh', [obo["UBERON_0002813"]]), # right cerebral hemisphere
                ('BA.', [obo["UBERON_0013529"]]), #Brodmann area
                ('BA1.', [obo["UBERON_0006099"]]), #Brodmann area 1
                ('BA2.', [obo["UBERON_0013533"]]), #Brodmann area 2
                ('BA3a.', [obo["UBERON_0006100"], #Brodmann area 3a
                           obo["FMA_74532"]]), #anterior
                ('BA3b.', [obo["UBERON_0006100"], #Brodmann area 3b
                           obo["FMA_74533"]]), #posterior
                ('BA44.', [obo["UBERON_0006481"]]), #Brodmann area 44
                ('BA45.', [obo["UBERON_0006482"]]), #Brodmann area 45
                ('BA4a.', [obo["UBERON_0013535"], #Brodmann area 4a
                           obo["FMA_74532"]]), #anterior
                ('BA4p.', [obo["UBERON_0013535"], #Brodmann area 4p
                           obo["FMA_74533"]]), #posterior
                ('BA6.', [obo["UBERON_0006472"]]), #Brodmann area 6
                ('V1.', [obo["UBERON_0002436"]]),
                ('V2.', [obo["UBERON_0006473"]]),
                ('MT', [fs["MT_area"]]),
                ('entorhinal', [obo["UBERON_0002728"]]),
                ('exvivo', [fs["exvivo"]]),
                ('label', [fs["label_file"]]),
                ('annot', [fs["annotation_file"]]),
                ('cortex', [obo["UBERON_0000956"]]),
                ('.stats', [fs["statistic_file"]]),
                ('aparc.annot', [fs["default_parcellation"]]),
                ('aparc.a2009s', [fs["a2009s_parcellation"]]),
                ('.ctab', [fs["color_table"]]),
               ]

# files or directories that should be ignored
ignore_list = ['bak', 'src', 'tmp', 'trash', 'touch']

# %% [markdown]
# ### Convert a file location to a NI-DM entity

# %%
def create_entity(graph, fs_subject_id, filepath):
    """ Create a PROV entity for a file in a FreeSurfer directory
    """
    # identify FreeSurfer terms based on directory and file names
    _, filename = os.path.split(filepath)
    relpath = filepath.split(fs_subject_id)[1].lstrip(os.path.sep)
    fstypes = relpath.split('/')[:-1]
    additional_types = relpath.split('/')[-1].split('.')
    
    file_md5_hash = hash_infile(filepath)
    if file_md5_hash is None:
        print fullpath

    url = "file://%s%s" % (getfqdn(), filepath)
    url_get = prov.URIRef("http://computor.mit.edu:10101/file?file_uri=%s" % url)
    # build a NI-DM object 
    obj_attr = [(prov.PROV["label"], filename),
                (fs["relative_path"], "%s" % relpath),
                (prov.PROV["location"], url_get),
                (obo["MS_1000568"], "%s" % file_md5_hash),
               ]

    for key in fstypes:
        obj_attr.append((nidm["tag"], key))
    for key in additional_types:
        obj_attr.append((nidm["tag"], key))

    for key, uris in fs_file_map:
        if key in filename:
            if key.rstrip('.').lstrip('.') not in fstypes + additional_types:
                obj_attr.append((nidm["tag"], key.rstrip('.').lstrip('.')))
            for uri in uris:
                obj_attr.append((prov.PROV["type"], uri))
    id = md5.new(fs_subject_id + relpath + file_md5_hash).hexdigest()
    return graph.entity(niiri[id], obj_attr)

# %% [markdown]
# ### Example of converting single files

# %%
g = prov.ProvBundle()
e1 = create_entity(g, "bert", os.path.join(sdir, "mri/T1.mgz"))
e2 = create_entity(g, "bert", os.path.join(sdir, "label/lh.BA6.label"))
fsdir_collection = g.collection(niiri['foo'])
g.hadMember(fsdir_collection, e1)
print g.rdf().serialize(format='turtle')
# Out:
# @prefix fs: <http://freesurfer.net/fswiki/terms/0.1/> .
# @prefix nidm: <http://nidm.nidash.org/terms/0.1/> .
# @prefix nif: <http://neurolex.org/wiki/> .
# @prefix niiri: <http://nidm.nidash.org/iri/> .
# @prefix obo: <http://purl.obolibrary.org/obo/> .
# @prefix prov: <http://www.w3.org/ns/prov#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xml: <http://www.w3.org/XML/1998/namespace> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
# @prefix xsd1: <http://www.w3.org/2001/XMLSchema-datatypes#> .
#
# <http://nidm.nidash.org/iri/77fa6a15e90b16a6d035a9739b9a9139> a fs:label_file,
#         obo:UBERON_0002812,
#         obo:UBERON_0006472,
#         prov:Entity ;
#     fs:relative_path "label/lh.BA6.label" ;
#     nidm:tag "BA6",
#         "label",
#         "lh" ;
#     obo:MS_1000568 "11bc4b80381b117b996da670a3dcbc13" ;
#     prov:label "lh.BA6.label" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/lh.BA6.label" .
#
# niiri:foo a prov:Collection,
#         prov:Entity ;
#     prov:hadMember <http://nidm.nidash.org/iri/98e3503c1e470eae20bd05b14574d5dc> .
#
# <http://nidm.nidash.org/iri/98e3503c1e470eae20bd05b14574d5dc> a nif:nlx_inv_20090243,
#         prov:Entity ;
#     fs:relative_path "mri/T1.mgz" ;
#     nidm:tag "T1",
#         "mgz",
#         "mri" ;
#     obo:MS_1000568 "9f0753143e2d39b76765b6f38266633f" ;
#     prov:label "T1.mgz" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/mri/T1.mgz" .

# %% [markdown]
# ### Print the PROV-N notation for an entity

# %%
print(e1.get_provn())
# Out:
# entity(niiri:98e3503c1e470eae20bd05b14574d5dc, [prov:label="T1.mgz", fs:relative_path="mri/T1.mgz", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/mri/T1.mgz", obo:MS_1000568="9f0753143e2d39b76765b6f38266633f", nidm:tag="mri", nidm:tag="T1", nidm:tag="mgz", prov:type='nif:nlx_inv_20090243'])

# %% [markdown]
# ### Print Turtle output for the entity

# %%
print(e1.rdf().serialize(format='turtle'))
# Out:
# @prefix ns1: <http://nidm.nidash.org/terms/0.1/> .
# @prefix ns2: <http://www.w3.org/ns/prov#> .
# @prefix ns3: <http://freesurfer.net/fswiki/terms/0.1/> .
# @prefix ns4: <http://purl.obolibrary.org/obo/> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xml: <http://www.w3.org/XML/1998/namespace> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# <http://nidm.nidash.org/iri/98e3503c1e470eae20bd05b14574d5dc> a <http://neurolex.org/wiki/nlx_inv_20090243>,
#         ns2:Entity ;
#     ns3:relative_path "mri/T1.mgz" ;
#     ns1:tag "T1",
#         "mgz",
#         "mri" ;
#     ns4:MS_1000568 "9f0753143e2d39b76765b6f38266633f" ;
#     ns2:label "T1.mgz" ;
#     ns2:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/mri/T1.mgz" .

# %% [markdown]
# ### Explore object references

# %%
print nif.get_uri() + 'nlx_inv_20090243'
print obo.get_uri() + 'MS_1000568'
print niiri.get_uri() + '1cb78d63583c319e68646a4fa5d2d68e'
# Out:
# http://neurolex.org/wiki/nlx_inv_20090243
# http://purl.obolibrary.org/obo/MS_1000568
# http://nidm.nidash.org/iri/1cb78d63583c319e68646a4fa5d2d68e

# %%
print e2.get_provn()
# Out:
# entity(niiri:77fa6a15e90b16a6d035a9739b9a9139, [prov:label="lh.BA6.label", fs:relative_path="label/lh.BA6.label", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/lh.BA6.label", obo:MS_1000568="11bc4b80381b117b996da670a3dcbc13", nidm:tag="label", nidm:tag="lh", nidm:tag="BA6", nidm:tag="label", prov:type='obo:UBERON_0002812', prov:type='obo:UBERON_0006472', prov:type='fs:label_file'])

# %% [markdown]
# ### Terms introduced
#
# fs namespace
#
#     - relative_path
#     - statistics
#     - MT_area
#     - exvivo
#     - label_file
#     - annotation_file
#     - statistic_file
#     - default_parcellation
#     - a2009s_parcellation
#     - color_table
#
# nidm namespace
#
#     - tag

# %% [markdown]
# ### Define a function that manages creating a NI-DM FreeSurfer object

# %%
def encode_fs_directory(g, basedir, project_id, subject_id, n_items=100000):
    """ Convert a FreeSurfer directory to a PROV graph
    """
    # directory collection/catalog
    collection_hash = md5.new(project_id + ':' + subject_id).hexdigest()
    fsdir_collection = g.collection(niiri[collection_hash])
    fsdir_collection.add_extra_attributes({prov.PROV['type']: fs['subject_directory'], 
                                           fs['subject_id']: subject_id})
    i = 0;
    for dirpath, dirnames, filenames in os.walk(os.path.realpath(basedir)):
        for filename in sorted(filenames):
            if filename.startswith('.'):
                continue
            i +=1 
            if i > n_items:
                break
            file2encode = os.path.realpath(os.path.join(dirpath, filename))
            if not os.path.isfile(file2encode):
                print "%s not a file" % file2encode
                continue
            ignore_key_found = False
            for key in ignore_list:
                if key in file2encode:
                    ignore_key_found = True
                    continue
            if ignore_key_found:
                continue
            try:
                entity = create_entity(g, subject_id, file2encode)
                g.hadMember(fsdir_collection, entity.get_identifier())
            except IOError, e:
                print e
    return g

# %% [markdown]
# ### Terms introduced
#
# fs namespace
#
#     - subject_id
#     - subject_directory

# %% [markdown]
# ### Example of generating a NI-DM FreeSurfer Object
#
# This example demonstrates the conversion from [PROV Notation](http://www.w3.org/TR/prov-n/) to RDF. This can also be achieved using the [ProvToolBox](https://github.com/lucmoreau/ProvToolbox), which provides a command line utility for serializing PROV to different syntaxes.

# %%
# location of FreeSurfer $SUBJECTS_DIR
basedir = sdir 
subject_id = 'bert'
project_id = 'nidm'
filename = 'bert.provn'
filename_ttl = 'bert.ttl'
os.unlink(filename)
os.unlink(filename_ttl)

from subprocess import Popen, PIPE

# location of the ProvToolBox commandline conversion utility
graph = prov.ProvBundle()
graph.add_namespace(foaf)
graph.add_namespace(dcterms)
graph.add_namespace(fs)
graph.add_namespace(nidm)
graph.add_namespace(niiri)
graph.add_namespace(obo)
graph.add_namespace(nif)

graph = encode_fs_directory(graph, basedir, project_id, subject_id)
with open(filename, 'wt') as fp:
    fp.writelines(graph.get_provn())
graph.rdf().serialize(filename_ttl, format='turtle')

# %%
cat bert.provn
# Out:
# document
#   prefix foaf <http://xmlns.com/foaf/0.1/>
#   prefix obo <http://purl.obolibrary.org/obo/>
#   prefix fs <http://freesurfer.net/fswiki/terms/0.1/>
#   prefix nif <http://neurolex.org/wiki/>
#   prefix nidm <http://nidm.nidash.org/terms/0.1/>
#   prefix niiri <http://nidm.nidash.org/iri/>
#   prefix dcterms <http://purl.org/dc/terms/>
#
#   entity(niiri:4c735fc66b5e12cdd321d6ed64394c84, [prov:type='prov:Collection', prov:type='fs:subject_directory', fs:subject_id="bert"])
#   entity(niiri:d0dc775e849c4ad4ce696e4744b2951f, [prov:label="BA.ctab", fs:relative_path="label/BA.ctab", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/BA.ctab", obo:MS_1000568="7e9597e6f9170517c69e4c9f3f6a5681", nidm:tag="label", nidm:tag="BA", nidm:tag="ctab", prov:type='obo:UBERON_0013529', prov:type='fs:color_table'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:d0dc775e849c4ad4ce696e4744b2951f)
#   entity(niiri:2b366e5382e19c6d1a6db620c7ef6489, [prov:label="BA.thresh.ctab", fs:relative_path="label/BA.thresh.ctab", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/BA.thresh.ctab", obo:MS_1000568="7e9597e6f9170517c69e4c9f3f6a5681", nidm:tag="label", nidm:tag="BA", nidm:tag="thresh", nidm:tag="ctab", prov:type='obo:UBERON_0013529', prov:type='fs:color_table'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:2b366e5382e19c6d1a6db620c7ef6489)
#   entity(niiri:7dba4b88cb8df248563bfbb9edb74063, [prov:label="aparc.annot.DKTatlas40.ctab", fs:relative_path="label/aparc.annot.DKTatlas40.ctab", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/aparc.annot.DKTatlas40.ctab", obo:MS_1000568="757e7e27742ae27d720f8fc37fbdaf36", nidm:tag="label", nidm:tag="aparc", nidm:tag="annot", nidm:tag="DKTatlas40", nidm:tag="ctab", prov:type='fs:annotation_file', nidm:tag="aparc.annot", prov:type='fs:default_parcellation', prov:type='fs:color_table'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:7dba4b88cb8df248563bfbb9edb74063)
#   entity(niiri:ddbbb0eb79eb892a2273e23009f06e14, [prov:label="aparc.annot.a2009s.ctab", fs:relative_path="label/aparc.annot.a2009s.ctab", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/aparc.annot.a2009s.ctab", obo:MS_1000568="cf32a567746bf18e8b52c323dc152570", nidm:tag="label", nidm:tag="aparc", nidm:tag="annot", nidm:tag="a2009s", nidm:tag="ctab", prov:type='fs:annotation_file', nidm:tag="aparc.annot", prov:type='fs:default_parcellation', prov:type='fs:color_table'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:ddbbb0eb79eb892a2273e23009f06e14)
#   entity(niiri:9384b407bb4a4f378d0cae474e67659f, [prov:label="aparc.annot.ctab", fs:relative_path="label/aparc.annot.ctab", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/aparc.annot.ctab", obo:MS_1000568="757e7e27742ae27d720f8fc37fbdaf36", nidm:tag="label", nidm:tag="aparc", nidm:tag="annot", nidm:tag="ctab", prov:type='fs:annotation_file', nidm:tag="aparc.annot", prov:type='fs:default_parcellation', prov:type='fs:color_table'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:9384b407bb4a4f378d0cae474e67659f)
#   entity(niiri:9ffe4b823aa97c767ef0a359554e58be, [prov:label="lh.BA.annot", fs:relative_path="label/lh.BA.annot", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/lh.BA.annot", obo:MS_1000568="1d7d118b9b674cd13fe1d709718f22b9", nidm:tag="label", nidm:tag="lh", nidm:tag="BA", nidm:tag="annot", prov:type='obo:UBERON_0002812', prov:type='obo:UBERON_0013529', prov:type='fs:annotation_file'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:9ffe4b823aa97c767ef0a359554e58be)
#   entity(niiri:a9fcdcd2a8f13debe80c37b6b3ebd9c4, [prov:label="lh.BA.thresh.annot", fs:relative_path="label/lh.BA.thresh.annot", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/lh.BA.thresh.annot", obo:MS_1000568="f2f963866b54d930ff0016a5aa68d347", nidm:tag="label", nidm:tag="lh", nidm:tag="BA", nidm:tag="thresh", nidm:tag="annot", prov:type='obo:UBERON_0002812', prov:type='obo:UBERON_0013529', prov:type='fs:annotation_file'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:a9fcdcd2a8f13debe80c37b6b3ebd9c4)
#   entity(niiri:dd363fe3630a12ac15033bd833199f25, [prov:label="lh.BA1.label", fs:relative_path="label/lh.BA1.label", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/lh.BA1.label", obo:MS_1000568="d654c9881ce89d37f05426fba262da94", nidm:tag="label", nidm:tag="lh", nidm:tag="BA1", nidm:tag="label", prov:type='obo:UBERON_0002812', prov:type='obo:UBERON_0006099', prov:type='fs:label_file'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:dd363fe3630a12ac15033bd833199f25)
#   entity(niiri:e8fd424fb4cbaf75179d1d6ae4cd6f85, [prov:label="lh.BA1.thresh.label", fs:relative_path="label/lh.BA1.thresh.label", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/lh.BA1.thresh.label", obo:MS_1000568="55ca57c22fd96deb1079bbc7f2437898", nidm:tag="label", nidm:tag="lh", nidm:tag="BA1", nidm:tag="thresh", nidm:tag="label", prov:type='obo:UBERON_0002812', prov:type='obo:UBERON_0006099', prov:type='fs:label_file'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:e8fd424fb4cbaf75179d1d6ae4cd6f85)
#   entity(niiri:6c84604134bf41b96beec503fb96815d, [prov:label="lh.BA2.label", fs:relative_path="label/lh.BA2.label", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/lh.BA2.label", obo:MS_1000568="40ffb1e1e405131d11722a2970333539", nidm:tag="label", nidm:tag="lh", nidm:tag="BA2", nidm:tag="label", prov:type='obo:UBERON_0002812', prov:type='obo:UBERON_0013533', prov:type='fs:label_file'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:6c84604134bf41b96beec503fb96815d)
#   entity(niiri:c5a40e28a03f00c5d79dc08ef78855ed, [prov:label="lh.BA2.thresh.label", fs:relative_path="label/lh.BA2.thresh.label", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/lh.BA2.thresh.label", obo:MS_1000568="768374eb7ea736bed960df2eaf9253ad", nidm:tag="label", nidm:tag="lh", nidm:tag="BA2", nidm:tag="thresh", nidm:tag="label", prov:type='obo:UBERON_0002812', prov:type='obo:UBERON_0013533', prov:type='fs:label_file'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:c5a40e28a03f00c5d79dc08ef78855ed)
#   entity(niiri:339ff642c738308ad9a340b5e66f21d9, [prov:label="lh.BA3a.label", fs:relative_path="label/lh.BA3a.label", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/lh.BA3a.label", obo:MS_1000568="f0068a81a0ebfc72fe54258f0636a910", nidm:tag="label", nidm:tag="lh", nidm:tag="BA3a", nidm:tag="label", prov:type='obo:UBERON_0002812', prov:type='obo:UBERON_0006100', prov:type='obo:FMA_74532', prov:type='fs:label_file'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:339ff642c738308ad9a340b5e66f21d9)
#   entity(niiri:8f8fe6f3269cd7a5b02aee504865b38b, [prov:label="lh.BA3a.thresh.label", fs:relative_path="label/lh.BA3a.thresh.label", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/lh.BA3a.thresh.label", obo:MS_1000568="031c1410eeefa8090cb34e14d333cd0a", nidm:tag="label", nidm:tag="lh", nidm:tag="BA3a", nidm:tag="thresh", nidm:tag="label", prov:type='obo:UBERON_0002812', prov:type='obo:UBERON_0006100', prov:type='obo:FMA_74532', prov:type='fs:label_file'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:8f8fe6f3269cd7a5b02aee504865b38b)
#   entity(niiri:349c21bb9bde7e7dffa7121b653f5df0, [prov:label="lh.BA3b.label", fs:relative_path="label/lh.BA3b.label", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/lh.BA3b.label", obo:MS_1000568="725a30f9ea3fbfccbe4dfd2cfb0e2cc2", nidm:tag="label", nidm:tag="lh", nidm:tag="BA3b", nidm:tag="label", prov:type='obo:UBERON_0002812', prov:type='obo:UBERON_0006100', prov:type='obo:FMA_74533', prov:type='fs:label_file'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:349c21bb9bde7e7dffa7121b653f5df0)
#   entity(niiri:8899d555f7c93d40972763a55de32ed9, [prov:label="lh.BA3b.thresh.label", fs:relative_path="label/lh.BA3b.thresh.label", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/lh.BA3b.thresh.label", obo:MS_1000568="7c63b4f3dae345c7035c18f9a35d9689", nidm:tag="label", nidm:tag="lh", nidm:tag="BA3b", nidm:tag="thresh", nidm:tag="label", prov:type='obo:UBERON_0002812', prov:type='obo:UBERON_0006100', prov:type='obo:FMA_74533', prov:type='fs:label_file'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:8899d555f7c93d40972763a55de32ed9)
#   entity(niiri:d4c0ce3b31f50e0cae45ff6723c88b7a, [prov:label="lh.BA44.label", fs:relative_path="label/lh.BA44.label", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/lh.BA44.label", obo:MS_1000568="76888db724ef4cde7f551b370c8b7aca", nidm:tag="label", nidm:tag="lh", nidm:tag="BA44", nidm:tag="label", prov:type='obo:UBERON_0002812', prov:type='obo:UBERON_0006481', prov:type='fs:label_file'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:d4c0ce3b31f50e0cae45ff6723c88b7a)
#   entity(niiri:87d7e3a411c2e3e3570b1af9130c422b, [prov:label="lh.BA44.thresh.label", fs:relative_path="label/lh.BA44.thresh.label", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/lh.BA44.thresh.label", obo:MS_1000568="d40258a16e11d06997f0a501ff1772cc", nidm:tag="label", nidm:tag="lh", nidm:tag="BA44", nidm:tag="thresh", nidm:tag="label", prov:type='obo:UBERON_0002812', prov:type='obo:UBERON_0006481', prov:type='fs:label_file'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:87d7e3a411c2e3e3570b1af9130c422b)
#   entity(niiri:f83014accee72a41cccac7686922731d, [prov:label="lh.BA45.label", fs:relative_path="label/lh.BA45.label", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/lh.BA45.label", obo:MS_1000568="46dc44f72d7957a168b768b449c4dd0a", nidm:tag="label", nidm:tag="lh", nidm:tag="BA45", nidm:tag="label", prov:type='obo:UBERON_0002812', prov:type='obo:UBERON_0006482', prov:type='fs:label_file'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:f83014accee72a41cccac7686922731d)
#   entity(niiri:046d023f6e731c5a9996ad03cff717b7, [prov:label="lh.BA45.thresh.label", fs:relative_path="label/lh.BA45.thresh.label", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/lh.BA45.thresh.label", obo:MS_1000568="6131431ba45c25032ad27e8b7b53e661", nidm:tag="label", nidm:tag="lh", nidm:tag="BA45", nidm:tag="thresh", nidm:tag="label", prov:type='obo:UBERON_0002812', prov:type='obo:UBERON_0006482', prov:type='fs:label_file'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:046d023f6e731c5a9996ad03cff717b7)
#   entity(niiri:f24ddece62d2167eddd3e552100ce099, [prov:label="lh.BA4a.label", fs:relative_path="label/lh.BA4a.label", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/lh.BA4a.label", obo:MS_1000568="0edcb6599c3016efa9bf974d96686cd3", nidm:tag="label", nidm:tag="lh", nidm:tag="BA4a", nidm:tag="label", prov:type='obo:UBERON_0002812', prov:type='obo:UBERON_0013535', prov:type='obo:FMA_74532', prov:type='fs:label_file'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:f24ddece62d2167eddd3e552100ce099)
#   entity(niiri:b1d13b15fa383178b1ed868d7b5caecd, [prov:label="lh.BA4a.thresh.label", fs:relative_path="label/lh.BA4a.thresh.label", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/lh.BA4a.thresh.label", obo:MS_1000568="2a4e7c160ab32fc5ac33872e01fb9ef0", nidm:tag="label", nidm:tag="lh", nidm:tag="BA4a", nidm:tag="thresh", nidm:tag="label", prov:type='obo:UBERON_0002812', prov:type='obo:UBERON_0013535', prov:type='obo:FMA_74532', prov:type='fs:label_file'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:b1d13b15fa383178b1ed868d7b5caecd)
#   entity(niiri:462206be19ada5752edc24868c5eea47, [prov:label="lh.BA4p.label", fs:relative_path="label/lh.BA4p.label", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/lh.BA4p.label", obo:MS_1000568="54f4629c97ae4bf67e38551b7feab567", nidm:tag="label", nidm:tag="lh", nidm:tag="BA4p", nidm:tag="label", prov:type='obo:UBERON_0002812', prov:type='obo:UBERON_0013535', prov:type='obo:FMA_74533', prov:type='fs:label_file'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:462206be19ada5752edc24868c5eea47)
#   entity(niiri:ffefdab83a950a624d01dd4e543f3442, [prov:label="lh.BA4p.thresh.label", fs:relative_path="label/lh.BA4p.thresh.label", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/lh.BA4p.thresh.label", obo:MS_1000568="26c30b893084e5c1f709b058cffb05e8", nidm:tag="label", nidm:tag="lh", nidm:tag="BA4p", nidm:tag="thresh", nidm:tag="label", prov:type='obo:UBERON_0002812', prov:type='obo:UBERON_0013535', prov:type='obo:FMA_74533', prov:type='fs:label_file'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:ffefdab83a950a624d01dd4e543f3442)
#   entity(niiri:77fa6a15e90b16a6d035a9739b9a9139, [prov:label="lh.BA6.label", fs:relative_path="label/lh.BA6.label", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/lh.BA6.label", obo:MS_1000568="11bc4b80381b117b996da670a3dcbc13", nidm:tag="label", nidm:tag="lh", nidm:tag="BA6", nidm:tag="label", prov:type='obo:UBERON_0002812', prov:type='obo:UBERON_0006472', prov:type='fs:label_file'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:77fa6a15e90b16a6d035a9739b9a9139)
#   entity(niiri:b3f84dfb2d69afcd95c801d59e996c71, [prov:label="lh.BA6.thresh.label", fs:relative_path="label/lh.BA6.thresh.label", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/lh.BA6.thresh.label", obo:MS_1000568="4b54bb3adee1aa74cc6e37fcc397fe03", nidm:tag="label", nidm:tag="lh", nidm:tag="BA6", nidm:tag="thresh", nidm:tag="label", prov:type='obo:UBERON_0002812', prov:type='obo:UBERON_0006472', prov:type='fs:label_file'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:b3f84dfb2d69afcd95c801d59e996c71)
#   entity(niiri:70786d2b1977daa65990bea625c95360, [prov:label="lh.MT.label", fs:relative_path="label/lh.MT.label", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/lh.MT.label", obo:MS_1000568="645fc04c3a18d21fdf5a2f110a44fe38", nidm:tag="label", nidm:tag="lh", nidm:tag="MT", nidm:tag="label", prov:type='obo:UBERON_0002812', prov:type='fs:MT_area', prov:type='fs:label_file'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:70786d2b1977daa65990bea625c95360)
#   entity(niiri:dbd9efb1d117b4635ba23bb6bb0c7579, [prov:label="lh.MT.thresh.label", fs:relative_path="label/lh.MT.thresh.label", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/lh.MT.thresh.label", obo:MS_1000568="af4c9a3b7e55ef1baae4042ebf4b222d", nidm:tag="label", nidm:tag="lh", nidm:tag="MT", nidm:tag="thresh", nidm:tag="label", prov:type='obo:UBERON_0002812', prov:type='fs:MT_area', prov:type='fs:label_file'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:dbd9efb1d117b4635ba23bb6bb0c7579)
#   entity(niiri:c1f4d75669fdca68a7af3f48c414272f, [prov:label="lh.V1.label", fs:relative_path="label/lh.V1.label", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/lh.V1.label", obo:MS_1000568="7d8415d770a914e819043dfe649d1057", nidm:tag="label", nidm:tag="lh", nidm:tag="V1", nidm:tag="label", prov:type='obo:UBERON_0002812', prov:type='obo:UBERON_0002436', prov:type='fs:label_file'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:c1f4d75669fdca68a7af3f48c414272f)
#   entity(niiri:53ccaf1cc86339adb45d0615046401d1, [prov:label="lh.V1.thresh.label", fs:relative_path="label/lh.V1.thresh.label", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/lh.V1.thresh.label", obo:MS_1000568="914c8f6350979301689f7b6924477292", nidm:tag="label", nidm:tag="lh", nidm:tag="V1", nidm:tag="thresh", nidm:tag="label", prov:type='obo:UBERON_0002812', prov:type='obo:UBERON_0002436', prov:type='fs:label_file'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:53ccaf1cc86339adb45d0615046401d1)
#   entity(niiri:5a64c02a723abd5c0ee0a103c55e820d, [prov:label="lh.V2.label", fs:relative_path="label/lh.V2.label", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/lh.V2.label", obo:MS_1000568="4d54534c9faa12ff6b3758821c18a4b2", nidm:tag="label", nidm:tag="lh", nidm:tag="V2", nidm:tag="label", prov:type='obo:UBERON_0002812', prov:type='obo:UBERON_0006473', prov:type='fs:label_file'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:5a64c02a723abd5c0ee0a103c55e820d)
#   entity(niiri:604221dfc933c467e9a44a35995ea0be, [prov:label="lh.V2.thresh.label", fs:relative_path="label/lh.V2.thresh.label", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/lh.V2.thresh.label", obo:MS_1000568="0765914a96848a91c38e46faa129f912", nidm:tag="label", nidm:tag="lh", nidm:tag="V2", nidm:tag="thresh", nidm:tag="label", prov:type='obo:UBERON_0002812', prov:type='obo:UBERON_0006473', prov:type='fs:label_file'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:604221dfc933c467e9a44a35995ea0be)
#   entity(niiri:605a35879d4d51d2789c8633582ebec0, [prov:label="lh.aparc.DKTatlas40.annot", fs:relative_path="label/lh.aparc.DKTatlas40.annot", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/lh.aparc.DKTatlas40.annot", obo:MS_1000568="205a1dcd0170f4b0e69db47ed0076c1a", nidm:tag="label", nidm:tag="lh", nidm:tag="aparc", nidm:tag="DKTatlas40", nidm:tag="annot", prov:type='obo:UBERON_0002812', prov:type='fs:annotation_file'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:605a35879d4d51d2789c8633582ebec0)
#   entity(niiri:a032a239bd0bd470443699b5af19af48, [prov:label="lh.aparc.a2009s.annot", fs:relative_path="label/lh.aparc.a2009s.annot", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/lh.aparc.a2009s.annot", obo:MS_1000568="093f7ada7c48bd773b5ea9ab4b6e1a4b", nidm:tag="label", nidm:tag="lh", nidm:tag="aparc", nidm:tag="a2009s", nidm:tag="annot", prov:type='obo:UBERON_0002812', prov:type='fs:annotation_file', nidm:tag="aparc.a2009s", prov:type='fs:a2009s_parcellation'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:a032a239bd0bd470443699b5af19af48)
#   entity(niiri:56098ec2f130a168f0339e4d311ea100, [prov:label="lh.aparc.annot", fs:relative_path="label/lh.aparc.annot", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/lh.aparc.annot", obo:MS_1000568="284a638bc51f53716978577d4382b675", nidm:tag="label", nidm:tag="lh", nidm:tag="aparc", nidm:tag="annot", prov:type='obo:UBERON_0002812', prov:type='fs:annotation_file', nidm:tag="aparc.annot", prov:type='fs:default_parcellation'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:56098ec2f130a168f0339e4d311ea100)
#   entity(niiri:77992da44ec093d4e6a55999646e405a, [prov:label="lh.bert_ref.aparc.a2009s.annot", fs:relative_path="label/lh.", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/lh.bert_ref.aparc.a2009s.annot", obo:MS_1000568="3d3e65c8b484136f4e9d409e910a174c", nidm:tag="label", nidm:tag="lh", nidm:tag="", prov:type='obo:UBERON_0002812', nidm:tag="annot", prov:type='fs:annotation_file', nidm:tag="aparc.a2009s", prov:type='fs:a2009s_parcellation'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:77992da44ec093d4e6a55999646e405a)
#   entity(niiri:34259316e4577472b15e1c2fa018a8fc, [prov:label="lh.bert_ref.aparc.annot", fs:relative_path="label/lh.", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/lh.bert_ref.aparc.annot", obo:MS_1000568="42934f498b15edbbcafb63bcf079b528", nidm:tag="label", nidm:tag="lh", nidm:tag="", prov:type='obo:UBERON_0002812', nidm:tag="annot", prov:type='fs:annotation_file', nidm:tag="aparc.annot", prov:type='fs:default_parcellation'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:34259316e4577472b15e1c2fa018a8fc)
#   entity(niiri:13fd5ed7bf9dee1ca7427683d3b111fb, [prov:label="lh.cortex.label", fs:relative_path="label/lh.cortex.label", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/lh.cortex.label", obo:MS_1000568="23a9a88da7c4572d61875b504eec1830", nidm:tag="label", nidm:tag="lh", nidm:tag="cortex", nidm:tag="label", prov:type='obo:UBERON_0002812', prov:type='fs:label_file', prov:type='obo:UBERON_0000956'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:13fd5ed7bf9dee1ca7427683d3b111fb)
#   entity(niiri:9da1d217df07aa2772cda4b502fd881c, [prov:label="lh.entorhinal_exvivo.label", fs:relative_path="label/lh.entorhinal_exvivo.label", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/lh.entorhinal_exvivo.label", obo:MS_1000568="c1166e63550a60d055ffe1dcc1bd91f0", nidm:tag="label", nidm:tag="lh", nidm:tag="entorhinal_exvivo", nidm:tag="label", prov:type='obo:UBERON_0002812', nidm:tag="rh", prov:type='obo:UBERON_0002813', nidm:tag="entorhinal", prov:type='obo:UBERON_0002728', nidm:tag="exvivo", prov:type='fs:exvivo', prov:type='fs:label_file'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:9da1d217df07aa2772cda4b502fd881c)
#   entity(niiri:5f20cadb89821914cc050f529d279b8a, [prov:label="lh.overlap.annot", fs:relative_path="label/lh.overlap.annot", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/lh.overlap.annot", obo:MS_1000568="75e637e3fb0305d751e9db906b33151d", nidm:tag="label", nidm:tag="lh", nidm:tag="overlap", nidm:tag="annot", prov:type='obo:UBERON_0002812', prov:type='fs:annotation_file'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:5f20cadb89821914cc050f529d279b8a)
#   entity(niiri:6f23ecc532a81b5d421365630915f5f3, [prov:label="lh.perirhinal.label", fs:relative_path="label/lh.perirhinal.label", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/lh.perirhinal.label", obo:MS_1000568="0f1f582c5e74372b405a3f42764d45bd", nidm:tag="label", nidm:tag="lh", nidm:tag="perirhinal", nidm:tag="label", prov:type='obo:UBERON_0002812', nidm:tag="rh", prov:type='obo:UBERON_0002813', prov:type='fs:label_file'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:6f23ecc532a81b5d421365630915f5f3)
#   entity(niiri:fc102be99c96b1d96d9fad68b0678112, [prov:label="rh.BA.annot", fs:relative_path="label/rh.BA.annot", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/rh.BA.annot", obo:MS_1000568="4eeb87bf43ac7376f85d830386e1573d", nidm:tag="label", nidm:tag="rh", nidm:tag="BA", nidm:tag="annot", prov:type='obo:UBERON_0002813', prov:type='obo:UBERON_0013529', prov:type='fs:annotation_file'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:fc102be99c96b1d96d9fad68b0678112)
#   entity(niiri:5cdcf5e5fc16eca7de43eb5321799794, [prov:label="rh.BA.thresh.annot", fs:relative_path="label/rh.BA.thresh.annot", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/rh.BA.thresh.annot", obo:MS_1000568="e897f5bcef69bef4e4f6225e1578e9cd", nidm:tag="label", nidm:tag="rh", nidm:tag="BA", nidm:tag="thresh", nidm:tag="annot", prov:type='obo:UBERON_0002813', prov:type='obo:UBERON_0013529', prov:type='fs:annotation_file'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:5cdcf5e5fc16eca7de43eb5321799794)
#   entity(niiri:84d65e935ef6680b0df23387a7079b3e, [prov:label="rh.BA1.label", fs:relative_path="label/rh.BA1.label", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/rh.BA1.label", obo:MS_1000568="1c9f14b1e893977a3ed405ec4b41dede", nidm:tag="label", nidm:tag="rh", nidm:tag="BA1", nidm:tag="label", prov:type='obo:UBERON_0002813', prov:type='obo:UBERON_0006099', prov:type='fs:label_file'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:84d65e935ef6680b0df23387a7079b3e)
#   entity(niiri:e3b476bc9782cd09cc0e0bf8bda32d2a, [prov:label="rh.BA1.thresh.label", fs:relative_path="label/rh.BA1.thresh.label", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/rh.BA1.thresh.label", obo:MS_1000568="fbfb267468259b8372c77bb93b7ee9bc", nidm:tag="label", nidm:tag="rh", nidm:tag="BA1", nidm:tag="thresh", nidm:tag="label", prov:type='obo:UBERON_0002813', prov:type='obo:UBERON_0006099', prov:type='fs:label_file'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:e3b476bc9782cd09cc0e0bf8bda32d2a)
#   entity(niiri:1e061fffb8ba56bc7b397ccaafef1bee, [prov:label="rh.BA2.label", fs:relative_path="label/rh.BA2.label", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/rh.BA2.label", obo:MS_1000568="76957226f4fa672c881d598e549292a1", nidm:tag="label", nidm:tag="rh", nidm:tag="BA2", nidm:tag="label", prov:type='obo:UBERON_0002813', prov:type='obo:UBERON_0013533', prov:type='fs:label_file'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:1e061fffb8ba56bc7b397ccaafef1bee)
#   entity(niiri:d679bd9a86a5bb4e266187d404f83ce1, [prov:label="rh.BA2.thresh.label", fs:relative_path="label/rh.BA2.thresh.label", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/rh.BA2.thresh.label", obo:MS_1000568="cbdfcb2763dd4b021f42b61f82465edb", nidm:tag="label", nidm:tag="rh", nidm:tag="BA2", nidm:tag="thresh", nidm:tag="label", prov:type='obo:UBERON_0002813', prov:type='obo:UBERON_0013533', prov:type='fs:label_file'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:d679bd9a86a5bb4e266187d404f83ce1)
#   entity(niiri:bab3c879108c4fb364041a45645d7f58, [prov:label="rh.BA3a.label", fs:relative_path="label/rh.BA3a.label", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/rh.BA3a.label", obo:MS_1000568="ef892f39e06cd662dcad217f8a856493", nidm:tag="label", nidm:tag="rh", nidm:tag="BA3a", nidm:tag="label", prov:type='obo:UBERON_0002813', prov:type='obo:UBERON_0006100', prov:type='obo:FMA_74532', prov:type='fs:label_file'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:bab3c879108c4fb364041a45645d7f58)
#   entity(niiri:541c304e148fd0eaf3c6d1b495f79a3b, [prov:label="rh.BA3a.thresh.label", fs:relative_path="label/rh.BA3a.thresh.label", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/rh.BA3a.thresh.label", obo:MS_1000568="3f96844120234b5a289a6159163b6992", nidm:tag="label", nidm:tag="rh", nidm:tag="BA3a", nidm:tag="thresh", nidm:tag="label", prov:type='obo:UBERON_0002813', prov:type='obo:UBERON_0006100', prov:type='obo:FMA_74532', prov:type='fs:label_file'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:541c304e148fd0eaf3c6d1b495f79a3b)
#   entity(niiri:326671f0db0e02f47f915c3198d1fa98, [prov:label="rh.BA3b.label", fs:relative_path="label/rh.BA3b.label", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/rh.BA3b.label", obo:MS_1000568="4caf93a3b5e977e40ea3ca55e0f3149e", nidm:tag="label", nidm:tag="rh", nidm:tag="BA3b", nidm:tag="label", prov:type='obo:UBERON_0002813', prov:type='obo:UBERON_0006100', prov:type='obo:FMA_74533', prov:type='fs:label_file'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:326671f0db0e02f47f915c3198d1fa98)
#   entity(niiri:6e567a523c4006d9a68c6b0ab001bbe3, [prov:label="rh.BA3b.thresh.label", fs:relative_path="label/rh.BA3b.thresh.label", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/rh.BA3b.thresh.label", obo:MS_1000568="1912b5389b3294ca76785be31eca53fa", nidm:tag="label", nidm:tag="rh", nidm:tag="BA3b", nidm:tag="thresh", nidm:tag="label", prov:type='obo:UBERON_0002813', prov:type='obo:UBERON_0006100', prov:type='obo:FMA_74533', prov:type='fs:label_file'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:6e567a523c4006d9a68c6b0ab001bbe3)
#   entity(niiri:e8e0afd0b3eb870e1afeb4542d02ca19, [prov:label="rh.BA44.label", fs:relative_path="label/rh.BA44.label", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/rh.BA44.label", obo:MS_1000568="e363ae86aaeeabb2c3f782f04e5f0462", nidm:tag="label", nidm:tag="rh", nidm:tag="BA44", nidm:tag="label", prov:type='obo:UBERON_0002813', prov:type='obo:UBERON_0006481', prov:type='fs:label_file'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:e8e0afd0b3eb870e1afeb4542d02ca19)
#   entity(niiri:f17b8ed28e191621ead8f898beacbacb, [prov:label="rh.BA44.thresh.label", fs:relative_path="label/rh.BA44.thresh.label", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/rh.BA44.thresh.label", obo:MS_1000568="b929ccb205aff5a1faf9921e519ba180", nidm:tag="label", nidm:tag="rh", nidm:tag="BA44", nidm:tag="thresh", nidm:tag="label", prov:type='obo:UBERON_0002813', prov:type='obo:UBERON_0006481', prov:type='fs:label_file'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:f17b8ed28e191621ead8f898beacbacb)
#   entity(niiri:d9b8ef2d0c2f8b8fe95f4b51b3e358c2, [prov:label="rh.BA45.label", fs:relative_path="label/rh.BA45.label", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/rh.BA45.label", obo:MS_1000568="ed1a23d768905d4c7dc772d275dc8521", nidm:tag="label", nidm:tag="rh", nidm:tag="BA45", nidm:tag="label", prov:type='obo:UBERON_0002813', prov:type='obo:UBERON_0006482', prov:type='fs:label_file'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:d9b8ef2d0c2f8b8fe95f4b51b3e358c2)
#   entity(niiri:8a7c05c533dfb08b4d7041ec0978d3c3, [prov:label="rh.BA45.thresh.label", fs:relative_path="label/rh.BA45.thresh.label", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/rh.BA45.thresh.label", obo:MS_1000568="b299b8ad72f18d944142953c8e6ce692", nidm:tag="label", nidm:tag="rh", nidm:tag="BA45", nidm:tag="thresh", nidm:tag="label", prov:type='obo:UBERON_0002813', prov:type='obo:UBERON_0006482', prov:type='fs:label_file'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:8a7c05c533dfb08b4d7041ec0978d3c3)
#   entity(niiri:10b55c9964d4b5e1844ff710b949a1a3, [prov:label="rh.BA4a.label", fs:relative_path="label/rh.BA4a.label", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/rh.BA4a.label", obo:MS_1000568="08c7e1544de10f421cc45ec91f73275f", nidm:tag="label", nidm:tag="rh", nidm:tag="BA4a", nidm:tag="label", prov:type='obo:UBERON_0002813', prov:type='obo:UBERON_0013535', prov:type='obo:FMA_74532', prov:type='fs:label_file'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:10b55c9964d4b5e1844ff710b949a1a3)
#   entity(niiri:bc289bb818e33fbc19527dbf67f9e26d, [prov:label="rh.BA4a.thresh.label", fs:relative_path="label/rh.BA4a.thresh.label", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/rh.BA4a.thresh.label", obo:MS_1000568="19cdc1b4dbe4ee3480f76b094851b736", nidm:tag="label", nidm:tag="rh", nidm:tag="BA4a", nidm:tag="thresh", nidm:tag="label", prov:type='obo:UBERON_0002813', prov:type='obo:UBERON_0013535', prov:type='obo:FMA_74532', prov:type='fs:label_file'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:bc289bb818e33fbc19527dbf67f9e26d)
#   entity(niiri:7efddb7b50840d84c981dee4221f71ac, [prov:label="rh.BA4p.label", fs:relative_path="label/rh.BA4p.label", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/rh.BA4p.label", obo:MS_1000568="b7ee11fae80dc1a206fac389885007e2", nidm:tag="label", nidm:tag="rh", nidm:tag="BA4p", nidm:tag="label", prov:type='obo:UBERON_0002813', prov:type='obo:UBERON_0013535', prov:type='obo:FMA_74533', prov:type='fs:label_file'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:7efddb7b50840d84c981dee4221f71ac)
#   entity(niiri:e4bdbc14a29e53dc4168b90a67815464, [prov:label="rh.BA4p.thresh.label", fs:relative_path="label/rh.BA4p.thresh.label", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/rh.BA4p.thresh.label", obo:MS_1000568="f8c65912f445313f4f07255655b5b76f", nidm:tag="label", nidm:tag="rh", nidm:tag="BA4p", nidm:tag="thresh", nidm:tag="label", prov:type='obo:UBERON_0002813', prov:type='obo:UBERON_0013535', prov:type='obo:FMA_74533', prov:type='fs:label_file'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:e4bdbc14a29e53dc4168b90a67815464)
#   entity(niiri:e74b0eb67811e6e5c8d16fd5dcde439a, [prov:label="rh.BA6.label", fs:relative_path="label/rh.BA6.label", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/rh.BA6.label", obo:MS_1000568="be4d900dea858518a40f47af1ca7c6da", nidm:tag="label", nidm:tag="rh", nidm:tag="BA6", nidm:tag="label", prov:type='obo:UBERON_0002813', prov:type='obo:UBERON_0006472', prov:type='fs:label_file'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:e74b0eb67811e6e5c8d16fd5dcde439a)
#   entity(niiri:577222cf99c2620301973d2e1ac2250a, [prov:label="rh.BA6.thresh.label", fs:relative_path="label/rh.BA6.thresh.label", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/rh.BA6.thresh.label", obo:MS_1000568="dc3d05d487b33cbe6fd69ef6d3aa319d", nidm:tag="label", nidm:tag="rh", nidm:tag="BA6", nidm:tag="thresh", nidm:tag="label", prov:type='obo:UBERON_0002813', prov:type='obo:UBERON_0006472', prov:type='fs:label_file'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:577222cf99c2620301973d2e1ac2250a)
#   entity(niiri:dc749cf5b0a66f3fa8314bc5bbbd5cd5, [prov:label="rh.MT.label", fs:relative_path="label/rh.MT.label", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/rh.MT.label", obo:MS_1000568="b29d3707cd0d28f0c0601e1fb5ba48ea", nidm:tag="label", nidm:tag="rh", nidm:tag="MT", nidm:tag="label", prov:type='obo:UBERON_0002813', prov:type='fs:MT_area', prov:type='fs:label_file'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:dc749cf5b0a66f3fa8314bc5bbbd5cd5)
#   entity(niiri:19abf59f432812703ea3ae9d28edcec1, [prov:label="rh.MT.thresh.label", fs:relative_path="label/rh.MT.thresh.label", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/rh.MT.thresh.label", obo:MS_1000568="b2740e2b696f976037d846594d21bfb8", nidm:tag="label", nidm:tag="rh", nidm:tag="MT", nidm:tag="thresh", nidm:tag="label", prov:type='obo:UBERON_0002813', prov:type='fs:MT_area', prov:type='fs:label_file'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:19abf59f432812703ea3ae9d28edcec1)
#   entity(niiri:aa4dc4ff53e7678ff596593cc70f1aa0, [prov:label="rh.V1.label", fs:relative_path="label/rh.V1.label", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/rh.V1.label", obo:MS_1000568="89a65f0f8654eb3d9f98fd6da557b614", nidm:tag="label", nidm:tag="rh", nidm:tag="V1", nidm:tag="label", prov:type='obo:UBERON_0002813', prov:type='obo:UBERON_0002436', prov:type='fs:label_file'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:aa4dc4ff53e7678ff596593cc70f1aa0)
#   entity(niiri:82a563766740515cb1d30ed339454f84, [prov:label="rh.V1.thresh.label", fs:relative_path="label/rh.V1.thresh.label", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/rh.V1.thresh.label", obo:MS_1000568="7b57d0c5edb45d4af4a326d3c3667da7", nidm:tag="label", nidm:tag="rh", nidm:tag="V1", nidm:tag="thresh", nidm:tag="label", prov:type='obo:UBERON_0002813', prov:type='obo:UBERON_0002436', prov:type='fs:label_file'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:82a563766740515cb1d30ed339454f84)
#   entity(niiri:781299dd32579c3673688b386f83b016, [prov:label="rh.V2.label", fs:relative_path="label/rh.V2.label", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/rh.V2.label", obo:MS_1000568="368c9f1616650fa008307ee573014d3a", nidm:tag="label", nidm:tag="rh", nidm:tag="V2", nidm:tag="label", prov:type='obo:UBERON_0002813', prov:type='obo:UBERON_0006473', prov:type='fs:label_file'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:781299dd32579c3673688b386f83b016)
#   entity(niiri:76e7b9f0d70cc31627e7865c66b1bb45, [prov:label="rh.V2.thresh.label", fs:relative_path="label/rh.V2.thresh.label", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/rh.V2.thresh.label", obo:MS_1000568="d037d5096ab2cd50aa187dd13e254e93", nidm:tag="label", nidm:tag="rh", nidm:tag="V2", nidm:tag="thresh", nidm:tag="label", prov:type='obo:UBERON_0002813', prov:type='obo:UBERON_0006473', prov:type='fs:label_file'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:76e7b9f0d70cc31627e7865c66b1bb45)
#   entity(niiri:aa3ee7d6950e8d1d6e788d45c7d2578f, [prov:label="rh.aparc.DKTatlas40.annot", fs:relative_path="label/rh.aparc.DKTatlas40.annot", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/rh.aparc.DKTatlas40.annot", obo:MS_1000568="bcc612f4a937cd069957256a01733a49", nidm:tag="label", nidm:tag="rh", nidm:tag="aparc", nidm:tag="DKTatlas40", nidm:tag="annot", prov:type='obo:UBERON_0002813', prov:type='fs:annotation_file'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:aa3ee7d6950e8d1d6e788d45c7d2578f)
#   entity(niiri:8a3f6a42da7757f97d8fb27ea655d65f, [prov:label="rh.aparc.a2009s.annot", fs:relative_path="label/rh.aparc.a2009s.annot", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/rh.aparc.a2009s.annot", obo:MS_1000568="dc64bf8cf4b25c6964bbdd510f9967ff", nidm:tag="label", nidm:tag="rh", nidm:tag="aparc", nidm:tag="a2009s", nidm:tag="annot", prov:type='obo:UBERON_0002813', prov:type='fs:annotation_file', nidm:tag="aparc.a2009s", prov:type='fs:a2009s_parcellation'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:8a3f6a42da7757f97d8fb27ea655d65f)
#   entity(niiri:41c46a0485b890662a5b57c25b86bfe1, [prov:label="rh.aparc.annot", fs:relative_path="label/rh.aparc.annot", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/rh.aparc.annot", obo:MS_1000568="246cf306d4d45f26e1291441502dc1c7", nidm:tag="label", nidm:tag="rh", nidm:tag="aparc", nidm:tag="annot", prov:type='obo:UBERON_0002813', prov:type='fs:annotation_file', nidm:tag="aparc.annot", prov:type='fs:default_parcellation'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:41c46a0485b890662a5b57c25b86bfe1)
#   entity(niiri:2cad28fde197143144da344d53bc363b, [prov:label="rh.bert_ref.aparc.a2009s.annot", fs:relative_path="label/rh.", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/rh.bert_ref.aparc.a2009s.annot", obo:MS_1000568="86ec7fffdc250d84a353c33d05116f1a", nidm:tag="label", nidm:tag="rh", nidm:tag="", prov:type='obo:UBERON_0002813', nidm:tag="annot", prov:type='fs:annotation_file', nidm:tag="aparc.a2009s", prov:type='fs:a2009s_parcellation'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:2cad28fde197143144da344d53bc363b)
#   entity(niiri:e66274c5acccbacf00a00da0a7d1e849, [prov:label="rh.bert_ref.aparc.annot", fs:relative_path="label/rh.", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/rh.bert_ref.aparc.annot", obo:MS_1000568="11a6e5e23dfb06075ce85be7cca9e190", nidm:tag="label", nidm:tag="rh", nidm:tag="", prov:type='obo:UBERON_0002813', nidm:tag="annot", prov:type='fs:annotation_file', nidm:tag="aparc.annot", prov:type='fs:default_parcellation'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:e66274c5acccbacf00a00da0a7d1e849)
#   entity(niiri:59d49f9f0587bd899c0b44a78187c6e6, [prov:label="rh.cortex.label", fs:relative_path="label/rh.cortex.label", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/rh.cortex.label", obo:MS_1000568="296ce44a7abb28cf8bb8840fa4f7fd24", nidm:tag="label", nidm:tag="rh", nidm:tag="cortex", nidm:tag="label", prov:type='obo:UBERON_0002813', prov:type='fs:label_file', prov:type='obo:UBERON_0000956'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:59d49f9f0587bd899c0b44a78187c6e6)
#   entity(niiri:5af75b6147f67b347e7d0389f0c7f1f5, [prov:label="rh.entorhinal_exvivo.label", fs:relative_path="label/rh.entorhinal_exvivo.label", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/rh.entorhinal_exvivo.label", obo:MS_1000568="fbddbeec08291c70da044a96c62422a6", nidm:tag="label", nidm:tag="rh", nidm:tag="entorhinal_exvivo", nidm:tag="label", prov:type='obo:UBERON_0002813', nidm:tag="entorhinal", prov:type='obo:UBERON_0002728', nidm:tag="exvivo", prov:type='fs:exvivo', prov:type='fs:label_file'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:5af75b6147f67b347e7d0389f0c7f1f5)
#   entity(niiri:104c799c20720f4a5a279fb45256827f, [prov:label="rh.overlap.annot", fs:relative_path="label/rh.overlap.annot", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/rh.overlap.annot", obo:MS_1000568="b06c02da48bd4ca2137aaa6a635eff3e", nidm:tag="label", nidm:tag="rh", nidm:tag="overlap", nidm:tag="annot", prov:type='obo:UBERON_0002813', prov:type='fs:annotation_file'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:104c799c20720f4a5a279fb45256827f)
#   entity(niiri:a8cd7fae0041f9dca225798a2ecf0f47, [prov:label="rh.perirhinal.label", fs:relative_path="label/rh.perirhinal.label", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/rh.perirhinal.label", obo:MS_1000568="f5adadfa852d7fcb8ebc47614a5bc6fc", nidm:tag="label", nidm:tag="rh", nidm:tag="perirhinal", nidm:tag="label", prov:type='obo:UBERON_0002813', prov:type='fs:label_file'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:a8cd7fae0041f9dca225798a2ecf0f47)
#   entity(niiri:98e3503c1e470eae20bd05b14574d5dc, [prov:label="T1.mgz", fs:relative_path="mri/T1.mgz", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/mri/T1.mgz", obo:MS_1000568="9f0753143e2d39b76765b6f38266633f", nidm:tag="mri", nidm:tag="T1", nidm:tag="mgz", prov:type='nif:nlx_inv_20090243'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:98e3503c1e470eae20bd05b14574d5dc)
#   entity(niiri:3b46f47836725704a8109ceadce071d1, [prov:label="aparc+aseg.mgz", fs:relative_path="mri/aparc+aseg.mgz", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/mri/aparc+aseg.mgz", obo:MS_1000568="3af945134447d04315fe973ea89cda30", nidm:tag="mri", nidm:tag="aparc+aseg", nidm:tag="mgz"])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:3b46f47836725704a8109ceadce071d1)
#   entity(niiri:d9f229a9215e69e028097dbdb13c8505, [prov:label="aparc.a2009s+aseg.mgz", fs:relative_path="mri/aparc.a2009s+aseg.mgz", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/mri/aparc.a2009s+aseg.mgz", obo:MS_1000568="8d8dbcf067eef346558520134cd96a7f", nidm:tag="mri", nidm:tag="aparc", nidm:tag="a2009s+aseg", nidm:tag="mgz", nidm:tag="aparc.a2009s", prov:type='fs:a2009s_parcellation'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:d9f229a9215e69e028097dbdb13c8505)
#   entity(niiri:29ebaf4436f4b678498510523efd11ee, [prov:label="aseg.auto.mgz", fs:relative_path="mri/aseg.auto.mgz", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/mri/aseg.auto.mgz", obo:MS_1000568="0d6031c46364175255fdfe6c03364a1a", nidm:tag="mri", nidm:tag="aseg", nidm:tag="auto", nidm:tag="mgz"])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:29ebaf4436f4b678498510523efd11ee)
#   entity(niiri:4fcfea889bb4caa903b59375580a3c47, [prov:label="aseg.auto_noCCseg.label_intensities.txt", fs:relative_path="mri/aseg.auto_noCCseg.label_intensities.txt", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/mri/aseg.auto_noCCseg.label_intensities.txt", obo:MS_1000568="4f2ba800b6bfa137fb7b67028bb18c07", nidm:tag="mri", nidm:tag="aseg", nidm:tag="auto_noCCseg", nidm:tag="label_intensities", nidm:tag="txt", nidm:tag="label", prov:type='fs:label_file'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:4fcfea889bb4caa903b59375580a3c47)
#   entity(niiri:17859dc1fec1dbc394158949b14cf856, [prov:label="aseg.auto_noCCseg.mgz", fs:relative_path="mri/aseg.auto_noCCseg.mgz", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/mri/aseg.auto_noCCseg.mgz", obo:MS_1000568="013dce69a79c2f443e3272f207ea6eb1", nidm:tag="mri", nidm:tag="aseg", nidm:tag="auto_noCCseg", nidm:tag="mgz"])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:17859dc1fec1dbc394158949b14cf856)
# ...
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:af5cd1684358198c875a0e9e0f547b67)
#   entity(niiri:b975b49bd3b441c032505ce12e8ef120, [prov:label="rh.curv", fs:relative_path="surf/rh.curv", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/surf/rh.curv", obo:MS_1000568="0e7254e119088cea79674da84f9458f3", nidm:tag="surf", nidm:tag="rh", nidm:tag="curv", prov:type='obo:UBERON_0002813'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:b975b49bd3b441c032505ce12e8ef120)
#   entity(niiri:53fd1c92fc82620aac2e40460312a65d, [prov:label="rh.curv.pial", fs:relative_path="surf/rh.curv.pial", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/surf/rh.curv.pial", obo:MS_1000568="d4ec066e97c6f3a5e4270bff851e66d4", nidm:tag="surf", nidm:tag="rh", nidm:tag="curv", nidm:tag="pial", prov:type='obo:UBERON_0002813'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:53fd1c92fc82620aac2e40460312a65d)
#   entity(niiri:034aff59b343346cd655247e6a6ac94e, [prov:label="rh.defect_borders", fs:relative_path="surf/rh.defect_borders", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/surf/rh.defect_borders", obo:MS_1000568="7bb15f9c44bb47facca09b1cdb6f6d13", nidm:tag="surf", nidm:tag="rh", nidm:tag="defect_borders", prov:type='obo:UBERON_0002813'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:034aff59b343346cd655247e6a6ac94e)
#   entity(niiri:a8d3a15b84c9434ce2626ecc5b401422, [prov:label="rh.defect_chull", fs:relative_path="surf/rh.defect_chull", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/surf/rh.defect_chull", obo:MS_1000568="576eef348dc23236db67e71305e8aa9b", nidm:tag="surf", nidm:tag="rh", nidm:tag="defect_chull", prov:type='obo:UBERON_0002813'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:a8d3a15b84c9434ce2626ecc5b401422)
#   entity(niiri:c40e5a3cd50177f116e39a27e1797802, [prov:label="rh.defect_labels", fs:relative_path="surf/rh.defect_labels", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/surf/rh.defect_labels", obo:MS_1000568="fef4202979ebde09e9bf2cbff12fb359", nidm:tag="surf", nidm:tag="rh", nidm:tag="defect_labels", prov:type='obo:UBERON_0002813', nidm:tag="label", prov:type='fs:label_file'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:c40e5a3cd50177f116e39a27e1797802)
#   entity(niiri:4017883bb149c321b04e7ab7e2bb0808, [prov:label="rh.inflated", fs:relative_path="surf/rh.inflated", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/surf/rh.inflated", obo:MS_1000568="4ae44899a83b62f4c7486f493390af47", nidm:tag="surf", nidm:tag="rh", nidm:tag="inflated", prov:type='obo:UBERON_0002813'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:4017883bb149c321b04e7ab7e2bb0808)
#   entity(niiri:6924ba2161bd0b505f68b81232d82b33, [prov:label="rh.inflated.H", fs:relative_path="surf/rh.inflated.H", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/surf/rh.inflated.H", obo:MS_1000568="877ce5c5dc4b578d01a833ed037a2600", nidm:tag="surf", nidm:tag="rh", nidm:tag="inflated", nidm:tag="H", prov:type='obo:UBERON_0002813'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:6924ba2161bd0b505f68b81232d82b33)
#   entity(niiri:44b44116d43395e32b31dbc1c48c99d6, [prov:label="rh.inflated.K", fs:relative_path="surf/rh.inflated.K", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/surf/rh.inflated.K", obo:MS_1000568="c711a6c2bca0b9744f2ddfd8c2b25e46", nidm:tag="surf", nidm:tag="rh", nidm:tag="inflated", nidm:tag="K", prov:type='obo:UBERON_0002813'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:44b44116d43395e32b31dbc1c48c99d6)
#   entity(niiri:c335571efa76cb400cbe5846eb579fa3, [prov:label="rh.inflated.nofix", fs:relative_path="surf/rh.inflated.nofix", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/surf/rh.inflated.nofix", obo:MS_1000568="5707e96558d2bf11c96e063d5b91e2ae", nidm:tag="surf", nidm:tag="rh", nidm:tag="inflated", nidm:tag="nofix", prov:type='obo:UBERON_0002813'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:c335571efa76cb400cbe5846eb579fa3)
#   entity(niiri:6fa1444aea376047e54b10b5366b7c21, [prov:label="rh.jacobian_white", fs:relative_path="surf/rh.jacobian_white", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/surf/rh.jacobian_white", obo:MS_1000568="f88be25eb79f802aa505a2880c99fe13", nidm:tag="surf", nidm:tag="rh", nidm:tag="jacobian_white", prov:type='obo:UBERON_0002813'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:6fa1444aea376047e54b10b5366b7c21)
#   entity(niiri:fc94feae3198f5cfe59be3b41a26bee4, [prov:label="rh.orig", fs:relative_path="surf/rh.orig", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/surf/rh.orig", obo:MS_1000568="2a51bc48ee1d3f715d9646774c2801ff", nidm:tag="surf", nidm:tag="rh", nidm:tag="orig", prov:type='obo:UBERON_0002813'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:fc94feae3198f5cfe59be3b41a26bee4)
#   entity(niiri:3966c3a9a3e9ad3eb8448c2262742166, [prov:label="rh.orig.nofix", fs:relative_path="surf/rh.orig.nofix", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/surf/rh.orig.nofix", obo:MS_1000568="11aa918755415bc632be33fa21e1ee32", nidm:tag="surf", nidm:tag="rh", nidm:tag="orig", nidm:tag="nofix", prov:type='obo:UBERON_0002813'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:3966c3a9a3e9ad3eb8448c2262742166)
#   entity(niiri:d038d222835a1585663b62a72ce318d8, [prov:label="rh.pial", fs:relative_path="surf/rh.pial", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/surf/rh.pial", obo:MS_1000568="08c3ec10c38e6dc51845bc481b6722dd", nidm:tag="surf", nidm:tag="rh", nidm:tag="pial", prov:type='obo:UBERON_0002813'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:d038d222835a1585663b62a72ce318d8)
#   entity(niiri:a06f517f4e789d27f2023a9ee4c44cb7, [prov:label="rh.qsphere.nofix", fs:relative_path="surf/rh.qsphere.nofix", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/surf/rh.qsphere.nofix", obo:MS_1000568="477398af892371b6dc9d6fa78b7b22cf", nidm:tag="surf", nidm:tag="rh", nidm:tag="qsphere", nidm:tag="nofix", prov:type='obo:UBERON_0002813'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:a06f517f4e789d27f2023a9ee4c44cb7)
#   entity(niiri:b2c95c80b8c87b35496e7a687aa3e0a8, [prov:label="rh.smoothwm", fs:relative_path="surf/rh.smoothwm", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/surf/rh.smoothwm", obo:MS_1000568="1d67a789af5fc6f5c9576af5583f53be", nidm:tag="surf", nidm:tag="rh", nidm:tag="smoothwm", prov:type='obo:UBERON_0002813'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:b2c95c80b8c87b35496e7a687aa3e0a8)
#   entity(niiri:ee502e8609af39951650598df0c6b1e9, [prov:label="rh.smoothwm.BE.crv", fs:relative_path="surf/rh.smoothwm.BE.crv", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/surf/rh.smoothwm.BE.crv", obo:MS_1000568="3d4d26b7ac82562703db53331df09416", nidm:tag="surf", nidm:tag="rh", nidm:tag="smoothwm", nidm:tag="BE", nidm:tag="crv", prov:type='obo:UBERON_0002813'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:ee502e8609af39951650598df0c6b1e9)
#   entity(niiri:9ccd2658d4eb99f560379c96aaa46f03, [prov:label="rh.smoothwm.C.crv", fs:relative_path="surf/rh.smoothwm.C.crv", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/surf/rh.smoothwm.C.crv", obo:MS_1000568="c9f3b72786a9b14771da8c1df2a6baeb", nidm:tag="surf", nidm:tag="rh", nidm:tag="smoothwm", nidm:tag="C", nidm:tag="crv", prov:type='obo:UBERON_0002813'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:9ccd2658d4eb99f560379c96aaa46f03)
#   entity(niiri:d79987454a29b76925cc4812d2b311ca, [prov:label="rh.smoothwm.FI.crv", fs:relative_path="surf/rh.smoothwm.FI.crv", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/surf/rh.smoothwm.FI.crv", obo:MS_1000568="dbdd0db90b2103af28bd38c362567ce5", nidm:tag="surf", nidm:tag="rh", nidm:tag="smoothwm", nidm:tag="FI", nidm:tag="crv", prov:type='obo:UBERON_0002813'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:d79987454a29b76925cc4812d2b311ca)
#   entity(niiri:248dc9673662d59658503392f1458011, [prov:label="rh.smoothwm.H.crv", fs:relative_path="surf/rh.smoothwm.H.crv", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/surf/rh.smoothwm.H.crv", obo:MS_1000568="4def2d2bc003d4eea626ebaef4da26a7", nidm:tag="surf", nidm:tag="rh", nidm:tag="smoothwm", nidm:tag="H", nidm:tag="crv", prov:type='obo:UBERON_0002813'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:248dc9673662d59658503392f1458011)
#   entity(niiri:9e46f41cf6e6852f9ffe56caf7d0e083, [prov:label="rh.smoothwm.K.crv", fs:relative_path="surf/rh.smoothwm.K.crv", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/surf/rh.smoothwm.K.crv", obo:MS_1000568="d391472a769c2e4fc2472ab55a86e52b", nidm:tag="surf", nidm:tag="rh", nidm:tag="smoothwm", nidm:tag="K", nidm:tag="crv", prov:type='obo:UBERON_0002813'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:9e46f41cf6e6852f9ffe56caf7d0e083)
#   entity(niiri:e450bb26d9dff4a942a6f2f29fcc7925, [prov:label="rh.smoothwm.K1.crv", fs:relative_path="surf/rh.smoothwm.K1.crv", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/surf/rh.smoothwm.K1.crv", obo:MS_1000568="c4109b52d202daf05561c56d22a8535f", nidm:tag="surf", nidm:tag="rh", nidm:tag="smoothwm", nidm:tag="K1", nidm:tag="crv", prov:type='obo:UBERON_0002813'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:e450bb26d9dff4a942a6f2f29fcc7925)
#   entity(niiri:1613af4eebec6a8babdd69df2a98ad6e, [prov:label="rh.smoothwm.K2.crv", fs:relative_path="surf/rh.smoothwm.K2.crv", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/surf/rh.smoothwm.K2.crv", obo:MS_1000568="87daf18e1fea30f0a7d20d075f8a50d9", nidm:tag="surf", nidm:tag="rh", nidm:tag="smoothwm", nidm:tag="K2", nidm:tag="crv", prov:type='obo:UBERON_0002813'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:1613af4eebec6a8babdd69df2a98ad6e)
#   entity(niiri:1ce2cd683fac746be4b2eb14c9cb6b8b, [prov:label="rh.smoothwm.S.crv", fs:relative_path="surf/rh.smoothwm.S.crv", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/surf/rh.smoothwm.S.crv", obo:MS_1000568="eca49e310f3902c8c58b454aa1dbf119", nidm:tag="surf", nidm:tag="rh", nidm:tag="smoothwm", nidm:tag="S", nidm:tag="crv", prov:type='obo:UBERON_0002813'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:1ce2cd683fac746be4b2eb14c9cb6b8b)
#   entity(niiri:72c9b5d6448ddeab68cba92d147a841e, [prov:label="rh.smoothwm.nofix", fs:relative_path="surf/rh.smoothwm.nofix", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/surf/rh.smoothwm.nofix", obo:MS_1000568="2a49b108425ff591d726262c63ebd817", nidm:tag="surf", nidm:tag="rh", nidm:tag="smoothwm", nidm:tag="nofix", prov:type='obo:UBERON_0002813'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:72c9b5d6448ddeab68cba92d147a841e)
#   entity(niiri:5e87114a858927d45ad74dac65f18b6c, [prov:label="rh.sphere", fs:relative_path="surf/rh.sphere", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/surf/rh.sphere", obo:MS_1000568="e5e9022fa8e3e5a31c1dc8a1b18fba8e", nidm:tag="surf", nidm:tag="rh", nidm:tag="sphere", prov:type='obo:UBERON_0002813'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:5e87114a858927d45ad74dac65f18b6c)
#   entity(niiri:e8272fd558d96fad5ef76f786997bf40, [prov:label="rh.sphere.reg", fs:relative_path="surf/rh.sphere.reg", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/surf/rh.sphere.reg", obo:MS_1000568="0b5ef4afafc36ff5a0d9c4d02037b5e7", nidm:tag="surf", nidm:tag="rh", nidm:tag="sphere", nidm:tag="reg", prov:type='obo:UBERON_0002813'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:e8272fd558d96fad5ef76f786997bf40)
#   entity(niiri:d7f03208ab1cc64f0fbb8f500af11663, [prov:label="rh.sulc", fs:relative_path="surf/rh.sulc", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/surf/rh.sulc", obo:MS_1000568="6ca40925fd39c10194df6e566470ffdd", nidm:tag="surf", nidm:tag="rh", nidm:tag="sulc", prov:type='obo:UBERON_0002813'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:d7f03208ab1cc64f0fbb8f500af11663)
#   entity(niiri:195dbb7b28d88e9c1aa0bf557f60b0d8, [prov:label="rh.thickness", fs:relative_path="surf/rh.thickness", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/surf/rh.thickness", obo:MS_1000568="f875d385411c89e25e32a65c7a832cc5", nidm:tag="surf", nidm:tag="rh", nidm:tag="thickness", prov:type='obo:UBERON_0002813'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:195dbb7b28d88e9c1aa0bf557f60b0d8)
#   entity(niiri:bc1b298d00edcc349fa6279fd5131cb2, [prov:label="rh.volume", fs:relative_path="surf/rh.volume", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/surf/rh.volume", obo:MS_1000568="e4797c96e626ba7cb62dc40f90c92d35", nidm:tag="surf", nidm:tag="rh", nidm:tag="volume", prov:type='obo:UBERON_0002813'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:bc1b298d00edcc349fa6279fd5131cb2)
#   entity(niiri:d6e91b98721751bcd014d96154b03b71, [prov:label="rh.w-g.pct.mgh", fs:relative_path="surf/rh.w-g.pct.mgh", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/surf/rh.w-g.pct.mgh", obo:MS_1000568="dff6c72408711f324adbf7802c6d254f", nidm:tag="surf", nidm:tag="rh", nidm:tag="w-g", nidm:tag="pct", nidm:tag="mgh", prov:type='obo:UBERON_0002813'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:d6e91b98721751bcd014d96154b03b71)
#   entity(niiri:9a90bcfd7114f660eea523ce00385b2a, [prov:label="rh.white", fs:relative_path="surf/rh.white", prov:location="http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/surf/rh.white", obo:MS_1000568="cc19bea56d0e1491ff8ced076963a148", nidm:tag="surf", nidm:tag="rh", nidm:tag="white", prov:type='obo:UBERON_0002813'])
#   hadMember(niiri:4c735fc66b5e12cdd321d6ed64394c84, niiri:9a90bcfd7114f660eea523ce00385b2a)
# endDocument

# %%
cat bert.ttl
# Out:
# @prefix dcterms: <http://purl.org/dc/terms/> .
# @prefix foaf: <http://xmlns.com/foaf/0.1/> .
# @prefix fs: <http://freesurfer.net/fswiki/terms/0.1/> .
# @prefix nidm: <http://nidm.nidash.org/terms/0.1/> .
# @prefix nif: <http://neurolex.org/wiki/> .
# @prefix niiri: <http://nidm.nidash.org/iri/> .
# @prefix obo: <http://purl.obolibrary.org/obo/> .
# @prefix prov: <http://www.w3.org/ns/prov#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xml: <http://www.w3.org/XML/1998/namespace> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
# @prefix xsd1: <http://www.w3.org/2001/XMLSchema-datatypes#> .
#
# <http://nidm.nidash.org/iri/4c735fc66b5e12cdd321d6ed64394c84> a fs:subject_directory,
#         prov:Collection,
#         prov:Entity ;
#     fs:subject_id "bert" ;
#     prov:hadMember <http://nidm.nidash.org/iri/0092e9809daa77b1cd57c5ce69d1e5c5>,
#         <http://nidm.nidash.org/iri/01b9287e320437fc6841c595a7f62d26>,
#         <http://nidm.nidash.org/iri/02c703e64f8e2eaafd04dae7a73d016c>,
#         <http://nidm.nidash.org/iri/034aff59b343346cd655247e6a6ac94e>,
#         <http://nidm.nidash.org/iri/0388e72d8deb18c97054a4ff8107a226>,
#         <http://nidm.nidash.org/iri/046d023f6e731c5a9996ad03cff717b7>,
#         <http://nidm.nidash.org/iri/051d13c878398a3a5938cfcc880345ee>,
#         <http://nidm.nidash.org/iri/05ed4db1e45f98b317f3082a5e4f389d>,
#         <http://nidm.nidash.org/iri/0b718ceea369698852244242c141e547>,
#         <http://nidm.nidash.org/iri/0b80d459f885075b9195517ac4b6816d>,
#         <http://nidm.nidash.org/iri/0cf83d517044d352f67b11837774a1f0>,
#         <http://nidm.nidash.org/iri/0db57c69946c707ce788c844dfd8b41c>,
#         <http://nidm.nidash.org/iri/0dbe6bbca7c6ab8c6785f8bf88635e45>,
#         <http://nidm.nidash.org/iri/104c799c20720f4a5a279fb45256827f>,
#         <http://nidm.nidash.org/iri/10b55c9964d4b5e1844ff710b949a1a3>,
#         <http://nidm.nidash.org/iri/13236da235ede643122d2129ff3b4fdb>,
#         <http://nidm.nidash.org/iri/13fd5ed7bf9dee1ca7427683d3b111fb>,
#         <http://nidm.nidash.org/iri/1613af4eebec6a8babdd69df2a98ad6e>,
#         <http://nidm.nidash.org/iri/1649798e9b3d1f01bc5f0a1b5d11c1a6>,
#         <http://nidm.nidash.org/iri/17859dc1fec1dbc394158949b14cf856>,
#         <http://nidm.nidash.org/iri/195dbb7b28d88e9c1aa0bf557f60b0d8>,
#         <http://nidm.nidash.org/iri/19abf59f432812703ea3ae9d28edcec1>,
#         <http://nidm.nidash.org/iri/1ce2cd683fac746be4b2eb14c9cb6b8b>,
#         <http://nidm.nidash.org/iri/1e061fffb8ba56bc7b397ccaafef1bee>,
#         <http://nidm.nidash.org/iri/1e34896bc5f0b84ea00f71929d01a705>,
#         <http://nidm.nidash.org/iri/1ec02e0212e27ce11cb6f02b06b1135c>,
#         <http://nidm.nidash.org/iri/22e28282d63612c4130e027676d85a3d>,
#         <http://nidm.nidash.org/iri/248dc9673662d59658503392f1458011>,
#         <http://nidm.nidash.org/iri/265e6c4a010cf1a14dfdecd65e1bf6e0>,
#         <http://nidm.nidash.org/iri/26a1e5d18388232ebb6ddd82aa3bb6db>,
#         <http://nidm.nidash.org/iri/26bdc84e25faef5358fb283d52d0055c>,
#         <http://nidm.nidash.org/iri/27f3db2ffaaa8180e873d0e0f7ec3ff4>,
#         <http://nidm.nidash.org/iri/29ebaf4436f4b678498510523efd11ee>,
#         <http://nidm.nidash.org/iri/2abe6059edb3fcf7df1f15cdcf7e7435>,
#         <http://nidm.nidash.org/iri/2b366e5382e19c6d1a6db620c7ef6489>,
#         <http://nidm.nidash.org/iri/2b9ea2495d880c71dd6ada380be91b69>,
#         <http://nidm.nidash.org/iri/2cad28fde197143144da344d53bc363b>,
#         <http://nidm.nidash.org/iri/30207f05d8ecfbca4f099dc50f176417>,
#         <http://nidm.nidash.org/iri/30bb879cabca192e4596d686c962de69>,
#         <http://nidm.nidash.org/iri/3171982db56216da860f838b44fbcdeb>,
#         <http://nidm.nidash.org/iri/31e0890fef9a67574199aa6b81c56a0f>,
#         <http://nidm.nidash.org/iri/326671f0db0e02f47f915c3198d1fa98>,
#         <http://nidm.nidash.org/iri/339ff642c738308ad9a340b5e66f21d9>,
#         <http://nidm.nidash.org/iri/34259316e4577472b15e1c2fa018a8fc>,
#         <http://nidm.nidash.org/iri/349c21bb9bde7e7dffa7121b653f5df0>,
#         <http://nidm.nidash.org/iri/35df9818371f502327463cea618073b4>,
#         <http://nidm.nidash.org/iri/381dbef1af935d3cb78f74751967ae27>,
#         <http://nidm.nidash.org/iri/3966c3a9a3e9ad3eb8448c2262742166>,
#         <http://nidm.nidash.org/iri/3b46f47836725704a8109ceadce071d1>,
#         <http://nidm.nidash.org/iri/3e8cdc31382bfe9826977c4b2b73524b>,
#         <http://nidm.nidash.org/iri/4017883bb149c321b04e7ab7e2bb0808>,
#         <http://nidm.nidash.org/iri/406b6708fab8989128948cbc5532b980>,
#         <http://nidm.nidash.org/iri/41c46a0485b890662a5b57c25b86bfe1>,
#         <http://nidm.nidash.org/iri/44472ac39f759b8749b2925b4e5afa60>,
#         <http://nidm.nidash.org/iri/44b44116d43395e32b31dbc1c48c99d6>,
#         <http://nidm.nidash.org/iri/44f239c114fbcb261b886fb9fb5ea9e7>,
#         <http://nidm.nidash.org/iri/462206be19ada5752edc24868c5eea47>,
#         <http://nidm.nidash.org/iri/46e2461c3fbe30b942d0e631dcb1a515>,
#         <http://nidm.nidash.org/iri/4bea435d0fb69f1a8e8a84c8fb8bc392>,
#         <http://nidm.nidash.org/iri/4fcfea889bb4caa903b59375580a3c47>,
#         <http://nidm.nidash.org/iri/526f980d57aa41db5c7847230c887d5c>,
#         <http://nidm.nidash.org/iri/53ccaf1cc86339adb45d0615046401d1>,
#         <http://nidm.nidash.org/iri/53fd1c92fc82620aac2e40460312a65d>,
#         <http://nidm.nidash.org/iri/541c304e148fd0eaf3c6d1b495f79a3b>,
#         <http://nidm.nidash.org/iri/542cbea495c57cfefeb374250b96e3aa>,
#         <http://nidm.nidash.org/iri/5589b976eea76304b4f16beb0d676dcb>,
#         <http://nidm.nidash.org/iri/56098ec2f130a168f0339e4d311ea100>,
#         <http://nidm.nidash.org/iri/563265a36772916f62b4e41fe6f22e7a>,
#         <http://nidm.nidash.org/iri/565fbddd9795ee7af65b26dab5ac7da2>,
#         <http://nidm.nidash.org/iri/56c6adfe923213144ee5fc75fe23c368>,
#         <http://nidm.nidash.org/iri/577222cf99c2620301973d2e1ac2250a>,
#         <http://nidm.nidash.org/iri/579e7dbbc21ec4103a4ab010166bf224>,
#         <http://nidm.nidash.org/iri/59d49f9f0587bd899c0b44a78187c6e6>,
#         <http://nidm.nidash.org/iri/5a4356526498f0f91aaa1315cda1d383>,
#         <http://nidm.nidash.org/iri/5a64c02a723abd5c0ee0a103c55e820d>,
#         <http://nidm.nidash.org/iri/5af75b6147f67b347e7d0389f0c7f1f5>,
#         <http://nidm.nidash.org/iri/5cbb3aff8d9357c260b5c9ccda7abcc7>,
#         <http://nidm.nidash.org/iri/5cdcf5e5fc16eca7de43eb5321799794>,
#         <http://nidm.nidash.org/iri/5e6af1b1461a07eef6ef581561fabcb4>,
#         <http://nidm.nidash.org/iri/5e87114a858927d45ad74dac65f18b6c>,
#         <http://nidm.nidash.org/iri/5f20cadb89821914cc050f529d279b8a>,
#         <http://nidm.nidash.org/iri/604221dfc933c467e9a44a35995ea0be>,
#         <http://nidm.nidash.org/iri/605a35879d4d51d2789c8633582ebec0>,
#         <http://nidm.nidash.org/iri/6533dc73cf040fc440dea08e8ec9cc36>,
#         <http://nidm.nidash.org/iri/6617cf555febd56ebbba8eadd0aa74a1>,
#         <http://nidm.nidash.org/iri/691e8f8148cf5b9e0fc96e333c51c840>,
#         <http://nidm.nidash.org/iri/6924ba2161bd0b505f68b81232d82b33>,
#         <http://nidm.nidash.org/iri/6af88a9d28d5e14893de5dae76ca8da6>,
#         <http://nidm.nidash.org/iri/6c84604134bf41b96beec503fb96815d>,
#         <http://nidm.nidash.org/iri/6e567a523c4006d9a68c6b0ab001bbe3>,
#         <http://nidm.nidash.org/iri/6f23ecc532a81b5d421365630915f5f3>,
#         <http://nidm.nidash.org/iri/6fa1444aea376047e54b10b5366b7c21>,
#         <http://nidm.nidash.org/iri/70786d2b1977daa65990bea625c95360>,
#         <http://nidm.nidash.org/iri/707db35073e54d0337fd70a1bd660705>,
#         <http://nidm.nidash.org/iri/715d30f14f8aecfbedbd5ed816eb9ed4>,
#         <http://nidm.nidash.org/iri/72567591ebdc496fd873ad06175c1f42>,
#         <http://nidm.nidash.org/iri/72c9b5d6448ddeab68cba92d147a841e>,
#         <http://nidm.nidash.org/iri/76e7b9f0d70cc31627e7865c66b1bb45>,
#         <http://nidm.nidash.org/iri/770ffb00e54418f8b18b3df754f7f6b8>,
#         <http://nidm.nidash.org/iri/77992da44ec093d4e6a55999646e405a>,
#         <http://nidm.nidash.org/iri/77db0caa952e529c6f9f46ca21f6935c>,
#         <http://nidm.nidash.org/iri/77f5d072c77f4dc84cf982877ad0a74d>,
#         <http://nidm.nidash.org/iri/77fa6a15e90b16a6d035a9739b9a9139>,
#         <http://nidm.nidash.org/iri/781299dd32579c3673688b386f83b016>,
#         <http://nidm.nidash.org/iri/794e223b11d3509f264282db063f80c8>,
#         <http://nidm.nidash.org/iri/7964e43cada02e1c0c3b2368545467fe>,
#         <http://nidm.nidash.org/iri/7dba4b88cb8df248563bfbb9edb74063>,
#         <http://nidm.nidash.org/iri/7efddb7b50840d84c981dee4221f71ac>,
#         <http://nidm.nidash.org/iri/82a563766740515cb1d30ed339454f84>,
#         <http://nidm.nidash.org/iri/84638e75e276b195d6df1306a9869e44>,
#         <http://nidm.nidash.org/iri/84aca538b9d97e1855e0c6b7c7552f40>,
#         <http://nidm.nidash.org/iri/84d65e935ef6680b0df23387a7079b3e>,
#         <http://nidm.nidash.org/iri/864be1867da9304d3c33997d9070fbfb>,
#         <http://nidm.nidash.org/iri/86997883e6bb5741fa23ff1f38cf043f>,
#         <http://nidm.nidash.org/iri/87b4be003a5afaf85454ea79cdf93e06>,
#         <http://nidm.nidash.org/iri/87d7e3a411c2e3e3570b1af9130c422b>,
#         <http://nidm.nidash.org/iri/87e60df009f10363de71105461ffa48d>,
#         <http://nidm.nidash.org/iri/885324af28d7e8fd02f6242cd28129f9>,
#         <http://nidm.nidash.org/iri/8899d555f7c93d40972763a55de32ed9>,
#         <http://nidm.nidash.org/iri/8a3f6a42da7757f97d8fb27ea655d65f>,
#         <http://nidm.nidash.org/iri/8a7c05c533dfb08b4d7041ec0978d3c3>,
#         <http://nidm.nidash.org/iri/8f4791c73ad48b426f1ff541de6d060b>,
#         <http://nidm.nidash.org/iri/8f8fe6f3269cd7a5b02aee504865b38b>,
#         <http://nidm.nidash.org/iri/90d447fe444736e12fe46ff2f8d5c705>,
#         <http://nidm.nidash.org/iri/9384b407bb4a4f378d0cae474e67659f>,
#         <http://nidm.nidash.org/iri/942a81a929a3e22dda14c9677f0cb03a>,
#         <http://nidm.nidash.org/iri/94ed55b575b1ecc036f424372f849796>,
#         <http://nidm.nidash.org/iri/971a85178a45a3b137eac6e0ebb4aa13>,
#         <http://nidm.nidash.org/iri/9804138a4afdac00afac52fc15a8c4d1>,
#         <http://nidm.nidash.org/iri/98e3503c1e470eae20bd05b14574d5dc>,
#         <http://nidm.nidash.org/iri/98e4bc623d67788a8b7b82cd66272bdf>,
#         <http://nidm.nidash.org/iri/9a90bcfd7114f660eea523ce00385b2a>,
#         <http://nidm.nidash.org/iri/9b9485eb45664d46847f93bc25120d26>,
#         <http://nidm.nidash.org/iri/9ccd2658d4eb99f560379c96aaa46f03>,
#         <http://nidm.nidash.org/iri/9da1d217df07aa2772cda4b502fd881c>,
#         <http://nidm.nidash.org/iri/9db121b63e91a86453138202bf9a94ac>,
#         <http://nidm.nidash.org/iri/9e46f41cf6e6852f9ffe56caf7d0e083>,
#         <http://nidm.nidash.org/iri/9ffe4b823aa97c767ef0a359554e58be>,
#         niiri:a032a239bd0bd470443699b5af19af48,
#         niiri:a06f517f4e789d27f2023a9ee4c44cb7,
#         niiri:a17508964ba41290660a7d1a6b48f8bf,
#         niiri:a1f738fba64aa199214b9204908a2ad4,
#         niiri:a4033c67595ca62205d8291d873d782c,
#         niiri:a405b8ea0af82749b15de3480df8af64,
#         niiri:a472d369447a0518ef3c027868e04771,
#         niiri:a4ddd38524961eccce29ba0935f4c4d2,
#         niiri:a598379cae66d6213e5f7f483aa7ea70,
#         niiri:a6cde29baedad298bcfb53309d63988d,
#         niiri:a6f3ac8770d447a61d88544d44c5482e,
#         niiri:a8cd7fae0041f9dca225798a2ecf0f47,
#         niiri:a8d3a15b84c9434ce2626ecc5b401422,
#         niiri:a9fcdcd2a8f13debe80c37b6b3ebd9c4,
#         niiri:aa3ee7d6950e8d1d6e788d45c7d2578f,
#         niiri:aa4dc4ff53e7678ff596593cc70f1aa0,
#         niiri:ab13d9828cc49c4f666fd9ab33c9c4bd,
#         niiri:ad64b01ac3bafac1f877de72f17c6d5c,
#         niiri:af5cd1684358198c875a0e9e0f547b67,
#         niiri:b198eeba3bdf28fb115eedaa2a67eccd,
#         niiri:b1b8c7983437f642e3a3f7db19bbe07e,
#         niiri:b1d13b15fa383178b1ed868d7b5caecd,
#         niiri:b245de46ec994bfb734b9a94342d8c24,
#         niiri:b2c95c80b8c87b35496e7a687aa3e0a8,
#         niiri:b3f84dfb2d69afcd95c801d59e996c71,
#         niiri:b91a663626a53b552b8ad08aad672f19,
#         niiri:b975b49bd3b441c032505ce12e8ef120,
#         niiri:bab3c879108c4fb364041a45645d7f58,
#         niiri:bc1b298d00edcc349fa6279fd5131cb2,
#         niiri:bc289bb818e33fbc19527dbf67f9e26d,
#         niiri:be85300d02a9f91fd469c7fb2d4d24ac,
#         niiri:c0f6377edefe55442b256ffadacaabc2,
#         niiri:c1f4d75669fdca68a7af3f48c414272f,
#         niiri:c335571efa76cb400cbe5846eb579fa3,
#         niiri:c366fffdcd874ba993f80f11057403b2,
#         niiri:c40e5a3cd50177f116e39a27e1797802,
#         niiri:c5a074a81a28352ee19326b3cf260387,
#         niiri:c5a40e28a03f00c5d79dc08ef78855ed,
#         niiri:c6d1610a5c4b0b3819514dca205da5ff,
#         niiri:cd2a8984d6b25aad6b7ff8ae526610ea,
#         niiri:d038d222835a1585663b62a72ce318d8,
#         niiri:d0dc775e849c4ad4ce696e4744b2951f,
#         niiri:d17d928ddc02197fddbaf9b145e8acc2,
#         niiri:d42c4ac7d551fe0cc2e0bfec62ee0dc0,
#         niiri:d4c0ce3b31f50e0cae45ff6723c88b7a,
#         niiri:d679bd9a86a5bb4e266187d404f83ce1,
#         niiri:d6e91b98721751bcd014d96154b03b71,
#         niiri:d79987454a29b76925cc4812d2b311ca,
#         niiri:d7f03208ab1cc64f0fbb8f500af11663,
#         niiri:d80525645f45a042c06132632edbdc82,
#         niiri:d859b32e30b7edec55aed3934c929893,
#         niiri:d957cae03c5a66476c9d304da12f5932,
#         niiri:d9b8ef2d0c2f8b8fe95f4b51b3e358c2,
#         niiri:d9f229a9215e69e028097dbdb13c8505,
#         niiri:dbd9efb1d117b4635ba23bb6bb0c7579,
#         niiri:dc749cf5b0a66f3fa8314bc5bbbd5cd5,
#         niiri:dc940277c77efe7b2ec8020663cffb77,
#         niiri:dd363fe3630a12ac15033bd833199f25,
#         niiri:ddbbb0eb79eb892a2273e23009f06e14,
#         niiri:e3b476bc9782cd09cc0e0bf8bda32d2a,
#         niiri:e450bb26d9dff4a942a6f2f29fcc7925,
#         niiri:e4bdbc14a29e53dc4168b90a67815464,
#         niiri:e522b153a27ab07522cf6dfc308c838d,
#         niiri:e64fc913db589848692b887576264e12,
#         niiri:e653f4094462aec5bd679683846732a4,
#         niiri:e66274c5acccbacf00a00da0a7d1e849,
#         niiri:e6f33e870fe384bcb0eb500c659069da,
#         niiri:e744f0513427fbe84d5d8ae8ecc0d15e,
#         niiri:e74b0eb67811e6e5c8d16fd5dcde439a,
#         niiri:e7f3fbb6ca0a8d0aa97441471a5b2c55,
#         niiri:e8272fd558d96fad5ef76f786997bf40,
#         niiri:e8e0afd0b3eb870e1afeb4542d02ca19,
#         niiri:e8fd424fb4cbaf75179d1d6ae4cd6f85,
#         niiri:e94e89ca3af2532f2a89f8885a630d2d,
#         niiri:ea6ff0b772513d85f38c30790416a821,
#         niiri:eb3e725d4108609c637ca658e5e987ea,
#         niiri:eb451cc27ec167903326dd79fe77aa96,
#         niiri:ecdb68580def1439dc7e7687e9a84cd4,
#         niiri:ee502e8609af39951650598df0c6b1e9,
#         niiri:ef46876f398841888e0467390b8758a2,
#         niiri:f0bade97d334d4451d89dbb4054433dc,
#         niiri:f17b8ed28e191621ead8f898beacbacb,
#         niiri:f24ddece62d2167eddd3e552100ce099,
#         niiri:f25a310141b70f08bb84881df502f9aa,
#         niiri:f381082e32444e53e65daf241a7a7f4a,
#         niiri:f6a40163187f0d089084451ed75451b1,
#         niiri:f7efe10b4f049a134b8a37d6785a00dc,
#         niiri:f83014accee72a41cccac7686922731d,
#         niiri:f86ed4fdb83af11e2306c72330ef5dc1,
#         niiri:fc102be99c96b1d96d9fad68b0678112,
#         niiri:fc94feae3198f5cfe59be3b41a26bee4,
#         niiri:ffefdab83a950a624d01dd4e543f3442 .
#
# <http://nidm.nidash.org/iri/0092e9809daa77b1cd57c5ce69d1e5c5> a obo:UBERON_0002812,
#         prov:Entity ;
#     fs:relative_path "surf/lh.orig.nofix" ;
#     nidm:tag "lh",
#         "nofix",
#         "orig",
#         "surf" ;
#     obo:MS_1000568 "2a9e0fa6981d3621f3ba15bb4ee111b0" ;
#     prov:label "lh.orig.nofix" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/surf/lh.orig.nofix" .
#
# <http://nidm.nidash.org/iri/01b9287e320437fc6841c595a7f62d26> a fs:a2009s_parcellation,
#         fs:statistic_file,
#         obo:UBERON_0002812,
#         prov:Entity ;
#     fs:relative_path "stats/lh.aparc.a2009s.stats" ;
#     nidm:tag "a2009s",
#         "aparc",
#         "aparc.a2009s",
#         "lh",
#         "stats" ;
#     obo:MS_1000568 "43ef328bc411a10df65d8287d75bf2a5" ;
#     prov:label "lh.aparc.a2009s.stats" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/stats/lh.aparc.a2009s.stats" .
#
# <http://nidm.nidash.org/iri/02c703e64f8e2eaafd04dae7a73d016c> a obo:UBERON_0002813,
#         prov:Entity ;
#     fs:relative_path "surf/rh.area" ;
#     nidm:tag "area",
#         "rh",
#         "surf" ;
#     obo:MS_1000568 "b5ed6007e18358b2fe424a2b5b12b0fc" ;
#     prov:label "rh.area" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/surf/rh.area" .
#
# <http://nidm.nidash.org/iri/034aff59b343346cd655247e6a6ac94e> a obo:UBERON_0002813,
#         prov:Entity ;
#     fs:relative_path "surf/rh.defect_borders" ;
#     nidm:tag "defect_borders",
#         "rh",
#         "surf" ;
#     obo:MS_1000568 "7bb15f9c44bb47facca09b1cdb6f6d13" ;
#     prov:label "rh.defect_borders" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/surf/rh.defect_borders" .
#
# <http://nidm.nidash.org/iri/0388e72d8deb18c97054a4ff8107a226> a prov:Entity ;
#     fs:relative_path "mri/talairach.log" ;
#     nidm:tag "log",
#         "mri",
#         "talairach" ;
#     obo:MS_1000568 "9d7f25a2e756f9c9060f781f3887d33d" ;
#     prov:label "talairach.log" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/mri/talairach.log" .
#
# <http://nidm.nidash.org/iri/046d023f6e731c5a9996ad03cff717b7> a fs:label_file,
#         obo:UBERON_0002812,
#         obo:UBERON_0006482,
#         prov:Entity ;
#     fs:relative_path "label/lh.BA45.thresh.label" ;
#     nidm:tag "BA45",
#         "label",
#         "lh",
#         "thresh" ;
#     obo:MS_1000568 "6131431ba45c25032ad27e8b7b53e661" ;
#     prov:label "lh.BA45.thresh.label" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/lh.BA45.thresh.label" .
#
# <http://nidm.nidash.org/iri/051d13c878398a3a5938cfcc880345ee> a prov:Entity ;
#     fs:relative_path "mri/orig/003.mgz" ;
#     nidm:tag "003",
#         "mgz",
#         "mri",
#         "orig" ;
#     obo:MS_1000568 "a6f30d4f32c2f01f16c839f207739a27" ;
#     prov:label "003.mgz" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/mri/orig/003.mgz" .
#
# <http://nidm.nidash.org/iri/05ed4db1e45f98b317f3082a5e4f389d> a prov:Entity ;
#     fs:relative_path "mri/transforms/talairach.m3z" ;
#     nidm:tag "m3z",
#         "mri",
#         "talairach",
#         "transforms" ;
#     obo:MS_1000568 "7bac5e084b83d23d2b64845e7a2f2986" ;
#     prov:label "talairach.m3z" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/mri/transforms/talairach.m3z" .
#
# <http://nidm.nidash.org/iri/0b718ceea369698852244242c141e547> a obo:UBERON_0002812,
#         prov:Entity ;
#     fs:relative_path "surf/lh.area" ;
#     nidm:tag "area",
#         "lh",
#         "surf" ;
#     obo:MS_1000568 "723c04cd15b1aae55e5f204ff7e25d25" ;
#     prov:label "lh.area" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/surf/lh.area" .
#
# <http://nidm.nidash.org/iri/0b80d459f885075b9195517ac4b6816d> a fs:statistic_file,
#         obo:UBERON_0002812,
#         obo:UBERON_0013529,
#         prov:Entity ;
#     fs:relative_path "stats/lh.BA.stats" ;
#     nidm:tag "BA",
#         "lh",
#         "stats" ;
#     obo:MS_1000568 "4feae4258c39f9fc2577405c97362553" ;
#     prov:label "lh.BA.stats" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/stats/lh.BA.stats" .
#
# <http://nidm.nidash.org/iri/0cf83d517044d352f67b11837774a1f0> a prov:Entity ;
#     fs:relative_path "mri/brainmask.mgz" ;
#     nidm:tag "brainmask",
#         "mgz",
#         "mri" ;
#     obo:MS_1000568 "14f92fac0340a647a793f432e96b2213" ;
#     prov:label "brainmask.mgz" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/mri/brainmask.mgz" .
#
# <http://nidm.nidash.org/iri/0db57c69946c707ce788c844dfd8b41c> a prov:Entity ;
#     fs:relative_path "mri/transforms/talairach.m3z.inv.z.mgz" ;
#     nidm:tag "inv",
#         "m3z",
#         "mgz",
#         "mri",
#         "talairach",
#         "transforms",
#         "z" ;
#     obo:MS_1000568 "131d2bbc343d18aeccdd5368c0365a23" ;
#     prov:label "talairach.m3z.inv.z.mgz" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/mri/transforms/talairach.m3z.inv.z.mgz" .
#
# <http://nidm.nidash.org/iri/0dbe6bbca7c6ab8c6785f8bf88635e45> a prov:Entity ;
#     fs:relative_path "mri/nu.mgz" ;
#     nidm:tag "mgz",
#         "mri",
#         "nu" ;
#     obo:MS_1000568 "c3ed2969a4aa05236c8cf4b0fdaf60fc" ;
#     prov:label "nu.mgz" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/mri/nu.mgz" .
#
# <http://nidm.nidash.org/iri/104c799c20720f4a5a279fb45256827f> a fs:annotation_file,
#         obo:UBERON_0002813,
#         prov:Entity ;
#     fs:relative_path "label/rh.overlap.annot" ;
#     nidm:tag "annot",
#         "label",
#         "overlap",
#         "rh" ;
#     obo:MS_1000568 "b06c02da48bd4ca2137aaa6a635eff3e" ;
#     prov:label "rh.overlap.annot" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/rh.overlap.annot" .
#
# <http://nidm.nidash.org/iri/10b55c9964d4b5e1844ff710b949a1a3> a fs:label_file,
#         obo:FMA_74532,
#         obo:UBERON_0002813,
#         obo:UBERON_0013535,
#         prov:Entity ;
#     fs:relative_path "label/rh.BA4a.label" ;
#     nidm:tag "BA4a",
#         "label",
#         "rh" ;
#     obo:MS_1000568 "08c7e1544de10f421cc45ec91f73275f" ;
#     prov:label "rh.BA4a.label" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/rh.BA4a.label" .
#
# <http://nidm.nidash.org/iri/13236da235ede643122d2129ff3b4fdb> a obo:UBERON_0002812,
#         prov:Entity ;
#     fs:relative_path "surf/lh.area.pial" ;
#     nidm:tag "area",
#         "lh",
#         "pial",
#         "surf" ;
#     obo:MS_1000568 "2b7cd8db4b73acda07640fde403db5a1" ;
#     prov:label "lh.area.pial" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/surf/lh.area.pial" .
#
# <http://nidm.nidash.org/iri/13fd5ed7bf9dee1ca7427683d3b111fb> a fs:label_file,
#         obo:UBERON_0000956,
#         obo:UBERON_0002812,
#         prov:Entity ;
#     fs:relative_path "label/lh.cortex.label" ;
#     nidm:tag "cortex",
#         "label",
#         "lh" ;
#     obo:MS_1000568 "23a9a88da7c4572d61875b504eec1830" ;
#     prov:label "lh.cortex.label" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/lh.cortex.label" .
#
# <http://nidm.nidash.org/iri/1613af4eebec6a8babdd69df2a98ad6e> a obo:UBERON_0002813,
#         prov:Entity ;
#     fs:relative_path "surf/rh.smoothwm.K2.crv" ;
#     nidm:tag "K2",
#         "crv",
#         "rh",
#         "smoothwm",
#         "surf" ;
#     obo:MS_1000568 "87daf18e1fea30f0a7d20d075f8a50d9" ;
#     prov:label "rh.smoothwm.K2.crv" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/surf/rh.smoothwm.K2.crv" .
#
# <http://nidm.nidash.org/iri/1649798e9b3d1f01bc5f0a1b5d11c1a6> a obo:UBERON_0002812,
#         prov:Entity ;
#     fs:relative_path "mri/lh.ribbon.mgz" ;
#     nidm:tag "lh",
#         "mgz",
#         "mri",
#         "ribbon" ;
#     obo:MS_1000568 "541be4ec953642248b70db70929ae4ab" ;
#     prov:label "lh.ribbon.mgz" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/mri/lh.ribbon.mgz" .
#
# <http://nidm.nidash.org/iri/17859dc1fec1dbc394158949b14cf856> a prov:Entity ;
#     fs:relative_path "mri/aseg.auto_noCCseg.mgz" ;
#     nidm:tag "aseg",
#         "auto_noCCseg",
#         "mgz",
#         "mri" ;
#     obo:MS_1000568 "013dce69a79c2f443e3272f207ea6eb1" ;
#     prov:label "aseg.auto_noCCseg.mgz" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/mri/aseg.auto_noCCseg.mgz" .
#
# <http://nidm.nidash.org/iri/195dbb7b28d88e9c1aa0bf557f60b0d8> a obo:UBERON_0002813,
#         prov:Entity ;
#     fs:relative_path "surf/rh.thickness" ;
#     nidm:tag "rh",
#         "surf",
#         "thickness" ;
#     obo:MS_1000568 "f875d385411c89e25e32a65c7a832cc5" ;
#     prov:label "rh.thickness" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/surf/rh.thickness" .
#
# <http://nidm.nidash.org/iri/19abf59f432812703ea3ae9d28edcec1> a fs:MT_area,
#         fs:label_file,
#         obo:UBERON_0002813,
#         prov:Entity ;
#     fs:relative_path "label/rh.MT.thresh.label" ;
#     nidm:tag "MT",
#         "label",
#         "rh",
#         "thresh" ;
#     obo:MS_1000568 "b2740e2b696f976037d846594d21bfb8" ;
#     prov:label "rh.MT.thresh.label" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/rh.MT.thresh.label" .
#
# <http://nidm.nidash.org/iri/1ce2cd683fac746be4b2eb14c9cb6b8b> a obo:UBERON_0002813,
#         prov:Entity ;
#     fs:relative_path "surf/rh.smoothwm.S.crv" ;
#     nidm:tag "S",
#         "crv",
#         "rh",
#         "smoothwm",
#         "surf" ;
#     obo:MS_1000568 "eca49e310f3902c8c58b454aa1dbf119" ;
#     prov:label "rh.smoothwm.S.crv" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/surf/rh.smoothwm.S.crv" .
#
# <http://nidm.nidash.org/iri/1e061fffb8ba56bc7b397ccaafef1bee> a fs:label_file,
#         obo:UBERON_0002813,
#         obo:UBERON_0013533,
#         prov:Entity ;
#     fs:relative_path "label/rh.BA2.label" ;
#     nidm:tag "BA2",
#         "label",
#         "rh" ;
#     obo:MS_1000568 "76957226f4fa672c881d598e549292a1" ;
#     prov:label "rh.BA2.label" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/rh.BA2.label" .
#
# <http://nidm.nidash.org/iri/1e34896bc5f0b84ea00f71929d01a705> a obo:UBERON_0002812,
#         prov:Entity ;
#     fs:relative_path "surf/lh.white" ;
#     nidm:tag "lh",
#         "surf",
#         "white" ;
#     obo:MS_1000568 "e8d73928aaa6be399129f234334d1e60" ;
#     prov:label "lh.white" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/surf/lh.white" .
#
# <http://nidm.nidash.org/iri/1ec02e0212e27ce11cb6f02b06b1135c> a fs:exvivo,
#         fs:statistic_file,
#         obo:UBERON_0002728,
#         obo:UBERON_0002812,
#         obo:UBERON_0002813,
#         prov:Entity ;
#     fs:relative_path "stats/lh.entorhinal_exvivo.stats" ;
#     nidm:tag "entorhinal",
#         "entorhinal_exvivo",
#         "exvivo",
#         "lh",
#         "rh",
#         "stats" ;
#     obo:MS_1000568 "5888518da395871dbf9fd909eae25890" ;
#     prov:label "lh.entorhinal_exvivo.stats" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/stats/lh.entorhinal_exvivo.stats" .
#
# <http://nidm.nidash.org/iri/22e28282d63612c4130e027676d85a3d> a prov:Entity ;
#     fs:relative_path "mri/transforms/talairach_avi_QA.log" ;
#     nidm:tag "log",
#         "mri",
#         "talairach_avi_QA",
#         "transforms" ;
#     obo:MS_1000568 "0b93ac9519418f1c647aa8af00b5ec7e" ;
#     prov:label "talairach_avi_QA.log" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/mri/transforms/talairach_avi_QA.log" .
#
# <http://nidm.nidash.org/iri/248dc9673662d59658503392f1458011> a obo:UBERON_0002813,
#         prov:Entity ;
#     fs:relative_path "surf/rh.smoothwm.H.crv" ;
#     nidm:tag "H",
#         "crv",
#         "rh",
#         "smoothwm",
#         "surf" ;
#     obo:MS_1000568 "4def2d2bc003d4eea626ebaef4da26a7" ;
#     prov:label "rh.smoothwm.H.crv" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/surf/rh.smoothwm.H.crv" .
#
# <http://nidm.nidash.org/iri/265e6c4a010cf1a14dfdecd65e1bf6e0> a prov:Entity ;
#     fs:relative_path "mri/wmparc.mgz" ;
#     nidm:tag "mgz",
#         "mri",
#         "wmparc" ;
#     obo:MS_1000568 "0fe2a6d73232b959be5b5057f15e0d46" ;
#     prov:label "wmparc.mgz" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/mri/wmparc.mgz" .
#
# <http://nidm.nidash.org/iri/26a1e5d18388232ebb6ddd82aa3bb6db> a fs:statistic_file,
#         obo:UBERON_0002813,
#         prov:Entity ;
#     fs:relative_path "stats/rh.aparc.stats" ;
#     nidm:tag "aparc",
#         "rh",
#         "stats" ;
#     obo:MS_1000568 "5feddd6ac30725c898dfbc90a70be73c" ;
#     prov:label "rh.aparc.stats" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/stats/rh.aparc.stats" .
#
# <http://nidm.nidash.org/iri/26bdc84e25faef5358fb283d52d0055c> a prov:Entity ;
#     fs:relative_path "scripts/ponscc.cut.log" ;
#     nidm:tag "cut",
#         "log",
#         "ponscc",
#         "scripts" ;
#     obo:MS_1000568 "22a21ba36d1ad392793bcc38a260f8f3" ;
#     prov:label "ponscc.cut.log" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/scripts/ponscc.cut.log" .
#
# <http://nidm.nidash.org/iri/27f3db2ffaaa8180e873d0e0f7ec3ff4> a prov:Entity ;
#     fs:relative_path "mri/brain.finalsurfs.mgz" ;
#     nidm:tag "brain",
#         "finalsurfs",
#         "mgz",
#         "mri" ;
#     obo:MS_1000568 "7789fbdb927e66d1bbce694954fbe590" ;
#     prov:label "brain.finalsurfs.mgz" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/mri/brain.finalsurfs.mgz" .
#
# <http://nidm.nidash.org/iri/29ebaf4436f4b678498510523efd11ee> a prov:Entity ;
#     fs:relative_path "mri/aseg.auto.mgz" ;
#     nidm:tag "aseg",
#         "auto",
#         "mgz",
#         "mri" ;
#     obo:MS_1000568 "0d6031c46364175255fdfe6c03364a1a" ;
#     prov:label "aseg.auto.mgz" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/mri/aseg.auto.mgz" .
#
# <http://nidm.nidash.org/iri/2abe6059edb3fcf7df1f15cdcf7e7435> a obo:UBERON_0002812,
#         prov:Entity ;
#     fs:relative_path "surf/lh.volume" ;
#     nidm:tag "lh",
#         "surf",
#         "volume" ;
#     obo:MS_1000568 "b52f74bac683394faf1466beea4d14a6" ;
#     prov:label "lh.volume" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/surf/lh.volume" .
#
# <http://nidm.nidash.org/iri/2b366e5382e19c6d1a6db620c7ef6489> a fs:color_table,
#         obo:UBERON_0013529,
#         prov:Entity ;
#     fs:relative_path "label/BA.thresh.ctab" ;
#     nidm:tag "BA",
#         "ctab",
#         "label",
#         "thresh" ;
#     obo:MS_1000568 "7e9597e6f9170517c69e4c9f3f6a5681" ;
#     prov:label "BA.thresh.ctab" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/BA.thresh.ctab" .
#
# <http://nidm.nidash.org/iri/2b9ea2495d880c71dd6ada380be91b69> a prov:Entity ;
#     fs:relative_path "mri/filled.mgz" ;
#     nidm:tag "filled",
#         "mgz",
#         "mri" ;
#     obo:MS_1000568 "3e3cf7725b644b4ae1773161b26baa6a" ;
#     prov:label "filled.mgz" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/mri/filled.mgz" .
#
# <http://nidm.nidash.org/iri/2cad28fde197143144da344d53bc363b> a fs:a2009s_parcellation,
#         fs:annotation_file,
#         obo:UBERON_0002813,
#         prov:Entity ;
#     fs:relative_path "label/rh." ;
#     nidm:tag "",
#         "annot",
#         "aparc.a2009s",
#         "label",
#         "rh" ;
#     obo:MS_1000568 "86ec7fffdc250d84a353c33d05116f1a" ;
#     prov:label "rh.bert_ref.aparc.a2009s.annot" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/rh.bert_ref.aparc.a2009s.annot" .
#
# <http://nidm.nidash.org/iri/30207f05d8ecfbca4f099dc50f176417> a prov:Entity ;
#     fs:relative_path "mri/mri_nu_correct.mni.log" ;
#     nidm:tag "log",
#         "mni",
#         "mri",
#         "mri_nu_correct" ;
#     obo:MS_1000568 "f2330a567fdb5a7d1e7df1cf8fc4353f" ;
#     prov:label "mri_nu_correct.mni.log" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/mri/mri_nu_correct.mni.log" .
#
# <http://nidm.nidash.org/iri/30bb879cabca192e4596d686c962de69> a obo:UBERON_0002812,
#         prov:Entity ;
#     fs:relative_path "surf/lh.smoothwm.K1.crv" ;
#     nidm:tag "K1",
#         "crv",
#         "lh",
#         "smoothwm",
#         "surf" ;
#     obo:MS_1000568 "f15df01af8682a0acbe61a1e6fba87c9" ;
#     prov:label "lh.smoothwm.K1.crv" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/surf/lh.smoothwm.K1.crv" .
#
# <http://nidm.nidash.org/iri/3171982db56216da860f838b44fbcdeb> a obo:UBERON_0002812,
#         prov:Entity ;
#     fs:relative_path "surf/lh.inflated.nofix" ;
#     nidm:tag "inflated",
#         "lh",
#         "nofix",
#         "surf" ;
#     obo:MS_1000568 "33dd533812f168cddc464c7d64d69166" ;
#     prov:label "lh.inflated.nofix" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/surf/lh.inflated.nofix" .
#
# <http://nidm.nidash.org/iri/31e0890fef9a67574199aa6b81c56a0f> a fs:statistic_file,
#         obo:UBERON_0002813,
#         prov:Entity ;
#     fs:relative_path "stats/rh.curv.stats" ;
#     nidm:tag "curv",
#         "rh",
#         "stats" ;
#     obo:MS_1000568 "45a9a74d092b4c4999ffb0583c4b6e0f" ;
#     prov:label "rh.curv.stats" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/stats/rh.curv.stats" .
#
# <http://nidm.nidash.org/iri/326671f0db0e02f47f915c3198d1fa98> a fs:label_file,
#         obo:FMA_74533,
#         obo:UBERON_0002813,
#         obo:UBERON_0006100,
#         prov:Entity ;
#     fs:relative_path "label/rh.BA3b.label" ;
#     nidm:tag "BA3b",
#         "label",
#         "rh" ;
#     obo:MS_1000568 "4caf93a3b5e977e40ea3ca55e0f3149e" ;
#     prov:label "rh.BA3b.label" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/rh.BA3b.label" .
#
# <http://nidm.nidash.org/iri/339ff642c738308ad9a340b5e66f21d9> a fs:label_file,
#         obo:FMA_74532,
#         obo:UBERON_0002812,
#         obo:UBERON_0006100,
#         prov:Entity ;
#     fs:relative_path "label/lh.BA3a.label" ;
#     nidm:tag "BA3a",
#         "label",
#         "lh" ;
#     obo:MS_1000568 "f0068a81a0ebfc72fe54258f0636a910" ;
#     prov:label "lh.BA3a.label" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/lh.BA3a.label" .
#
# <http://nidm.nidash.org/iri/34259316e4577472b15e1c2fa018a8fc> a fs:annotation_file,
#         fs:default_parcellation,
#         obo:UBERON_0002812,
#         prov:Entity ;
#     fs:relative_path "label/lh." ;
#     nidm:tag "",
#         "annot",
#         "aparc.annot",
#         "label",
#         "lh" ;
#     obo:MS_1000568 "42934f498b15edbbcafb63bcf079b528" ;
#     prov:label "lh.bert_ref.aparc.annot" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/lh.bert_ref.aparc.annot" .
#
# <http://nidm.nidash.org/iri/349c21bb9bde7e7dffa7121b653f5df0> a fs:label_file,
#         obo:FMA_74533,
#         obo:UBERON_0002812,
#         obo:UBERON_0006100,
#         prov:Entity ;
#     fs:relative_path "label/lh.BA3b.label" ;
#     nidm:tag "BA3b",
#         "label",
#         "lh" ;
#     obo:MS_1000568 "725a30f9ea3fbfccbe4dfd2cfb0e2cc2" ;
#     prov:label "lh.BA3b.label" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/lh.BA3b.label" .
#
# <http://nidm.nidash.org/iri/35df9818371f502327463cea618073b4> a prov:Entity ;
#     fs:relative_path "mri/brain.mgz" ;
#     nidm:tag "brain",
#         "mgz",
#         "mri" ;
#     obo:MS_1000568 "78ba4ef8377bb0f733d2f90eacb2d303" ;
#     prov:label "brain.mgz" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/mri/brain.mgz" .
#
# <http://nidm.nidash.org/iri/381dbef1af935d3cb78f74751967ae27> a prov:Entity ;
#     fs:relative_path "scripts/pctsurfcon.log" ;
#     nidm:tag "log",
#         "pctsurfcon",
#         "scripts" ;
#     obo:MS_1000568 "534d7f2ee7bce5d9775bb82bbefa5be3" ;
#     prov:label "pctsurfcon.log" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/scripts/pctsurfcon.log" .
#
# <http://nidm.nidash.org/iri/3966c3a9a3e9ad3eb8448c2262742166> a obo:UBERON_0002813,
#         prov:Entity ;
#     fs:relative_path "surf/rh.orig.nofix" ;
#     nidm:tag "nofix",
#         "orig",
#         "rh",
#         "surf" ;
#     obo:MS_1000568 "11aa918755415bc632be33fa21e1ee32" ;
#     prov:label "rh.orig.nofix" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/surf/rh.orig.nofix" .
#
# <http://nidm.nidash.org/iri/3b46f47836725704a8109ceadce071d1> a prov:Entity ;
#     fs:relative_path "mri/aparc+aseg.mgz" ;
#     nidm:tag "aparc+aseg",
#         "mgz",
#         "mri" ;
#     obo:MS_1000568 "3af945134447d04315fe973ea89cda30" ;
#     prov:label "aparc+aseg.mgz" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/mri/aparc+aseg.mgz" .
#
# <http://nidm.nidash.org/iri/3e8cdc31382bfe9826977c4b2b73524b> a fs:statistic_file,
#         obo:UBERON_0002812,
#         prov:Entity ;
#     fs:relative_path "stats/lh.curv.stats" ;
#     nidm:tag "curv",
#         "lh",
#         "stats" ;
#     obo:MS_1000568 "e0a9ea49bceea11d9f3175d159eea927" ;
#     prov:label "lh.curv.stats" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/stats/lh.curv.stats" .
#
# <http://nidm.nidash.org/iri/4017883bb149c321b04e7ab7e2bb0808> a obo:UBERON_0002813,
#         prov:Entity ;
#     fs:relative_path "surf/rh.inflated" ;
#     nidm:tag "inflated",
#         "rh",
#         "surf" ;
#     obo:MS_1000568 "4ae44899a83b62f4c7486f493390af47" ;
#     prov:label "rh.inflated" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/surf/rh.inflated" .
#
# <http://nidm.nidash.org/iri/406b6708fab8989128948cbc5532b980> a prov:Entity ;
#     fs:relative_path "mri/wm.asegedit.mgz" ;
#     nidm:tag "asegedit",
#         "mgz",
#         "mri",
#         "wm" ;
#     obo:MS_1000568 "2c127d7c48e4a0b7d84afd62f147a0d0" ;
#     prov:label "wm.asegedit.mgz" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/mri/wm.asegedit.mgz" .
#
# <http://nidm.nidash.org/iri/41c46a0485b890662a5b57c25b86bfe1> a fs:annotation_file,
#         fs:default_parcellation,
#         obo:UBERON_0002813,
#         prov:Entity ;
#     fs:relative_path "label/rh.aparc.annot" ;
#     nidm:tag "annot",
#         "aparc",
#         "aparc.annot",
#         "label",
#         "rh" ;
#     obo:MS_1000568 "246cf306d4d45f26e1291441502dc1c7" ;
#     prov:label "rh.aparc.annot" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/rh.aparc.annot" .
#
# <http://nidm.nidash.org/iri/44472ac39f759b8749b2925b4e5afa60> a prov:Entity ;
#     fs:relative_path "scripts/recon-all.local-copy" ;
#     nidm:tag "local-copy",
#         "recon-all",
#         "scripts" ;
#     obo:MS_1000568 "09311bd663ee0ca4dbcb9075cedbb93c" ;
#     prov:label "recon-all.local-copy" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/scripts/recon-all.local-copy" .
#
# <http://nidm.nidash.org/iri/44b44116d43395e32b31dbc1c48c99d6> a obo:UBERON_0002813,
#         prov:Entity ;
#     fs:relative_path "surf/rh.inflated.K" ;
#     nidm:tag "K",
#         "inflated",
#         "rh",
#         "surf" ;
#     obo:MS_1000568 "c711a6c2bca0b9744f2ddfd8c2b25e46" ;
#     prov:label "rh.inflated.K" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/surf/rh.inflated.K" .
#
# <http://nidm.nidash.org/iri/44f239c114fbcb261b886fb9fb5ea9e7> a prov:Entity ;
#     fs:relative_path "mri/norm.mgz" ;
#     nidm:tag "mgz",
#         "mri",
#         "norm" ;
#     obo:MS_1000568 "207a34d31302146896a891c7dfead2ca" ;
#     prov:label "norm.mgz" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/mri/norm.mgz" .
#
# <http://nidm.nidash.org/iri/462206be19ada5752edc24868c5eea47> a fs:label_file,
#         obo:FMA_74533,
#         obo:UBERON_0002812,
#         obo:UBERON_0013535,
#         prov:Entity ;
#     fs:relative_path "label/lh.BA4p.label" ;
#     nidm:tag "BA4p",
#         "label",
#         "lh" ;
#     obo:MS_1000568 "54f4629c97ae4bf67e38551b7feab567" ;
#     prov:label "lh.BA4p.label" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/lh.BA4p.label" .
#
# <http://nidm.nidash.org/iri/46e2461c3fbe30b942d0e631dcb1a515> a fs:statistic_file,
#         prov:Entity ;
#     fs:relative_path "stats/wmparc.stats" ;
#     nidm:tag "stats",
#         "wmparc" ;
#     obo:MS_1000568 "a5cfd73e72d5c8dcc02d6e2c1f2a8a99" ;
#     prov:label "wmparc.stats" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/stats/wmparc.stats" .
#
# <http://nidm.nidash.org/iri/4bea435d0fb69f1a8e8a84c8fb8bc392> a prov:Entity ;
#     fs:relative_path "mri/talairach_with_skull_2.log" ;
#     nidm:tag "log",
#         "mri",
#         "talairach_with_skull_2" ;
#     obo:MS_1000568 "9d7f25a2e756f9c9060f781f3887d33d" ;
#     prov:label "talairach_with_skull_2.log" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/mri/talairach_with_skull_2.log" .
#
# <http://nidm.nidash.org/iri/4fcfea889bb4caa903b59375580a3c47> a fs:label_file,
#         prov:Entity ;
#     fs:relative_path "mri/aseg.auto_noCCseg.label_intensities.txt" ;
#     nidm:tag "aseg",
#         "auto_noCCseg",
#         "label",
#         "label_intensities",
#         "mri",
#         "txt" ;
#     obo:MS_1000568 "4f2ba800b6bfa137fb7b67028bb18c07" ;
#     prov:label "aseg.auto_noCCseg.label_intensities.txt" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/mri/aseg.auto_noCCseg.label_intensities.txt" .
#
# <http://nidm.nidash.org/iri/526f980d57aa41db5c7847230c887d5c> a prov:Entity ;
#     fs:relative_path "scripts/recon-all.cmd" ;
#     nidm:tag "cmd",
#         "recon-all",
#         "scripts" ;
#     obo:MS_1000568 "c439cd35ff815dcad233cbf6aa19437f" ;
#     prov:label "recon-all.cmd" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/scripts/recon-all.cmd" .
#
# <http://nidm.nidash.org/iri/53ccaf1cc86339adb45d0615046401d1> a fs:label_file,
#         obo:UBERON_0002436,
#         obo:UBERON_0002812,
#         prov:Entity ;
#     fs:relative_path "label/lh.V1.thresh.label" ;
#     nidm:tag "V1",
#         "label",
#         "lh",
#         "thresh" ;
#     obo:MS_1000568 "914c8f6350979301689f7b6924477292" ;
#     prov:label "lh.V1.thresh.label" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/lh.V1.thresh.label" .
#
# <http://nidm.nidash.org/iri/53fd1c92fc82620aac2e40460312a65d> a obo:UBERON_0002813,
#         prov:Entity ;
#     fs:relative_path "surf/rh.curv.pial" ;
#     nidm:tag "curv",
#         "pial",
#         "rh",
#         "surf" ;
#     obo:MS_1000568 "d4ec066e97c6f3a5e4270bff851e66d4" ;
#     prov:label "rh.curv.pial" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/surf/rh.curv.pial" .
#
# <http://nidm.nidash.org/iri/541c304e148fd0eaf3c6d1b495f79a3b> a fs:label_file,
#         obo:FMA_74532,
#         obo:UBERON_0002813,
#         obo:UBERON_0006100,
#         prov:Entity ;
#     fs:relative_path "label/rh.BA3a.thresh.label" ;
#     nidm:tag "BA3a",
#         "label",
#         "rh",
#         "thresh" ;
#     obo:MS_1000568 "3f96844120234b5a289a6159163b6992" ;
#     prov:label "rh.BA3a.thresh.label" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/rh.BA3a.thresh.label" .
#
# <http://nidm.nidash.org/iri/542cbea495c57cfefeb374250b96e3aa> a fs:statistic_file,
#         obo:UBERON_0002812,
#         prov:Entity ;
#     fs:relative_path "stats/lh.aparc.DKTatlas40.stats" ;
#     nidm:tag "DKTatlas40",
#         "aparc",
#         "lh",
#         "stats" ;
#     obo:MS_1000568 "d52768f16494b6840061c941a7cb8a41" ;
#     prov:label "lh.aparc.DKTatlas40.stats" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/stats/lh.aparc.DKTatlas40.stats" .
#
# <http://nidm.nidash.org/iri/5589b976eea76304b4f16beb0d676dcb> a obo:UBERON_0002812,
#         prov:Entity ;
#     fs:relative_path "surf/lh.thickness" ;
#     nidm:tag "lh",
#         "surf",
#         "thickness" ;
#     obo:MS_1000568 "ba8b9ea239be2af02a8aaf8f958925fd" ;
#     prov:label "lh.thickness" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/surf/lh.thickness" .
#
# <http://nidm.nidash.org/iri/56098ec2f130a168f0339e4d311ea100> a fs:annotation_file,
#         fs:default_parcellation,
#         obo:UBERON_0002812,
#         prov:Entity ;
#     fs:relative_path "label/lh.aparc.annot" ;
#     nidm:tag "annot",
#         "aparc",
#         "aparc.annot",
#         "label",
#         "lh" ;
#     obo:MS_1000568 "284a638bc51f53716978577d4382b675" ;
#     prov:label "lh.aparc.annot" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/lh.aparc.annot" .
#
# <http://nidm.nidash.org/iri/563265a36772916f62b4e41fe6f22e7a> a prov:Entity ;
#     fs:relative_path "mri/transforms/talairach.m3z.inv.y.mgz" ;
#     nidm:tag "inv",
#         "m3z",
#         "mgz",
#         "mri",
#         "talairach",
#         "transforms",
#         "y" ;
#     obo:MS_1000568 "4f96b22b5faa63a80ca2936360b4829b" ;
#     prov:label "talairach.m3z.inv.y.mgz" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/mri/transforms/talairach.m3z.inv.y.mgz" .
#
# <http://nidm.nidash.org/iri/565fbddd9795ee7af65b26dab5ac7da2> a fs:label_file,
#         obo:UBERON_0002812,
#         prov:Entity ;
#     fs:relative_path "surf/lh.defect_labels" ;
#     nidm:tag "defect_labels",
#         "label",
#         "lh",
#         "surf" ;
#     obo:MS_1000568 "21c1321c2a60a104f387d8ee7e2d68bb" ;
#     prov:label "lh.defect_labels" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/surf/lh.defect_labels" .
#
# <http://nidm.nidash.org/iri/56c6adfe923213144ee5fc75fe23c368> a obo:UBERON_0002812,
#         prov:Entity ;
#     fs:relative_path "surf/lh.inflated" ;
#     nidm:tag "inflated",
#         "lh",
#         "surf" ;
#     obo:MS_1000568 "24f80de3f528075c109d8588e6afa24c" ;
# ...
#         "lh",
#         "smoothwm",
#         "surf" ;
#     obo:MS_1000568 "51430ca1dbdd480bd6b7c0d4d89a55f9" ;
#     prov:label "lh.smoothwm.BE.crv" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/surf/lh.smoothwm.BE.crv" .
#
# niiri:dd363fe3630a12ac15033bd833199f25 a fs:label_file,
#         obo:UBERON_0002812,
#         obo:UBERON_0006099,
#         prov:Entity ;
#     fs:relative_path "label/lh.BA1.label" ;
#     nidm:tag "BA1",
#         "label",
#         "lh" ;
#     obo:MS_1000568 "d654c9881ce89d37f05426fba262da94" ;
#     prov:label "lh.BA1.label" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/lh.BA1.label" .
#
# niiri:ddbbb0eb79eb892a2273e23009f06e14 a fs:annotation_file,
#         fs:color_table,
#         fs:default_parcellation,
#         prov:Entity ;
#     fs:relative_path "label/aparc.annot.a2009s.ctab" ;
#     nidm:tag "a2009s",
#         "annot",
#         "aparc",
#         "aparc.annot",
#         "ctab",
#         "label" ;
#     obo:MS_1000568 "cf32a567746bf18e8b52c323dc152570" ;
#     prov:label "aparc.annot.a2009s.ctab" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/aparc.annot.a2009s.ctab" .
#
# niiri:e3b476bc9782cd09cc0e0bf8bda32d2a a fs:label_file,
#         obo:UBERON_0002813,
#         obo:UBERON_0006099,
#         prov:Entity ;
#     fs:relative_path "label/rh.BA1.thresh.label" ;
#     nidm:tag "BA1",
#         "label",
#         "rh",
#         "thresh" ;
#     obo:MS_1000568 "fbfb267468259b8372c77bb93b7ee9bc" ;
#     prov:label "rh.BA1.thresh.label" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/rh.BA1.thresh.label" .
#
# niiri:e450bb26d9dff4a942a6f2f29fcc7925 a obo:UBERON_0002813,
#         prov:Entity ;
#     fs:relative_path "surf/rh.smoothwm.K1.crv" ;
#     nidm:tag "K1",
#         "crv",
#         "rh",
#         "smoothwm",
#         "surf" ;
#     obo:MS_1000568 "c4109b52d202daf05561c56d22a8535f" ;
#     prov:label "rh.smoothwm.K1.crv" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/surf/rh.smoothwm.K1.crv" .
#
# niiri:e4bdbc14a29e53dc4168b90a67815464 a fs:label_file,
#         obo:FMA_74533,
#         obo:UBERON_0002813,
#         obo:UBERON_0013535,
#         prov:Entity ;
#     fs:relative_path "label/rh.BA4p.thresh.label" ;
#     nidm:tag "BA4p",
#         "label",
#         "rh",
#         "thresh" ;
#     obo:MS_1000568 "f8c65912f445313f4f07255655b5b76f" ;
#     prov:label "rh.BA4p.thresh.label" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/rh.BA4p.thresh.label" .
#
# niiri:e522b153a27ab07522cf6dfc308c838d a prov:Entity ;
#     fs:relative_path "mri/rawavg.mgz" ;
#     nidm:tag "mgz",
#         "mri",
#         "rawavg" ;
#     obo:MS_1000568 "789fe137158a584af830c71942bd6889" ;
#     prov:label "rawavg.mgz" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/mri/rawavg.mgz" .
#
# niiri:e64fc913db589848692b887576264e12 a prov:Entity ;
#     fs:relative_path "mri/transforms/talairach_avi_QA2.log" ;
#     nidm:tag "log",
#         "mri",
#         "talairach_avi_QA2",
#         "transforms" ;
#     obo:MS_1000568 "2ec8f6e65308cac0ab06e85217487483" ;
#     prov:label "talairach_avi_QA2.log" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/mri/transforms/talairach_avi_QA2.log" .
#
# niiri:e653f4094462aec5bd679683846732a4 a prov:Entity ;
#     fs:relative_path "mri/orig/001.lta" ;
#     nidm:tag "001",
#         "lta",
#         "mri",
#         "orig" ;
#     obo:MS_1000568 "07ff62f82a18b4f90b2310f5d14fc4e2" ;
#     prov:label "001.lta" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/mri/orig/001.lta" .
#
# niiri:e66274c5acccbacf00a00da0a7d1e849 a fs:annotation_file,
#         fs:default_parcellation,
#         obo:UBERON_0002813,
#         prov:Entity ;
#     fs:relative_path "label/rh." ;
#     nidm:tag "",
#         "annot",
#         "aparc.annot",
#         "label",
#         "rh" ;
#     obo:MS_1000568 "11a6e5e23dfb06075ce85be7cca9e190" ;
#     prov:label "rh.bert_ref.aparc.annot" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/rh.bert_ref.aparc.annot" .
#
# niiri:e6f33e870fe384bcb0eb500c659069da a prov:Entity ;
#     fs:relative_path "mri/wm255.txt" ;
#     nidm:tag "mri",
#         "txt",
#         "wm255" ;
#     obo:MS_1000568 "d84cd2194b1ccdf66e835a30f84d768f" ;
#     prov:label "wm255.txt" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/mri/wm255.txt" .
#
# niiri:e744f0513427fbe84d5d8ae8ecc0d15e a obo:UBERON_0002812,
#         prov:Entity ;
#     fs:relative_path "surf/lh.smoothwm" ;
#     nidm:tag "lh",
#         "smoothwm",
#         "surf" ;
#     obo:MS_1000568 "51674e793d8988195fec9021496707a3" ;
#     prov:label "lh.smoothwm" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/surf/lh.smoothwm" .
#
# niiri:e74b0eb67811e6e5c8d16fd5dcde439a a fs:label_file,
#         obo:UBERON_0002813,
#         obo:UBERON_0006472,
#         prov:Entity ;
#     fs:relative_path "label/rh.BA6.label" ;
#     nidm:tag "BA6",
#         "label",
#         "rh" ;
#     obo:MS_1000568 "be4d900dea858518a40f47af1ca7c6da" ;
#     prov:label "rh.BA6.label" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/rh.BA6.label" .
#
# niiri:e7f3fbb6ca0a8d0aa97441471a5b2c55 a prov:Entity ;
#     fs:relative_path "mri/orig/003.lta" ;
#     nidm:tag "003",
#         "lta",
#         "mri",
#         "orig" ;
#     obo:MS_1000568 "33d38f56e91c768b4bf6b6fc61af4b69" ;
#     prov:label "003.lta" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/mri/orig/003.lta" .
#
# niiri:e8272fd558d96fad5ef76f786997bf40 a obo:UBERON_0002813,
#         prov:Entity ;
#     fs:relative_path "surf/rh.sphere.reg" ;
#     nidm:tag "reg",
#         "rh",
#         "sphere",
#         "surf" ;
#     obo:MS_1000568 "0b5ef4afafc36ff5a0d9c4d02037b5e7" ;
#     prov:label "rh.sphere.reg" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/surf/rh.sphere.reg" .
#
# niiri:e8e0afd0b3eb870e1afeb4542d02ca19 a fs:label_file,
#         obo:UBERON_0002813,
#         obo:UBERON_0006481,
#         prov:Entity ;
#     fs:relative_path "label/rh.BA44.label" ;
#     nidm:tag "BA44",
#         "label",
#         "rh" ;
#     obo:MS_1000568 "e363ae86aaeeabb2c3f782f04e5f0462" ;
#     prov:label "rh.BA44.label" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/rh.BA44.label" .
#
# niiri:e8fd424fb4cbaf75179d1d6ae4cd6f85 a fs:label_file,
#         obo:UBERON_0002812,
#         obo:UBERON_0006099,
#         prov:Entity ;
#     fs:relative_path "label/lh.BA1.thresh.label" ;
#     nidm:tag "BA1",
#         "label",
#         "lh",
#         "thresh" ;
#     obo:MS_1000568 "55ca57c22fd96deb1079bbc7f2437898" ;
#     prov:label "lh.BA1.thresh.label" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/lh.BA1.thresh.label" .
#
# niiri:e94e89ca3af2532f2a89f8885a630d2d a obo:UBERON_0002812,
#         prov:Entity ;
#     fs:relative_path "surf/lh.smoothwm.C.crv" ;
#     nidm:tag "C",
#         "crv",
#         "lh",
#         "smoothwm",
#         "surf" ;
#     obo:MS_1000568 "434bd941ed232e00db1fa6853d7c561f" ;
#     prov:label "lh.smoothwm.C.crv" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/surf/lh.smoothwm.C.crv" .
#
# niiri:ea6ff0b772513d85f38c30790416a821 a obo:UBERON_0002812,
#         prov:Entity ;
#     fs:relative_path "surf/lh.smoothwm.S.crv" ;
#     nidm:tag "S",
#         "crv",
#         "lh",
#         "smoothwm",
#         "surf" ;
#     obo:MS_1000568 "65426e4a17d991e4afe9aa91cf4ea1b0" ;
#     prov:label "lh.smoothwm.S.crv" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/surf/lh.smoothwm.S.crv" .
#
# niiri:eb3e725d4108609c637ca658e5e987ea a prov:Entity ;
#     fs:relative_path "scripts/recon-all-status.log" ;
#     nidm:tag "log",
#         "recon-all-status",
#         "scripts" ;
#     obo:MS_1000568 "bd0d00460e510233b273d22020fd5c6d" ;
#     prov:label "recon-all-status.log" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/scripts/recon-all-status.log" .
#
# niiri:eb451cc27ec167903326dd79fe77aa96 a obo:UBERON_0002812,
#         prov:Entity ;
#     fs:relative_path "surf/lh.curv" ;
#     nidm:tag "curv",
#         "lh",
#         "surf" ;
#     obo:MS_1000568 "0548078064f290c85cfa6c050ff5304f" ;
#     prov:label "lh.curv" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/surf/lh.curv" .
#
# niiri:ecdb68580def1439dc7e7687e9a84cd4 a obo:UBERON_0002813,
#         prov:Entity ;
#     fs:relative_path "surf/rh.area.pial" ;
#     nidm:tag "area",
#         "pial",
#         "rh",
#         "surf" ;
#     obo:MS_1000568 "0fce42d68d165409fa67f903cbe1a767" ;
#     prov:label "rh.area.pial" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/surf/rh.area.pial" .
#
# niiri:ee502e8609af39951650598df0c6b1e9 a obo:UBERON_0002813,
#         prov:Entity ;
#     fs:relative_path "surf/rh.smoothwm.BE.crv" ;
#     nidm:tag "BE",
#         "crv",
#         "rh",
#         "smoothwm",
#         "surf" ;
#     obo:MS_1000568 "3d4d26b7ac82562703db53331df09416" ;
#     prov:label "rh.smoothwm.BE.crv" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/surf/rh.smoothwm.BE.crv" .
#
# niiri:ef46876f398841888e0467390b8758a2 a obo:UBERON_0002812,
#         prov:Entity ;
#     fs:relative_path "surf/lh.sphere.reg" ;
#     nidm:tag "lh",
#         "reg",
#         "sphere",
#         "surf" ;
#     obo:MS_1000568 "e26de2323fbe1cf09fbb185d1ea03440" ;
#     prov:label "lh.sphere.reg" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/surf/lh.sphere.reg" .
#
# niiri:f0bade97d334d4451d89dbb4054433dc a prov:Entity ;
#     fs:relative_path "mri/orig/003-iscale.txt" ;
#     nidm:tag "003-iscale",
#         "mri",
#         "orig",
#         "txt" ;
#     obo:MS_1000568 "11bd0387ab31562c2bbf493255dd9681" ;
#     prov:label "003-iscale.txt" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/mri/orig/003-iscale.txt" .
#
# niiri:f17b8ed28e191621ead8f898beacbacb a fs:label_file,
#         obo:UBERON_0002813,
#         obo:UBERON_0006481,
#         prov:Entity ;
#     fs:relative_path "label/rh.BA44.thresh.label" ;
#     nidm:tag "BA44",
#         "label",
#         "rh",
#         "thresh" ;
#     obo:MS_1000568 "b929ccb205aff5a1faf9921e519ba180" ;
#     prov:label "rh.BA44.thresh.label" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/rh.BA44.thresh.label" .
#
# niiri:f24ddece62d2167eddd3e552100ce099 a fs:label_file,
#         obo:FMA_74532,
#         obo:UBERON_0002812,
#         obo:UBERON_0013535,
#         prov:Entity ;
#     fs:relative_path "label/lh.BA4a.label" ;
#     nidm:tag "BA4a",
#         "label",
#         "lh" ;
#     obo:MS_1000568 "0edcb6599c3016efa9bf974d96686cd3" ;
#     prov:label "lh.BA4a.label" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/lh.BA4a.label" .
#
# niiri:f25a310141b70f08bb84881df502f9aa a obo:UBERON_0002812,
#         prov:Entity ;
#     fs:relative_path "surf/lh.jacobian_white" ;
#     nidm:tag "jacobian_white",
#         "lh",
#         "surf" ;
#     obo:MS_1000568 "9501e3ffaced3b09aa247bfe2ef2e9f7" ;
#     prov:label "lh.jacobian_white" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/surf/lh.jacobian_white" .
#
# niiri:f381082e32444e53e65daf241a7a7f4a a prov:Entity ;
#     fs:relative_path "mri/aseg.mgz" ;
#     nidm:tag "aseg",
#         "mgz",
#         "mri" ;
#     obo:MS_1000568 "0d6031c46364175255fdfe6c03364a1a" ;
#     prov:label "aseg.mgz" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/mri/aseg.mgz" .
#
# niiri:f6a40163187f0d089084451ed75451b1 a obo:UBERON_0002812,
#         prov:Entity ;
#     fs:relative_path "surf/lh.qsphere.nofix" ;
#     nidm:tag "lh",
#         "nofix",
#         "qsphere",
#         "surf" ;
#     obo:MS_1000568 "078b7939c92ae5c216788ea8523ee66b" ;
#     prov:label "lh.qsphere.nofix" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/surf/lh.qsphere.nofix" .
#
# niiri:f7efe10b4f049a134b8a37d6785a00dc a prov:Entity ;
#     fs:relative_path "mri/orig.mgz" ;
#     nidm:tag "mgz",
#         "mri",
#         "orig" ;
#     obo:MS_1000568 "a0924b00e495015b4161f0de1a167f07" ;
#     prov:label "orig.mgz" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/mri/orig.mgz" .
#
# niiri:f83014accee72a41cccac7686922731d a fs:label_file,
#         obo:UBERON_0002812,
#         obo:UBERON_0006482,
#         prov:Entity ;
#     fs:relative_path "label/lh.BA45.label" ;
#     nidm:tag "BA45",
#         "label",
#         "lh" ;
#     obo:MS_1000568 "46dc44f72d7957a168b768b449c4dd0a" ;
#     prov:label "lh.BA45.label" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/lh.BA45.label" .
#
# niiri:f86ed4fdb83af11e2306c72330ef5dc1 a prov:Entity ;
#     fs:relative_path "mri/wm1.txt" ;
#     nidm:tag "mri",
#         "txt",
#         "wm1" ;
#     obo:MS_1000568 "18fbad2e966d01b408a65628f9a31cce" ;
#     prov:label "wm1.txt" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/mri/wm1.txt" .
#
# niiri:fc102be99c96b1d96d9fad68b0678112 a fs:annotation_file,
#         obo:UBERON_0002813,
#         obo:UBERON_0013529,
#         prov:Entity ;
#     fs:relative_path "label/rh.BA.annot" ;
#     nidm:tag "BA",
#         "annot",
#         "label",
#         "rh" ;
#     obo:MS_1000568 "4eeb87bf43ac7376f85d830386e1573d" ;
#     prov:label "rh.BA.annot" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/rh.BA.annot" .
#
# niiri:fc94feae3198f5cfe59be3b41a26bee4 a obo:UBERON_0002813,
#         prov:Entity ;
#     fs:relative_path "surf/rh.orig" ;
#     nidm:tag "orig",
#         "rh",
#         "surf" ;
#     obo:MS_1000568 "2a51bc48ee1d3f715d9646774c2801ff" ;
#     prov:label "rh.orig" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/surf/rh.orig" .
#
# niiri:ffefdab83a950a624d01dd4e543f3442 a fs:label_file,
#         obo:FMA_74533,
#         obo:UBERON_0002812,
#         obo:UBERON_0013535,
#         prov:Entity ;
#     fs:relative_path "label/lh.BA4p.thresh.label" ;
#     nidm:tag "BA4p",
#         "label",
#         "lh",
#         "thresh" ;
#     obo:MS_1000568 "26c30b893084e5c1f709b058cffb05e8" ;
#     prov:label "lh.BA4p.thresh.label" ;
#     prov:location "http://computor.mit.edu:10101/file?file_uri=file://warpspeed.local/Applications/freesurfer/subjects/bert/label/lh.BA4p.thresh.label" .

# %% [markdown]
# ## Send rdf to a remote triplestore

# %%
# !curl -T bert.provn.ttl http://bips.incf.org:8890/DAV/home/demo/rdf_sink -u demo:demo

# %% [markdown]
# ## Querying FreeSurferobject models with SPARQL using a triplestore
#
# In this section we will show example SPARQL queries that access a triplestore containing FreeSurfer object models.
#
# First we query for images that are of type T1.

# %%
import rdflib as rdf
g = rdf.graph.Graph()
g.parse(filename_ttl, format='turtle')

query = """
PREFIX prov: <http://www.w3.org/ns/prov#>
PREFIX obo: <http://purl.obolibrary.org/obo/>
PREFIX foaf: <http://xmlns.com/foaf/0.1/>
PREFIX fs: <http://freesurfer.net/fswiki/terms/0.1/>
PREFIX nidm: <http://nidm.nidash.org/terms/0.1/>
PREFIX niiri: <http://nidm.nidash.org/iri/>
PREFIX nif: <http://neurolex.org/wiki/>
PREFIX dcterms: <http://purl.org/dc/terms/>

SELECT ?s ?label
WHERE { ?c fs:subject_id ?s .
        # ?c prov:hadMember ?e .
        # ?e prov:label ?label .
        # ?e a nif:nlx_inv_20090243 .}
"""

results = g.query(query)

for row in results:
    print([e for e in row])
# Out:
# [rdflib.term.Literal(u'bert'), rdflib.term.Literal(u'T1.mgz')]

# %% [markdown]
# Now we query for files that have the word BA in their label

# %%
query = """
PREFIX prov: <http://www.w3.org/ns/prov#>
PREFIX obo: <http://purl.obolibrary.org/obo/>
PREFIX foaf: <http://xmlns.com/foaf/0.1/>
PREFIX fs: <http://freesurfer.net/fswiki/terms/0.1/>
PREFIX nidm: <http://nidm.nidash.org/terms/0.1/>
PREFIX niiri: <http://nidm.nidash.org/iri/>
PREFIX nif: <http://neurolex.org/wiki/>
PREFIX dcterms: <http://purl.org/dc/terms/>

SELECT ?s ?label
WHERE { ?c fs:subject_id ?s .
        # ?c prov:hadMember ?e .
        # ?e prov:label ?label .
        FILTER regex(?label, "BA")}

"""

results = g.query(query)

for row in results:
    print([e for e in row])
# Out:
# [rdflib.term.Literal(u'bert'), rdflib.term.Literal(u'lh.BA2.label')]
# [rdflib.term.Literal(u'bert'), rdflib.term.Literal(u'lh.BA1.thresh.label')]
# [rdflib.term.Literal(u'bert'), rdflib.term.Literal(u'lh.BA3b.label')]
# [rdflib.term.Literal(u'bert'), rdflib.term.Literal(u'rh.BA2.label')]
# [rdflib.term.Literal(u'bert'), rdflib.term.Literal(u'rh.BA3b.label')]
# [rdflib.term.Literal(u'bert'), rdflib.term.Literal(u'lh.BA3a.thresh.label')]
# [rdflib.term.Literal(u'bert'), rdflib.term.Literal(u'lh.BA45.thresh.label')]
# [rdflib.term.Literal(u'bert'), rdflib.term.Literal(u'rh.BA3a.label')]
# [rdflib.term.Literal(u'bert'), rdflib.term.Literal(u'rh.BA4a.label')]
# [rdflib.term.Literal(u'bert'), rdflib.term.Literal(u'lh.BA4a.label')]
# [rdflib.term.Literal(u'bert'), rdflib.term.Literal(u'lh.BA44.thresh.label')]
# [rdflib.term.Literal(u'bert'), rdflib.term.Literal(u'lh.BA.stats')]
# [rdflib.term.Literal(u'bert'), rdflib.term.Literal(u'lh.BA.annot')]
# [rdflib.term.Literal(u'bert'), rdflib.term.Literal(u'BA.ctab')]
# [rdflib.term.Literal(u'bert'), rdflib.term.Literal(u'lh.BA1.label')]
# [rdflib.term.Literal(u'bert'), rdflib.term.Literal(u'lh.BA2.thresh.label')]
# [rdflib.term.Literal(u'bert'), rdflib.term.Literal(u'rh.BA.annot')]
# [rdflib.term.Literal(u'bert'), rdflib.term.Literal(u'lh.BA44.label')]
# [rdflib.term.Literal(u'bert'), rdflib.term.Literal(u'rh.BA1.label')]
# [rdflib.term.Literal(u'bert'), rdflib.term.Literal(u'rh.BA4p.label')]
# [rdflib.term.Literal(u'bert'), rdflib.term.Literal(u'lh.BA.thresh.annot')]
# [rdflib.term.Literal(u'bert'), rdflib.term.Literal(u'rh.BA4a.thresh.label')]
# [rdflib.term.Literal(u'bert'), rdflib.term.Literal(u'lh.BA6.thresh.label')]
# [rdflib.term.Literal(u'bert'), rdflib.term.Literal(u'BA.thresh.ctab')]
# [rdflib.term.Literal(u'bert'), rdflib.term.Literal(u'lh.BA4p.label')]
# [rdflib.term.Literal(u'bert'), rdflib.term.Literal(u'rh.BA6.label')]
# [rdflib.term.Literal(u'bert'), rdflib.term.Literal(u'rh.BA6.thresh.label')]
# [rdflib.term.Literal(u'bert'), rdflib.term.Literal(u'rh.BA.thresh.stats')]
# [rdflib.term.Literal(u'bert'), rdflib.term.Literal(u'rh.BA3b.thresh.label')]
# [rdflib.term.Literal(u'bert'), rdflib.term.Literal(u'lh.BA4a.thresh.label')]
# [rdflib.term.Literal(u'bert'), rdflib.term.Literal(u'rh.BA44.label')]
# [rdflib.term.Literal(u'bert'), rdflib.term.Literal(u'rh.BA4p.thresh.label')]
# [rdflib.term.Literal(u'bert'), rdflib.term.Literal(u'lh.BA3b.thresh.label')]
# [rdflib.term.Literal(u'bert'), rdflib.term.Literal(u'lh.BA4p.thresh.label')]
# [rdflib.term.Literal(u'bert'), rdflib.term.Literal(u'rh.BA1.thresh.label')]
# [rdflib.term.Literal(u'bert'), rdflib.term.Literal(u'rh.BA44.thresh.label')]
# [rdflib.term.Literal(u'bert'), rdflib.term.Literal(u'rh.BA.stats')]
# [rdflib.term.Literal(u'bert'), rdflib.term.Literal(u'rh.BA3a.thresh.label')]
# [rdflib.term.Literal(u'bert'), rdflib.term.Literal(u'lh.BA.thresh.stats')]
# [rdflib.term.Literal(u'bert'), rdflib.term.Literal(u'rh.BA45.label')]
# [rdflib.term.Literal(u'bert'), rdflib.term.Literal(u'rh.BA45.thresh.label')]
# [rdflib.term.Literal(u'bert'), rdflib.term.Literal(u'rh.BA2.thresh.label')]
# [rdflib.term.Literal(u'bert'), rdflib.term.Literal(u'lh.BA6.label')]
# [rdflib.term.Literal(u'bert'), rdflib.term.Literal(u'lh.BA3a.label')]
# [rdflib.term.Literal(u'bert'), rdflib.term.Literal(u'rh.BA.thresh.annot')]
# [rdflib.term.Literal(u'bert'), rdflib.term.Literal(u'lh.BA45.label')]

# %% [markdown]
# Now we query for files that are explicitly of the type Brodmann Area. Note that this query doesn't resolve all the finer sub-divisions of Brodmann Area.

# %%
query = """
PREFIX prov: <http://www.w3.org/ns/prov#>
PREFIX obo: <http://purl.obolibrary.org/obo/>
PREFIX foaf: <http://xmlns.com/foaf/0.1/>
PREFIX fs: <http://freesurfer.net/fswiki/terms/0.1/>
PREFIX nidm: <http://nidm.nidash.org/terms/0.1/>
PREFIX niiri: <http://nidm.nidash.org/iri/>
PREFIX nif: <http://neurolex.org/wiki/>
PREFIX dcterms: <http://purl.org/dc/terms/>

SELECT ?s ?label
WHERE { ?c fs:subject_id ?s .
        # ?c prov:hadMember ?e .
        # ?e prov:label ?label .
        # ?e a obo:UBERON_0013529 .}

"""

results = g.query(query)

for row in results:
    print([e for e in row])
# Out:
# [rdflib.term.Literal(u'bert'), rdflib.term.Literal(u'rh.BA.stats')]
# [rdflib.term.Literal(u'bert'), rdflib.term.Literal(u'lh.BA.thresh.stats')]
# [rdflib.term.Literal(u'bert'), rdflib.term.Literal(u'BA.thresh.ctab')]
# [rdflib.term.Literal(u'bert'), rdflib.term.Literal(u'lh.BA.annot')]
# [rdflib.term.Literal(u'bert'), rdflib.term.Literal(u'rh.BA.thresh.stats')]
# [rdflib.term.Literal(u'bert'), rdflib.term.Literal(u'lh.BA.stats')]
# [rdflib.term.Literal(u'bert'), rdflib.term.Literal(u'rh.BA.annot')]
# [rdflib.term.Literal(u'bert'), rdflib.term.Literal(u'lh.BA.thresh.annot')]
# [rdflib.term.Literal(u'bert'), rdflib.term.Literal(u'rh.BA.thresh.annot')]
# [rdflib.term.Literal(u'bert'), rdflib.term.Literal(u'BA.ctab')]

# %% [markdown]
# # FreeSurfer terms dictionary
#
# ```
#     @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
#     @prefix owl: <http://www.w3.org/2002/07/owl#> .
#     @prefix skos: <http://www.w3.org/2004/02/skos/core#> .
#     @prefix dcam: <http://purl.org/dc/dcam/> .
#     @prefix dcterms: <http://purl.org/dc/terms/> .
#     @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
#     @prefix fs: <http://freesurfer.net/fswiki/terms/0.1/> .
#
#     <http://freesurfer.net/fswiki/terms/0.1/>
#         dcterms:modified "2013-06-05"^^<http://www.w3.org/2001/XMLSchema#date> ;
#         dcterms:title "FreeSurfer Metadata Terms"@en .
#
#     fs:subject_id
#         dcterms:description "An identifier of MRI dataset processed through freesurfer"@en ;
#         dcterms:issued "2013-06-05"^^<http://www.w3.org/2001/XMLSchema#date> ;
#         a nidm:ParticipantID;
#         rdfs:comment "A directory within FreeSurfer SUBJECTS_DIR"@en ;
#         rdfs:isDefinedBy <http://freesurfer.net/fswiki/terms/0.1/> ;
#         rdfs:label "Subject identifier"@en .
#     fs:relative_path
#         dcterms:description "Location of file from the root of the subject directory structure"@en ;
#         dcterms:issued "2013-06-05"^^<http://www.w3.org/2001/XMLSchema#date> ;
#         a nidm:annotation;
#         rdfs:comment "Location of file from the root of the subject directory structure"@en ;
#         rdfs:isDefinedBy <http://freesurfer.net/fswiki/terms/0.1/> ;
#         rdfs:label "Relative Path"@en .
# ```
#
# Terms still to encode:
#
#     - statistics
#     - MT_area
#     - exvivo
#     - label_file
#     - annotation_file
#     - statistic_file
#     - default_parcellation
#     - a2009s_parcellation
#     - color_table
#     - subject_directory
